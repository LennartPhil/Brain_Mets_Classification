# %% [markdown]
# # Pretrain Rough

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import re

from plotting_analysis_funcs import *

# %% [markdown]
# ## ResNeXt50
# Dropout Rate : 0.45

# %%
path_to_resnext50_pretrain_rough_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/pretrain_rough/resnext50_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_19_28_24/history_resnext50_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_19_28_24.npy')

plot_lr_history(
    path_to_train_history = path_to_resnext50_pretrain_rough_learning_rate,
    title = 'ResNeXt50 Pretrain Rough Training History',
    y_axis_max = 10
)
# Out:
# Epochs: 400
# Lowest loss 4.9255 at learning rate 9.61e-02
# np.float32(0.09605058)

# %% [markdown]
# I'll pick 10^-2

# %%
path_to_resnext50_pretrain_rough_weights_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/pretrain_rough/resnext50_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_23_06_39_34/history_resnext50_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_23_06_39_34.npy')

plot_training_history(
    path_to_train_history = path_to_resnext50_pretrain_rough_weights_train_history,
    title = 'ResNeXt50 Pretrain Weights Training History',
    custom_loss_limit = 15
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt50 Pretrain Weights Training History'
# Total Epochs Trained: 2500
# --------------------------------------------------
# Lowest Validation Loss of 0.1756 achieved at Epoch 2500.
# Validation Accuracy at this epoch was 0.9721.
# --------------------------------------------------
# Highest Validation Accuracy of 0.9852 achieved at Epoch 2011.
# Validation Loss at this epoch was 0.2813.
# ...

# %%
path_to_resnext50_pretrain_rough_transfer_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/pretrain_rough/resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_15_19_27/history_resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_15_19_27.npy')

plot_lr_history(
    path_to_train_history = path_to_resnext50_pretrain_rough_transfer_learning_rate,
    title = 'ResNeXt50 Pretrain Rough Transfer Learning Rate History',
    y_axis_max = 2
)
# Out:
# Epochs: 400
# Lowest loss 0.5710 at learning rate 8.91e-03
# np.float32(0.008912509)

# %% [markdown]
# I'll pick a learning rate of 8 x 10^-4

# %%
path_to_resnext50_pretrain_rough_weights_transfer_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/pretrain_rough/resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_08_56_24/history_resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_08_56_24.npy')

plot_training_history(
    path_to_train_history = path_to_resnext50_pretrain_rough_weights_transfer_train_history,
    title = 'ResNeXt50 Pretrain Rough Weights Transfer Training History',
    custom_loss_limit = 8
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt50 Pretrain Rough Weights Transfer Training History'
# Total Epochs Trained: 304
# --------------------------------------------------
# Lowest Validation Loss of 0.8502 achieved at Epoch 4.
# Validation Accuracy at this epoch was 0.5420.
# --------------------------------------------------
# Highest Validation Accuracy of 0.6870 achieved at Epoch 72.
# Validation Loss at this epoch was 1.1619.
# ...

# %% [markdown]
# Okay, major overfitting. I think I'll increase the dropout rate to 0.5

# %%
path_to_resnext50_pretrain_rough_weights_transfer_dropout_50_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/pretrain_rough/resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_08_59_13/history_resnext50_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_08_59_13.npy')

plot_training_history(
    path_to_train_history = path_to_resnext50_pretrain_rough_weights_transfer_dropout_50_train_history,
    title = 'ResNeXt50 Pretrain Rough Weights Transfer Training History with Dropout 0.5',
    custom_loss_limit = 8
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt50 Pretrain Rough Weights Transfer Training History with Dropout 0.5'
# Total Epochs Trained: 305
# --------------------------------------------------
# Lowest Validation Loss of 0.8667 achieved at Epoch 5.
# Validation Accuracy at this epoch was 0.5344.
# --------------------------------------------------
# Highest Validation Accuracy of 0.6412 achieved at Epoch 19.
# Validation Loss at this epoch was 0.8994.
# ...

# %% [markdown]
# No real improvment, I'll go back to dropout of 0.45 and increase the l2 regularization

# %% [markdown]
# ## ResNeXt101
# Dropout Rate : 0.45

# %%
path_to_resnext101_pretrain_weight_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/pretrain_rough/resnext101_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_20_45_05/history_resnext101_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_20_45_05.npy')

plot_lr_history(
    path_to_train_history = path_to_resnext101_pretrain_weight_learning_rate,
    title = 'ResNeXt101 Pretrain Rough Training History',
    y_axis_max = 20
)
# Out:
# Epochs: 400
# Lowest loss 9.2950 at learning rate 9.61e-02
# np.float32(0.09605058)

# %% [markdown]
# I'll pick 10^-2

# %%
path_to_resnext101_pretrain_rough_weights_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/pretrain_rough/resnext101_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_23_14_34_02/history_resnext101_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_23_14_34_02.npy')

plot_training_history(
    path_to_train_history = path_to_resnext101_pretrain_rough_weights_train_history,
    title = 'ResNeXt101 Pretrain Weights Training History',
    custom_loss_limit = 15
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt101 Pretrain Weights Training History'
# Total Epochs Trained: 2500
# --------------------------------------------------
# Lowest Validation Loss of 0.2236 achieved at Epoch 2399.
# Validation Accuracy at this epoch was 0.9869.
# --------------------------------------------------
# Highest Validation Accuracy of 0.9901 achieved at Epoch 2345.
# Validation Loss at this epoch was 0.2338.
# ...

# %%
path_to_resnext101_pretrain_rough_transfer_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/pretrain_rough/resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_16_15_37/history_resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_16_15_37.npy')

plot_lr_history(
    path_to_train_history = path_to_resnext101_pretrain_rough_transfer_learning_rate,
    title = 'ResNeXt101 Pretrain Rough Transfer Learning Rate History',
    y_axis_max = 1.5
)
# Out:
# Epochs: 400
# Lowest loss 0.5658 at learning rate 7.90e-03
# np.float32(0.007897688)

# %% [markdown]
# I'll pick a learning rate of 8 x 10^-4

# %%
path_to_resnext101_pretrain_rough_weights_transfer_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/pretrain_rough/resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_09_39_24/history_resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_09_39_24.npy')

plot_training_history(
    path_to_train_history = path_to_resnext101_pretrain_rough_weights_transfer_train_history,
    title = 'ResNeXt101 Pretrain Rough Weights Transfer Training History',
    custom_loss_limit = 6
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt101 Pretrain Rough Weights Transfer Training History'
# Total Epochs Trained: 302
# --------------------------------------------------
# Lowest Validation Loss of 0.9016 achieved at Epoch 2.
# Validation Accuracy at this epoch was 0.5115.
# --------------------------------------------------
# Highest Validation Accuracy of 0.6031 achieved at Epoch 276.
# Validation Loss at this epoch was 1.8042.
# ...

# %% [markdown]
# Also major overfitting, I'll increase the dropout rate to 0.50

# %%
path_to_resnext101_pretrain_rough_weights_transfer_dropout_50_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/pretrain_rough/resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_09_42_28/history_resnext101_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_09_42_28.npy')

plot_training_history(
    path_to_train_history = path_to_resnext101_pretrain_rough_weights_transfer_dropout_50_train_history,
    title = 'ResNeXt101 Pretrain Rough Weights Transfer Training History with Dropout 0.5',
    custom_loss_limit = 6
)
# Out:
# ...
# Training History Analysis for: 'ResNeXt101 Pretrain Rough Weights Transfer Training History with Dropout 0.5'
# Total Epochs Trained: 301
# --------------------------------------------------
# Lowest Validation Loss of 0.9072 achieved at Epoch 1.
# Validation Accuracy at this epoch was 0.4656.
# --------------------------------------------------
# Highest Validation Accuracy of 0.5649 achieved at Epoch 161.
# Validation Loss at this epoch was 2.2631.
# ...

# %% [markdown]
# Also seems to perform worse than before, I'll go back to a dropout rate of 0.45 and increase the l2 regularization.

# %% [markdown]
# ## ResNet152
# Dropout Rate : 0.45

# %%
path_to_resnet152_pretrain_rough_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/pretrain_rough/resnet152_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_17_16_06/history_resnet152_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_lr_run_2025_11_20_17_16_06.npy')

plot_lr_history(
    path_to_train_history = path_to_resnet152_pretrain_rough_learning_rate,
    title = 'ResNet152 Pretrain Rough Training History',
    y_axis_max = 20
)
# Out:
# Epochs: 400
# Lowest loss 10.1350 at learning rate 9.61e-02
# np.float32(0.09605058)

# %% [markdown]
# I'll also pick 10^-2

# %%
path_to_resnet152_pretrain_rough_weights_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/pretrain_rough/resnet152_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_22_11_31_26/history_resnet152_00_3cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_pretrain_rough_normal_run_2025_11_22_11_31_26.npy')

plot_training_history(
    path_to_train_history = path_to_resnet152_pretrain_rough_weights_train_history,
    title = 'ResNet152 Pretrain Weights Training History',
    custom_loss_limit = 15
)
# Out:
# ...
# Training History Analysis for: 'ResNet152 Pretrain Weights Training History'
# Total Epochs Trained: 3500
# --------------------------------------------------
# Lowest Validation Loss of 0.1127 achieved at Epoch 3465.
# Validation Accuracy at this epoch was 0.9869.
# --------------------------------------------------
# Highest Validation Accuracy of 0.9901 achieved at Epoch 3081.
# Validation Loss at this epoch was 0.1636.
# ...

# %%
path_to_resnet152_pretrain_rough_transfer_learning_rate = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/pretrain_rough/resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_13_43_37/history_resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_11_24_13_43_37.npy')

plot_lr_history(
    path_to_train_history = path_to_resnet152_pretrain_rough_transfer_learning_rate,
    title = 'ResNet152 Pretrain Rough Transfer Learning Rate History',
    y_axis_max = 1.5
)
# Out:
# Epochs: 400
# Lowest loss 0.5595 at learning rate 1.92e-02
# np.float32(0.01916461)

# %% [markdown]
# I'll pick a learning rate of 7 x 10^-4

# %%
path_to_resnext152_pretrain_rough_weights_transfer_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/pretrain_rough/resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_07_41_50/history_resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_25_07_41_50.npy')

plot_training_history(
    path_to_train_history = path_to_resnext152_pretrain_rough_weights_transfer_train_history,
    title = 'ResNet152 Pretrain Rough Weights Transfer Training History',
    custom_loss_limit = 6
)
# Out:
# ...
# Training History Analysis for: 'ResNet152 Pretrain Rough Weights Transfer Training History'
# Total Epochs Trained: 311
# --------------------------------------------------
# Lowest Validation Loss of 0.7944 achieved at Epoch 11.
# Validation Accuracy at this epoch was 0.5420.
# --------------------------------------------------
# Highest Validation Accuracy of 0.6183 achieved at Epoch 118.
# Validation Loss at this epoch was 1.2444.
# ...

# %% [markdown]
# Also major overfitting, I'll increase the dropout rate to 0.50

# %%
path_to_resnext152_pretrain_rough_weights_transfer_dropout_50_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/pretrain_rough/resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_07_43_24/history_resnet152_00_2cls_slice_no_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_11_27_07_43_24.npy')

plot_training_history(
    path_to_train_history = path_to_resnext152_pretrain_rough_weights_transfer_dropout_50_train_history,
    title = 'ResNet152 Pretrain Rough Weights Transfer Training History with Dropout 0.5',
    custom_loss_limit = 6
)
# Out:
# ...
# Training History Analysis for: 'ResNet152 Pretrain Rough Weights Transfer Training History with Dropout 0.5'
# Total Epochs Trained: 311
# --------------------------------------------------
# Lowest Validation Loss of 0.7799 achieved at Epoch 11.
# Validation Accuracy at this epoch was 0.5878.
# --------------------------------------------------
# Highest Validation Accuracy of 0.6183 achieved at Epoch 8.
# Validation Loss at this epoch was 0.7835.
# ...

# %% [markdown]
# Also worse than before, I'll go back to a dropout rate of 0.45 and increase the l2 regularization.
