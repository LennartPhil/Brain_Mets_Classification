# %% [markdown]
# # Pretrain Rough

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import re

from plotting_analysis_funcs import *

# %% [markdown]
# ## ResNeXt50

# %% [markdown]
# ## ResNeXt101

# %% [markdown]
# ## ResNet152
