# %% [markdown]
# # Four Sequences Training Analysis
# Base Models: ResNeXt50, ResNeXt101, ResNet152
#
# In the following file I'll note the trainings of the above mentioned Base Models with 4 MRI squences as inputs.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import re

from plotting_analysis_funcs import *
# Out:
# /var/folders/by/b05bkcn50tb0fx4h3hhz0h800000gn/T/ipykernel_2083/2426438369.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # ResNeXt50

# %%
path_to_resnext50_clinical_data_2_classes_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt50/2_classes_training/clinical_data/resnext50_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_27_23_20_27/history_resnext50_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_27_23_20_27.npy')

plot_training_history(path_to_resnext50_clinical_data_2_classes_train_history, title = 'ResNeXt50 Clinical Data 2 Classes Training History', custom_loss_limit=20)
# Out:
# ...
# Training History Analysis for: 'ResNeXt50 Clinical Data 2 Classes Training History'
# Total Epochs Trained: 1882
# --------------------------------------------------
# Lowest Validation Loss of 0.9528 achieved at Epoch 1582.
# Validation Accuracy at this epoch was 0.7176.
# --------------------------------------------------
# Highest Validation Accuracy of 0.7252 achieved at Epoch 1748.
# Validation Loss at this epoch was 1.1007.
# ...

# %% [markdown]
# # ResNeXt101

# %%
path_to_resnext101_clinical_data_2_classes_lr_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/clinical_data/resnext101_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_09_27_15_57_06/history_resnext101_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_lr_run_2025_09_27_15_57_06.npy')

plot_lr_history(path_to_resnext101_clinical_data_2_classes_lr_history, title ='ResNeXt101 Clinical Data 2 Classes - Learning Rate History', y_axis_max = 18)
# Out:
# Epochs: 400
# Lowest loss 11.1609 at learning rate 9.61e-02
# 0.09605058

# %% [markdown]
# I'll pick a learning rate of 3 x 10^-2 (0.03)

# %%
path_to_resnext101_clincal_data_2_classes_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNeXt101/2_classes_training/clinical_data/resnext101_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_28_02_05_44/history_resnext101_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_28_02_05_44.npy')

plot_training_history(path_to_resnext101_clincal_data_2_classes_train_history, title = 'ResNeXt101 Clinical Data 2 Classes Training History', custom_loss_limit=20)
# Out:
# ...
# Training History Analysis for: 'ResNeXt101 Clinical Data 2 Classes Training History'
# Total Epochs Trained: 1847
# --------------------------------------------------
# Lowest Validation Loss of 1.1022 achieved at Epoch 1547.
# Validation Accuracy at this epoch was 0.6489.
# --------------------------------------------------
# Highest Validation Accuracy of 0.7481 achieved at Epoch 983.
# Validation Loss at this epoch was 1.7794.
# ...

# %% [markdown]
# # ResNet152

# %%
path_to_resnet152_clinical_data_2_classes_train_history = Path('/Users/LennartPhilipp/Desktop/Uni/Prowiss/Training/training_histories_06_25/ResNet152/2_classes_training/clinical_data/resnet152_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_27_17_15_10/history_resnet152_00_2cls_slice_clin_no_layer_gray_seq[t1c]_normal_DA_normal_run_2025_09_27_17_15_10.npy')

plot_training_history(path_to_resnet152_clinical_data_2_classes_train_history, title = 'ResNet152 Clinical Data 2 Classes Training History', custom_loss_limit=20)
# Out:
# ...
# Training History Analysis for: 'ResNet152 Clinical Data 2 Classes Training History'
# Total Epochs Trained: 1830
# --------------------------------------------------
# Lowest Validation Loss of 1.1242 achieved at Epoch 1530.
# Validation Accuracy at this epoch was 0.6489.
# --------------------------------------------------
# Highest Validation Accuracy of 0.7405 achieved at Epoch 324.
# Validation Loss at this epoch was 13.5472.
# ...

# %% [markdown]
# k-fold
