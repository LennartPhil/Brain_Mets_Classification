# %%
import os
import sys
sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification")

from tqdm import tqdm
from datetime import datetime
import shutil
import pandas as pd
from dateutil.relativedelta import relativedelta
from nipype.interfaces.dcm2nii import Dcm2niix
from pathlib import Path

import brain_mets_classification.config as config
import brain_mets_classification.custom_funcs as funcs
import brain_mets_classification.preprocessing_funcs as preprocessing

# %%
path_to_folder = "/Volumes/BrainMets/LennartBrainMets_revision"
#path_to_folder = f"{config.path_to_ssd}/originalPatientFiles"

#path_to_folder = f"{config.path_to_n30}/RgbBrainMetsSampleN30"
pathToCleanMRIList = ""

# %% [markdown]
# ### Step 0: Removes sequences based on the blacklist

# %%
#Example file structure
#├── Anonymized - 01005097
#│   └── Mrt Body
#│       ├── Diffusion trace tra schnell_ADC - 8
#│       │   ├── IM-2330-0001-0001.dcm
#│       │   ├── IM-2330-0002-0001.dcm
#...
#│       │   ├── IM-2469-0026-0001.dcm
#│       │   └── IM-2469-0027-0001.dcm
#│       ├── Diffusion trace tra schnell_TRACEW - 7
#│       │   ├── IM-2329-0001-0001.dcm
#│       │   ├── IM-2329-0002-0001.dcm
#...
#│       │   ├── IM-2468-0026-0001.dcm
#│       │   └── IM-2468-0027-0001.dcm
#│       ├── T1 mp-rage3d we sag 1mm KM - 13
#│       │   ├── IM-2335-0001-0001.dcm
#│       │   ├── IM-2335-0002-0001.dcm
#...
#│       │   ├── IM-2474-0159-0001.dcm
#│       │   └── IM-2474-0160-0001.dcm
#├── Anonymized - 12345678
#...

blackList = ["auswertung_fmrt",
             "fmri",
             "thorax",
             "lws", "hws", "bws", "ws",
             "hand",
             "posdisp",
             "cor", "sag",
             "cest",
             "ciss",
             "dti",
             "evidence", "reading",
             "field",
             "evaseries",
             "ct",
             "lokalizer", "localizer",
             "mip", "protocol", "resolve", "results", "screen save", "sub", "svs", "tof", "mean_", "leakage", "lunge"]

# Creates a new directory for all the patient folders
pathToCleanMRIList = funcs.createNewPreprocessingStepFolder("0_blacklist")

# Goes through list of files/folders at path_to_folder and only adds the directories to the list
folderList = [
    folder for folder in os.listdir(path_to_folder) if os.path.isdir(os.path.join(path_to_folder, folder))
]

patientIDs = []

sequencesList = []


# Loops through all the "Anonymized - #######" folders
for patient_folder in tqdm(folderList):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue

    # all folders are named like "Anonymized - 12345678"
    patientID = patient_folder.split(" - ")[1]

    # adds the patientID to the list patientIDS if it hasn't been added before
    if patientID not in patientIDs:
        patientIDs.append(patientID)

    path_to_MRI_session_folders = os.path.join(path_to_folder, patient_folder)
    MRI_session_folders = os.listdir(path_to_MRI_session_folders)

    # loops through the different MRI sessions
    for mri_session in MRI_session_folders:
        
        # ignores the ds_folders
        if config.dsStore in mri_session:
            continue

        # get a list of all the sequences in the mri_sequences
        path_to_mri_sequences = os.path.join(path_to_MRI_session_folders, mri_session)
        mri_sequences = os.listdir(path_to_mri_sequences)

        # loops through the different sequences created during each MRI session
        for sequence in mri_sequences:

            # ignores the ds_folders
            if config.dsStore in sequence:
                continue

            sequences_lower_cased = sequence.lower()

            if not any(blackListSeq in sequences_lower_cased for blackListSeq in blackList):

                # create folder for patient
                funcs.createFolderForPatient(
                    path = pathToCleanMRIList,
                    patientID = patientID
                )

                # # create new folder as pathToCleanMRIList/patientID/T1CE
                # path_to_sequence = funcs.createSequenceFolder(
                #     path = os.path.join(pathToCleanMRIList, patientID),
                #     patientID = patientID,
                #     sequence = "",
                #     sequence_list = [],
                #     original_sequence_name = sequence
                # )

                pathToPatient = os.path.join(pathToCleanMRIList, patientID)
                folderName = f"{patientID}_{sequence}"
                path_to_sequence = os.path.join(pathToPatient, folderName)
                # check if path_to_sequence already exists then create directory
                sequences = os.listdir(pathToPatient)
                counter = sequences.count(folderName)
                if counter >= 1:
                    path_to_sequence = f"{path_to_sequence}{counter + 1}"
                    os.mkdir(path_to_sequence)
                else:
                    os.mkdir(path_to_sequence)

                # get list of all the dicom files for the T1CE sequence
                dicomFiles = os.listdir(os.path.join(path_to_mri_sequences, sequence))

                # loops through the list of dicom files
                for dicomFile in dicomFiles:
                    # ignores the ds_folders
                    if config.dsStore in dicomFile:
                        continue

                    # copy each file individually into the path_to_sequence folder
                    shutil.copyfile(os.path.join(path_to_mri_sequences, sequence, dicomFile), os.path.join(path_to_sequence, dicomFile))



#             sequencesList.append(sequences_lower_cased)

# cleanList = list(dict.fromkeys(sorted(sequencesList)))

# minusNumberList = []

# for sequence in cleanList:
#     sequenceWithoutNumber = sequence.split(" - ")[0]
#     minusNumberList.append(sequenceWithoutNumber)

# cleanMinusNumber = list(dict.fromkeys(minusNumberList))









# removedSequences = []

# for sequence in cleanMinusNumber:
#     if not any(backListSequ in sequence for backListSequ in blackList): #and any(whiteListSeq in sequence for whiteListSeq in whiteList):
#         print(sequence)
#     else:
#         removedSequences.append(sequence)

# print(f"\n\nRemoved Sequences: {len(removedSequences)}")
# for removedSequence in removedSequences:
#     print(removedSequence)
# Out:
# 100%|██████████| 29/29 [02:27<00:00,  5.09s/it]

# %% [markdown]
# ### Step 0.5: removes the patients with less than 4 sequences from the previously created folder

# %%
filterFolderList = [
    folder for folder in os.listdir(pathToCleanMRIList) if os.path.isdir(os.path.join(pathToCleanMRIList, folder))
]

# loops through all the "12345678" folders
for patient_folder in tqdm(filterFolderList):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue
    
    path_to_patient = os.path.join(pathToCleanMRIList, patient_folder)

    # list to the mri sessions folders
    mri_sessions = os.listdir(path_to_patient)

    if len(mri_sessions) < 4:
        os.system(f"rm -r {path_to_patient}")
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2496.56it/s]

# %%
#print(pathToCleanMRIList)
pathToCleanMRIList = "/Volumes/BrainMets/Rgb_Brain_Mets/allPatients/Rgb_Brain_Mets_Preprocessing_0_blacklist_20240120-155725"

# %% [markdown]
# ## Step 1: Filters the different Sequences

# %%
pathToPreprocess1 = funcs.createNewPreprocessingStepFolder("01_sequencesFiltered")

T1List = ["t1"]
T2List = ["t2", "flair", "dark"] # consider adding "dark" as "dark-fluid" is the same as flair
T2SternList = ["stern", "hemo", "blutung", "*", "hämo"]
FLAIRList = ["flair", "dark"] # consider adding "dark" as "dark-fluid" is the same as flair
KMList = ["km"]
ADCList = ["adc"]
DWIList = ["diffusion", "diff", "adc", "dwi"]
MPRList = ["mpr"]

# list of patientIDs
folderPreprocess0List = [
    folder for folder in os.listdir(pathToCleanMRIList) if os.path.isdir(os.path.join(pathToCleanMRIList, folder))
]

# list of list of sequences for the DataFrame
dfpatientIDs = [] # list of ints
dfT1_sequences = [] # list of strings
dfT1_amount = [] # list of ints
dfT1CE_sequences = [] # list of strings
dfT1CE_amount = [] # list of ints
dfT2_sequences = [] # list of strings
dfT2_amount = [] # list of ints
dfFLAIR_sequences = [] # list of strings
dfFLAIR_amount = [] # list of ints
dfSTERN_sequences = [] # list of strings
dfSTERN_amount = [] # list of ints
dfDWI_sequences = [] # list of strings
dfDWI_amount = [] # list of ints
dfADC_sequences = [] # list of strings
dfADC_amount = [] # list of ints
dfMPR_sequences = [] # list of strings
dfMPR_amount = [] # list of ints
dfrejected_sequences = [] # list of strings
dfrejected_amount = [] # list of ints
df_has_rejected = [] # list of bools
df_has_duplicates = [] # list of bools

dfPatients = [[]]

# Loops through all the "#######" folders
for patient_folder in tqdm(folderPreprocess0List):

    T1_sequences = []
    T1CE_sequences = []
    T2_sequences = []
    FLAIR_sequences = []
    STERN_sequences = []
    DWI_sequences = []
    ADC_sequences = []
    MPR_sequences = []

    rejected_sequences = []

    has_duplicates = False
    has_rejected = False

    patientID = patient_folder

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue
    
    path_to_patient_sequences = os.path.join(pathToCleanMRIList, patient_folder)
    mri_sequences = os.listdir(path_to_patient_sequences)

    # create new folder for patient in pathToPreprocess1

    # loop through the sequences for each patient
    for sequence in mri_sequences:

        # only get the sequence name, folder names: "12345678_SEQUENCENAME"
        sequence_name = sequence.split("_", 1)[1]
        sequence_lower_cased = sequence_name.lower()

        # create folder for patient
        funcs.createFolderForPatient(
            path = pathToPreprocess1,
            patientID = patientID
        )

        #T1
        if any(t1Sequence in sequence_lower_cased for t1Sequence in T1List):
            # sequence contains "t1" in its name
            # check if it's T1CE or not, if not it's regular t1, if it is then it's a T1CE sequence
            if any(KMSequence in sequence_lower_cased for KMSequence in KMList):
                # it's a T1CE sequence
                # rename like this: {patientID}_T1CE-{sequence}

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.T1CE.value,
                    sequence_list = T1CE_sequences,
                    original_sequence_name = sequence_name)
                
                T1CE_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)

            else:
                # it's a normale T1 Sequence
                # rename like this: {patientID}_T1-{sequence}

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.T1.value,
                    sequence_list = T1_sequences,
                    original_sequence_name = sequence_name)
                
                T1_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)
                
        elif any(t2Sequence in sequence_lower_cased for t2Sequence in T2List):
            # sequence containts "t2" in its name
            # check if it's a FLAIR, a STAR or a regular T2 sequence

            if any(flairSequence in sequence_lower_cased for flairSequence in FLAIRList):
                # it's a FLAIR sequence
                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.FLAIR.value,
                    sequence_list = FLAIR_sequences,
                    original_sequence_name = sequence_name)
                
                FLAIR_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)

            elif any(sternSequence in sequence_lower_cased for sternSequence in T2SternList):
                # it's a STERN sequence

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.STERN.value,
                    sequence_list = STERN_sequences,
                    original_sequence_name = sequence_name)
                
                STERN_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)
                
            else:
                # it's a normale T2 sequence

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.T2.value,
                    sequence_list = T2_sequences,
                    original_sequence_name = sequence_name)
                
                T2_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)
        
        elif any(diffSequence in sequence_lower_cased for diffSequence in DWIList):
            # sequence contains "diffusion" or "dif" in it's name
            
            if any(adcSequence in sequence_lower_cased for adcSequence in ADCList):
                # it's a adc sequence

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.ADC.value,
                    sequence_list = ADC_sequences,
                    original_sequence_name = sequence_name)
                
                ADC_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)
                
            else:
                # it's a normal dif sequence

                # create new folder in preprocessing1/patientID/folder name above
                path_to_sequence = funcs.createSequenceFolder(
                    path = f"{pathToPreprocess1}/{patientID}",
                    patientID =  patientID,
                    sequence = config.desiredSequences.DWI.value,
                    sequence_list = DWI_sequences,
                    original_sequence_name = sequence_name)
                
                DWI_sequences.append(sequence_name)

                # copy files to new folder
                funcs.copyFilesFromDirectoryToNewDirectory(
                    path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                    path_to_new_directory = path_to_sequence)

        elif any(mprsequence in sequence_lower_cased for mprsequence in MPRList):
            # it's a mpr sequence

            # create new folder in preprocessing1/patientID/folder name above
            path_to_sequence = funcs.createSequenceFolder(
                path = f"{pathToPreprocess1}/{patientID}",
                patientID =  patientID,
                sequence = config.desiredSequences.MPR.value,
                sequence_list = MPR_sequences,
                original_sequence_name = sequence_name)
                
            MPR_sequences.append(sequence_name)

            # copy files to new folder
            funcs.copyFilesFromDirectoryToNewDirectory(
                path_to_original_directory =  os.path.join(path_to_patient_sequences, sequence),
                path_to_new_directory = path_to_sequence)

        else:
            # file got rejected
            rejected_sequences.append(sequence_name)
    

    # code for the dataframe goes here
            
    list_of_sequences = [T1_sequences, T1CE_sequences, T2_sequences, FLAIR_sequences, STERN_sequences, DWI_sequences, ADC_sequences, MPR_sequences]
    
    dfpatientIDs.append(patientID)

    dfT1_sequences.append(T1_sequences)
    dfT1_amount.append(len(T1_sequences))

    dfT1CE_sequences.append(T1CE_sequences)
    dfT1CE_amount.append(len(T1CE_sequences))

    dfT2_sequences.append(T2_sequences)
    dfT2_amount.append(len(T2_sequences))

    dfFLAIR_sequences.append(FLAIR_sequences)
    dfFLAIR_amount.append(len(FLAIR_sequences))

    dfSTERN_sequences.append(STERN_sequences)
    dfSTERN_amount.append(len(STERN_sequences))

    dfDWI_sequences.append(DWI_sequences)
    dfDWI_amount.append(len(DWI_sequences))

    dfADC_sequences.append(ADC_sequences)
    dfADC_amount.append(len(ADC_sequences))

    dfMPR_sequences.append(MPR_sequences)
    dfMPR_amount.append(len(MPR_sequences))

    dfrejected_sequences.append(rejected_sequences)
    dfrejected_amount.append(len(rejected_sequences))

    # has duplicates
    for sequenceList in list_of_sequences:
        if len(sequenceList) > 1:
            has_duplicates = True

    df_has_duplicates.append(has_duplicates)

    # has rejected
    if rejected_sequences:
        has_rejected = True
    
    df_has_rejected.append(has_rejected)

    #dfPatients.append([len(T1_sequences), T1_sequences, len(T1CE_sequences), T1CE_sequences, len(T2_sequences), T2_sequences, len(FLAIR_sequences), FLAIR_sequences, len(STERN_sequences), STERN_sequences, len(DWI_sequences), DWI_sequences, len(ADC_sequences), ADC_sequences, len(rejected_sequences), rejected_sequences, has_rejected, has_duplicates])
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# 100%|██████████| 29/29 [01:44<00:00,  3.60s/it]

# %% [markdown]
# #### Creates a Dataframe for the patients

# %%
# create patient Dataframe

patientsDataFrame = pd.DataFrame(list(zip(
             dfT1_amount,
             dfT1_sequences,
             dfT1CE_amount,
             dfT1CE_sequences,
             dfT2_amount,
             dfT2_sequences,
             dfFLAIR_amount,
             dfFLAIR_sequences,
             dfSTERN_amount,
             dfSTERN_sequences,
             dfDWI_amount,
             dfDWI_sequences,
             dfADC_amount,
             dfADC_sequences,
             dfMPR_amount,
             dfMPR_sequences,
             dfrejected_amount,
             dfrejected_sequences,
             df_has_rejected,
             df_has_duplicates)),
    columns = ["T1 amount",
               "T1 sequences",
               "T1CE amount",
               "T1CE sequences",
               "T2 amount",
               "T2 sequences",
               "FLAIR amount",
               "FLAIR sequences",
               "STERN amount",
               "STERN sequences",
               "DWI amount",
               "DWI sequences",
               "ADC amount",
               "ADC seqeunces",
               "MPR amount",
               "MPR sequences",
               "rejected amount",
               "rejected sequences",
               "has rejected",
               "has duplicates"],
    index = dfpatientIDs)

# %% [markdown]
# saves the Dataframe as a .csv file

# %%
patientsDataFrame.to_csv(f"{config.path_to_revision}/patientsDataframe.csv")
#patientsDataFrame.to_csv(f"{config.path_to_ssd}/patientsDataframe.csv")

# %% [markdown]
# get the Dataframe from the .csv file

# %%
patientsDataFrame = pd.read_csv(f"{config.path_to_ssd}/patientsDataframe.csv")

# %% [markdown]
# Display statistics about the patients dataframe

# %%
# To-Do:
# get amount of patients with T1, T1CE, T2, FLAIR sequences
# get amount of patients with T1, T1CE, T2, FLAIR + STERN sequences
# get amount of patients with T1, T1CE, T2, FLAIR + STERN + DWI + ADC sequences
# get patient IDs of patients with duplicates
# get patient IDs of patients with rejections
# check rejected files

# get amount of patients with T1, T1CE, T2, FLAIR sequences
patient4Seq = patientsDataFrame.query("`T1 amount` > 0 and `T1CE amount` > 0 and `T2 amount` > 0 and `FLAIR amount` > 0")
patientCount4Seq = len(patient4Seq)
print(f"Amount of patients with 4 sequences: {patientCount4Seq}")

# get amount of patients with T1, T1CE, T2, FLAIR + STERN sequences
patientCount5Seq = len(patientsDataFrame.query("`T1 amount` > 0 and `T1CE amount` > 0 and `T2 amount` > 0 and `FLAIR amount` > 0 and `STERN amount` > 0"))
print(f"Amount of patients with the 4 sequences + STERN: {patientCount5Seq}")

# get amount of patients with T1, T1CE, T2, FLAIR + DWI + ADC sequences
patientCount6Seq = len(patientsDataFrame.query("`T1 amount` > 0 and `T1CE amount` > 0 and `T2 amount` > 0 and `FLAIR amount` > 0 and `DWI amount` > 0 and `ADC amount` > 0"))
print(f"Amount of patients with the 4 sequences + DWI + ADC: {patientCount6Seq}")

# get amount of patients with T1, T1CE, T2, FLAIR + STERN + DWI + ADC sequences
patientCount7Seq = len(patientsDataFrame.query("`T1 amount` > 0 and `T1CE amount` > 0 and `T2 amount` > 0 and `FLAIR amount` > 0 and `STERN amount` > 0 and `DWI amount` > 0 and `ADC amount` > 0"))
print(f"Amount of patients with the 4 sequences + STERN + DWI + ADC: {patientCount7Seq}")

# get patient IDs of patients with duplicates
patientIDsWithDuplicates = patientsDataFrame[patientsDataFrame["has duplicates"] == True].index
print(f"List of patientIDs that have duplicates (#{len(patientIDsWithDuplicates)})")
for patientID in patientIDsWithDuplicates:
    print(patientID)


# get patient IDs of patients with rejections
patientIDsWithRejectedSequences = patientsDataFrame[patientsDataFrame["has rejected"] == True].index
print(f"List of patientIDs that have rejected Sequences (#{len(patientIDsWithRejectedSequences)})")
for patientID in patientIDsWithRejectedSequences:
    print(patientID)
# Out:
# Amount of patients with 4 sequences: 25
# Amount of patients with the 4 sequences + STERN: 13
# Amount of patients with the 4 sequences + DWI + ADC: 23
# Amount of patients with the 4 sequences + STERN + DWI + ADC: 13
# List of patientIDs that have duplicates (#24)
# 01405609
# 01773716
# 01878754
# 02110064
# 01969755
# 01798755
# 02036130
# 01781732
# 01592849
# 01549022
# 01983705
# 01349100
# 02015335
# 01231700
# 02145870
# 02126982
# 01288036
# 01947074
# 02119712
# 01804484
# 01914558
# 01812578
# 02132336
# 01854308
# List of patientIDs that have rejected Sequences (#8)
# 01961554
# 01781732
# 01983705
# 02015335
# 02126982
# 01288036
# 02119712
# 01914558

# %% [markdown]
# ## Step 2: Remove " " from the folder names as dicom2niix doesn't seam to work with spaces in the folder name

# %%
# To-Do:
# go through each patient folder and replace " " with "+"


#path_to_filtered_patient_files = os.path.join(config.path_to_n30, "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-171818")
path_to_filtered_patient_files = pathToPreprocess1

patient_folders = [
    folder for folder in os.listdir(path_to_filtered_patient_files) if os.path.isdir(os.path.join(path_to_filtered_patient_files, folder))
]

for patient_folder in tqdm(patient_folders):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue

    patientID = patient_folder

    path_to_patient = os.path.join(path_to_filtered_patient_files, patient_folder)

    # get the different sequence folders for each patient
    sequences = [
        folder for folder in os.listdir(path_to_patient) if os.path.isdir(os.path.join(path_to_patient, folder))
    ]

    for sequence in sequences:

        # ignores the ds_folders
        if config.dsStore in sequence:
            continue

        newFolderName = sequence.replace(" ", "+")
        os.rename(os.path.join(path_to_patient, sequence), os.path.join(path_to_patient, newFolderName))
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 70.41it/s]

# %% [markdown]
# ## Number comparison between the first search and the second search
#
# First Search:
# - Amount of patients with 4 sequences: 282
# - Amount of patients with the 4 sequences + STERN: **199**
# - Amount of patients with the 4 sequences + DWI + ADC: 273
# - Amount of patients with the 4 sequences + STERN + DWI + ADC: **197**
# - List of patientIDs that have duplicates (#**67**)
#
# Second Search:
# - Amount of patients with 4 sequences: 282
# - Amount of patients with the 4 sequences + STERN: **205**
# - Amount of patients with the 4 sequences + DWI + ADC: 273
# - Amount of patients with the 4 sequences + STERN + DWI + ADC: **202**
# - List of patientIDs that have duplicates (#**63**)
# - List of patientIDs that have rejected Sequences (#80)

# %% [markdown]
# To-Do:
# 1. [ ] Create two Dataframes and compare them with eachother
# 2. [ ] Report to Quirin
# 3. [ ] Go to Preprocessing

# %%
path_to_1st_DF = "/Volumes/BrainMets/Rgb_Brain_Mets/allPatients/patientsDataframe0.csv"
path_to_1st_modified_Data = "/Volumes/BrainMets/Rgb_Brain_Mets/allPatients/Rgb_Brain_Mets_Preprocessing1_20240111-215606"
path_to_2nd_DF = "/Volumes/BrainMets/Rgb_Brain_Mets/allPatients/patientsDataframe.csv"

# %%
first_DF = pd.read_csv(path_to_1st_DF)
second_DF = pd.read_csv(path_to_2nd_DF)

# %% [markdown]
# Create a Dataframe based on the patient files

# %%
patient_folders = [
    folder for folder in os.listdir(path_to_1st_modified_Data) if os.path.isdir(os.path.join(path_to_1st_modified_Data, folder))
]

patientIDList = []
patientsLists = [[]]

for patient_folder in tqdm(patient_folders):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue

    T1_sequences = []
    T1_amount = []
    T1CE_sequences = []
    T1CE_amount = []
    T2_sequences = []
    T2_amount = []
    FLAIR_sequences = []
    FLAIR_amount = []
    STERN_sequences = []
    STERN_amount = []
    DWI_sequences = []
    DWI_amount = []
    ADC_sequences = []
    ADC_amount = []
    MPR_sequences = []
    MPR_amount = []

    has_duplicates = False

    # cannot read the rejected sequences as they're not in the folders

    patientID = patient_folder

    path_to_patient_sequences = os.path.join(path_to_1st_modified_Data, patient_folder)
    mri_sequences = os.listdir(path_to_patient_sequences)

    for sequence in mri_sequences:

        if config.dsStore in sequence:
            continue

        # each sequences is written like this "{patientID}_{sequenceType}_{amountOfSequence}_{NameOfSequence}"

        sequenceType = sequence.split("_")[1] # like T1, T1CE, T2...
        sequenceName = sequence.split("_", 3)[3]
        #print(f"{sequenceType}: {sequenceName}")

        if sequenceType == config.desiredSequences.T1.value:
            # T1
            T1_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.T1CE.value:
            # T1CE
            T1CE_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.T2.value:
            # T2
            T2_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.FLAIR.value:
            # FLAIR
            FLAIR_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.STERN.value:
            # STERN
            STERN_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.DWI.value:
            # DWI
            DWI_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.ADC.value:
            # ADC
            ADC_sequences.append(sequenceName)
        elif sequenceType == config.desiredSequences.MPR.value:
            # MPR
            MPR_sequences.append(sequenceName)
        else:
            print(f"Error: couldn't match sequence name {sequenceName} to sequence type")
    
    patientIDList.append(patientID)

    T1_amount = len(T1_sequences)
    T1CE_amount = len(T1CE_sequences)
    T2_amount = len(T2_sequences)
    FLAIR_amount = len(FLAIR_sequences)
    STERN_amount = len(STERN_sequences)
    DWI_amount = len(DWI_sequences)
    ADC_amount = len(ADC_sequences)
    MPR_amount = len(MPR_sequences)

    for sequenceAmounts in [T1_amount, T1CE_amount, T2_amount, FLAIR_amount, STERN_amount, DWI_amount, ADC_amount, MPR_amount]:
        if sequenceAmounts > 1:
            has_duplicates = True

    patientsLists.append([T1_amount, T1_sequences,
                          T1CE_amount, T1CE_sequences,
                          T2_amount, T2_sequences,
                          FLAIR_amount, FLAIR_sequences,
                          STERN_amount, STERN_sequences,
                          DWI_amount, DWI_sequences,
                          ADC_amount, ADC_sequences,
                          MPR_amount, MPR_sequences,
                          has_duplicates])

patientsLists.pop(0)

first_modified_data_DF = pd.DataFrame(patientsLists,
                                      columns = ["T1 amount", "T1 sequences",
                                                 "T1CE amount", "T1CE sequences",
                                                 "T2 amount", "T2 sequences",
                                                 "FLAIR amount", "FLAIR sequences",
                                                 "STERN amount", "STERN sequences",
                                                 "DWI amount", "DWI sequences",
                                                 "ADC amount", "ADC sequences",
                                                 "MPR amount", "MPR sequences",
                                                 "has duplicates"],
                                       index = patientIDList)
# Out:
# 100%|██████████| 321/321 [00:00<00:00, 5819.20it/s]

# %% [markdown]
# ## Step 3: Compare list of patients from the excel sheet with the list of patients that have the right MRI sequences
# - get list of excel patients
# - get list of mri patients
# - patients that exist in both lists should be copied to new directory, this is basically the dataset that can be publicized (don't forget the duplicate sequences though)
# - from that new directory get patients that have T1, T1CE, T2 and FLAIR sequences
# - run preprocessing on those

# %%
# get list of excel patients
#path_to_patients_csv = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/patientsIDsexbirthdateprimary.csv"
path_to_patients_csv = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/patientsIDsexbirthdateprimary_01_08_24.csv"
excel_patients = pd.read_csv(path_to_patients_csv)

excel_patients_ids = excel_patients["ID"].values.astype(int)

# %% [markdown]
# copy patients that are both in the excel sheet and also in the directory in new directory

# %%
# get list of mri patients
path_to_mri_sequences = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_revision/Rgb_Brain_Mets_Preprocessing_manually_selected"

path_to_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM"

patientFolders = [
    folder for folder in os.listdir(path_to_mri_sequences) if os.path.isdir(os.path.join(path_to_mri_sequences, folder))
]

list_of_mri_patient_ids: [int] = []

list_of_fit_patients: [config.patient] = [] # patient is both in mri list and in excel list
list_of_unfit_patient_ids: [int] = [] # patient is not in excel list

for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    patientID = int(patientFolder)
    list_of_mri_patient_ids.append(patientID)

    if patientID in excel_patients_ids:
        # hurray, mri patient is also in the excel patient list

        # To-do:
        # create patient directory
        # create directory for the sequences, maybe store those sequences in a list, to check them out later
        # copy all files into each sequence directory for patient

        patient = config.patient(id = patientID)
        list_of_fit_patients.append(patient)
        
        # creates new folder for patient in the dataset directory
        funcs.createFolderForPatient(path_to_dataset, patientFolder)

        # get list of all sequence names, copy each sequence into new directory
        list_of_sequences = [
            sequenceFolder for sequenceFolder in os.listdir(os.path.join(path_to_mri_sequences, patientFolder)) if os.path.isdir(os.path.join(path_to_mri_sequences, patientFolder, sequenceFolder))
        ]

        for sequenceFolder in list_of_sequences:

            sequenceUnknown = False
            
            # ignores the ds_folders
            if config.dsStore in sequenceFolder:
                continue
            
            # get sequence type from sequenceFolder name
            # e.g. {patientID}_{sequenceType}_{sequenceCount}_{sequenceName}
            sequenceType = sequenceFolder.split("_")[1]
            sequenceName = sequenceFolder.split("_", 3)[3] # this contains "+" instead of " "(space)

            if sequenceType == config.desiredSequences.T1.value:
                
                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.T1.value,
                    sequence_list = patient.T1_sequences,
                    original_sequence_name = sequenceName
                )

                patient.T1_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.T1CE.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.T1CE.value,
                    sequence_list = patient.T1CE_sequences,
                    original_sequence_name = sequenceName
                )

                patient.T1CE_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.T2.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.T2.value,
                    sequence_list = patient.T2_sequences,
                    original_sequence_name = sequenceName
                )

                patient.T2_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.FLAIR.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.FLAIR.value,
                    sequence_list = patient.FLAIR_sequences,
                    original_sequence_name = sequenceName
                )

                patient.FLAIR_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.STERN.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.STERN.value,
                    sequence_list = patient.STERN_sequences,
                    original_sequence_name = sequenceName
                )

                patient.STERN_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.DWI.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.DWI.value,
                    sequence_list = patient.DWI_sequences,
                    original_sequence_name = sequenceName
                )

                patient.DWI_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.ADC.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.ADC.value,
                    sequence_list = patient.ADC_sequences,
                    original_sequence_name = sequenceName
                )

                patient.ADC_sequences.append(sequenceName)

            elif sequenceType == config.desiredSequences.MPR.value:

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = config.desiredSequences.MPR.value,
                    sequence_list = patient.MPR_sequences,
                    original_sequence_name = sequenceName
                )

                patient.MPR_sequences.append(sequenceName)

            else:
                print(f"{patientFolder}:sequence description ({sequenceType}) unknown")
                sequenceUnknown = True

                path_to_sequence_folder = funcs.createSequenceFolder(
                    path = os.path.join(path_to_dataset, patientFolder),
                    patientID = patientFolder,
                    sequence = sequenceType,
                    sequence_list = [],
                    original_sequence_name = sequenceName
                )

            funcs.copyFilesFromDirectoryToNewDirectory(
                path_to_original_directory = os.path.join(path_to_mri_sequences, patientFolder, sequenceFolder),
                path_to_new_directory = path_to_sequence_folder
            )

        patient.T1_amount = len(patient.T1_sequences)
        patient.T1CE_amount = len(patient.T1CE_sequences)
        patient.T2_amount = len(patient.T2_sequences)
        patient.FLAIR_amount = len(patient.FLAIR_sequences)
        patient.STERN_amount = len(patient.STERN_sequences)
        patient.ADC_amount = len(patient.ADC_sequences)
        patient.DWI_amount = len(patient.DWI_sequences)
        patient.MPR_amount = len(patient.MPR_sequences)

        list_of_fit_patients.append(patient)

    else:
        list_of_unfit_patient_ids.append(patientID)
# Out:
# 100%|██████████| 29/29 [00:30<00:00,  1.05s/it]

# %%
# To-Do
# check duplicate patients
# extract dicom infos, especially date of images
# save .csv file with patient age, sex, primary
# turn into nifti
# get all the patients with T1, T1CE, T2, FLAIR

# %% [markdown]
# ## Step 4: Create a dataset with the patientID, age, sex and primary

# %%
# create .csv file with patient id, age, sex, primary

# get list of excel patients
#path_to_patients_csv = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/patientsIDsexbirthdateprimary.csv"
path_to_patients_csv = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/patientsIDsexbirthdateprimary_01_08_24.csv"
excel_patients = pd.read_csv(path_to_patients_csv)

# get list of patient IDs
excel_patients_ids = excel_patients["ID"].values.astype(int)

path_to_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM"

# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_dataset) if os.path.isdir(os.path.join(path_to_dataset, folder))
]

# dict that holds the patient id and the date of the mri
mri_date_dict = {}

# loop through the patients
for patientFolder in patientFolders:

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    patientID = int(patientFolder)

    final_mri_date = ""

    # get list of all .txt files
    list_of_txt_files = [
        txt_file for txt_file in os.listdir(os.path.join(path_to_dataset, patientFolder)) if ".txt" in txt_file
    ]

    list_of_mri_dates = []

    # loop through all the .txt files (so all the dicom metadata files)
    for txt_file in list_of_txt_files:

        # get content of metadata file
        try:
            file = open(os.path.join(path_to_dataset, patientFolder, txt_file), "r").readlines()
        except:
            print(f"can't open file at {path_to_dataset} {patientFolder} {txt_file}")
        # get date of mri, format: yyyymmdd

        # extract the date of the mri
        try:
            date_string = ([line for line in file if "(0008, 0012) Instance Creation Date              DA: \'" in line][0].split("(0008, 0012) Instance Creation Date              DA: \'")[1]).split("\'")[0]
        except:
            try:
                date_string = ([line for line in file if "(0008, 0020) Study Date                          DA: \'" in line][0].split("(0008, 0020) Study Date                          DA: \'")[1]).split("\'")[0]
            except:
                date_string = "empty"
            
        list_of_mri_dates.append(date_string)

    # no mri dates for the patient were found
    if not list_of_mri_dates:
        print("is empty!")
        print(patientFolder)

    # returns true if all the dates in the list_of_mri_dates are the same
    if all(x==list_of_mri_dates[0] for x in list_of_mri_dates):
        
        # append the date to the dict
        final_mri_date = list_of_mri_dates[0]
        mri_date_dict[float(patientID)] = final_mri_date

    else:
        print(patientFolder)
        print(list_of_mri_dates)

# drop unnecessary columns
excel_patients = excel_patients.drop(columns=["on_server", "Unnamed: 0", "in_study (0 = no, 1 = yes, 2 = tbd, 3 = remarkable)"])

# add a new column "mri_date" based on the mri_date_dict
excel_patients["mri_date"] = excel_patients["ID"].map(mri_date_dict)

# convert strings to datetime
excel_patients["mri_date"] = pd.to_datetime(excel_patients["mri_date"])
excel_patients["birthdate"] = pd.to_datetime(excel_patients["birthdate"])

# remove possibly empty columns
dataset_patients = excel_patients.loc[excel_patients.mri_date.isna() == False]

# get only unique columns (some patients are listed multiple times, I really don't know why)
dataset_patients = dataset_patients.drop_duplicates(subset=['ID'], keep='first')

# create a dict with patientID : age
age_dict = {}
for index, row in dataset_patients.iterrows():
    id = row["ID"]
    # calculate the age of the patient when the mri was recorded
    age = relativedelta(row["mri_date"], row["birthdate"]).years
    age_dict[id] = age

# add new age column
dataset_patients["age"] = dataset_patients["ID"].map(age_dict)

# remove mri_date and birthdate columns to perserve anonymity
dataset_patients = dataset_patients.drop(columns=["mri_date", "birthdate"])

# export dataset
dataset_patients.to_csv("/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/_patientData.tsv", index=False, sep="\t")
# Out:
# can't open file at /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM 01231700 ._01231700_T1_T1+se+tra+-+6_metadata.txt
# can't open file at /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM 01231700 ._01231700_T1CE_T1+se+tra+KM+-+7_metadata.txt

# %%
# turn sequences to niftis, with new name {patientID}_{sequenceType}, unless there are multiple instances of one sequence or the sequencetype is unknown (3DT1CE)

def convert_dicom_to_nifti (path_to_sequence_folder: str, path_to_output_directory: str, new_filename: str):
    
    converter = Dcm2niix()
    converter.inputs.source_dir = path_to_sequence_folder
    converter.inputs.compress = "y" # uses compression, "y" = yes
    converter.inputs.merge_imgs = True
    converter.inputs.bids_format = True
    converter.inputs.out_filename = new_filename
    converter.inputs.output_dir = path_to_output_directory
    converter.run()
    #print(f"converting: {path_to_sequence_folder}, {path_to_output_directory}, {new_filename} \n")


path_to_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision"

# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_dataset) if os.path.isdir(os.path.join(path_to_dataset, folder))
]

# loop through the patients
for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    patientID = int(patientFolder)

    patient = config.patient(id = patientID)

    # get list of sequences
    list_of_sequences = [
        sequenceFolder for sequenceFolder in os.listdir(os.path.join(path_to_dataset, patientFolder)) if os.path.isdir(os.path.join(path_to_dataset, patientFolder, sequenceFolder))
    ]

    # add all the sequences to the patient object, to check amount of sequences and thus decide wether to rename file or not
    for sequence in list_of_sequences:

        # ignores the ds_folders
        if config.dsStore in sequence:
            continue

        # get type of sequence and sequence name and add to patient
        sequence_type = sequence.split("_")[1]
        sequence_name = sequence.split("_", 3)[3]

        match sequence_type:
            case config.desiredSequences.T1.value:
                patient.T1_sequences.append(sequence_name)

            case config.desiredSequences.T1CE.value:
                patient.T1CE_sequences.append(sequence_name)

            case config.desiredSequences.T2.value:
                patient.T2_sequences.append(sequence_name)

            case config.desiredSequences.FLAIR.value:
                patient.FLAIR_sequences.append(sequence_name)

            case config.desiredSequences.STERN.value:
                patient.STERN_sequences.append(sequence_name)

            case config.desiredSequences.DWI.value:
                patient.DWI_sequences.append(sequence_name)

            case config.desiredSequences.ADC.value:
                patient.ADC_sequences.append(sequence_name)

            case config.desiredSequences.MPR.value:
                patient.MPR_sequences.append(sequence_name)

            case _:
                print(f"other sequence: {sequence}")
                patient.other_sequences.append(sequence.split("_", 1)[1])

    for sequence in list_of_sequences:

        # ignores the ds_folders
        if config.dsStore in sequence:
            continue

        # get type of sequence and sequence name and add to patient
        sequence_type = sequence.split("_")[1]
        sequence_name = sequence.split("_", 3)[3]

        path_to_output_directory = os.path.join(path_to_dataset, patientFolder)
        path_to_sequence_folder = os.path.join(path_to_dataset, patientFolder, sequence)

        match sequence_type:
            case config.desiredSequences.T1.value:
                
                if len(patient.T1_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_T1"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_T1_{sequence_name}"

            case config.desiredSequences.T1CE.value:

                if len(patient.T1CE_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_T1CE"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_T1CE_{sequence_name}"

            case config.desiredSequences.T2.value:

                if len(patient.T2_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_T2"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_T2_{sequence_name}"

            case config.desiredSequences.FLAIR.value:

                if len(patient.FLAIR_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_FLAIR"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_FLAIR_{sequence_name}"

            case config.desiredSequences.STERN.value:

                if len(patient.STERN_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_STERN"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_STERN_{sequence_name}"

            case config.desiredSequences.DWI.value:

                if len(patient.DWI_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_DWI"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_DWI_{sequence_name}"

            case config.desiredSequences.ADC.value:

                if len(patient.ADC_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_ADC"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_ADC_{sequence_name}"

            case config.desiredSequences.MPR.value:

                if len(patient.MPR_sequences) == 1:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}.nii.gz
                    new_filename = f"{patientID}_MPR"
                    
                else:
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    new_filename = f"{patientID}_MPR_{sequence_name}"
            case _:
                    
                    # turn dicom folder into nifti and rename such as {patientID}_{T1}_{sequenceName}.nii.gz
                    sequence_type_and_name = sequence.split("_", 1)[1]
                    new_filename = f"{patientID}_{sequence_type_and_name}"
            
        convert_dicom_to_nifti(
            path_to_sequence_folder = path_to_sequence_folder,
            path_to_output_directory = path_to_output_directory,
            new_filename =  new_filename)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# 240208-12:46:22,844 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.844870:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:22,845 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.844870:Found 26 DICOM file(s)
# 240208-12:46:22,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.844870:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:22,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.844870:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:22,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.844870:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_FLAIR (320x320x26x1)
# 240208-12:46:22,959 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.959473:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_FLAIR.nii"
# 240208-12:46:22,959 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:22.959473:Conversion required 0.196522 seconds (0.017179 for core code).
# 240208-12:46:23,116 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.116149:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:23,116 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.116149:Found 26 DICOM file(s)
# 240208-12:46:23,117 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.116149:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:23,117 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.116149:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:23,117 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.116149:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T1CE (224x320x26x1)
# 240208-12:46:23,184 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.184263:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T1CE.nii"
# 240208-12:46:23,184 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.184263:Conversion required 0.139723 seconds (0.014937 for core code).
# 240208-12:46:23,356 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.356155:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:23,356 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.356155:Found 26 DICOM file(s)
# 240208-12:46:23,357 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.356155:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:23,357 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.356155:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:23,357 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.356155:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T2 (384x384x26x1)
# 240208-12:46:23,454 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.454270:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T2.nii"
# 240208-12:46:23,454 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.454270:Conversion required 0.175060 seconds (0.016367 for core code).
# 240208-12:46:23,618 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.618481:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:23,619 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.618481:Found 26 DICOM file(s)
# 240208-12:46:23,619 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.618481:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:23,619 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.618481:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:23,620 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.618481:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T1 (224x320x26x1)
# 240208-12:46:23,685 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.685703:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_T1.nii"
# 240208-12:46:23,686 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.685703:Conversion required 0.131727 seconds (0.014454 for core code).
# 240208-12:46:23,835 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:23,835 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Found 26 DICOM file(s)
# 240208-12:46:23,835 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:23,836 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:23,836 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:23,836 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.835008:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_ADC (192x192x26x1)
# 240208-12:46:23,860 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.860071:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_ADC.nii"
# 240208-12:46:23,860 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:23.860071:Conversion required 0.092134 seconds (0.011449 for core code).
# 240208-12:46:24,123 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:24,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Found 78 DICOM file(s)
# 240208-12:46:24,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Warning: Discrepancy between reported (4.9s) and estimated (3.68969s) repetition time (issue 560).
# 240208-12:46:24,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:24,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:24,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.123832:Convert 78 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_DWI (192x192x26x3)
# 240208-12:46:24,203 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.203152:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01405609/1405609_DWI.nii"
# 240208-12:46:24,203 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.203152:Conversion required 0.259279 seconds (0.026420 for core code).
#   3%|▎         | 1/29 [00:03<01:32,  3.29s/it]
# 240208-12:46:24,389 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.389634:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:24,390 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.389634:Found 27 DICOM file(s)
# 240208-12:46:24,390 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.389634:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:24,390 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.389634:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:24,390 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.389634:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T2 (384x384x27x1)
# 240208-12:46:24,487 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.487618:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T2.nii"
# 240208-12:46:24,487 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.487618:Conversion required 0.194634 seconds (0.018325 for core code).
# 240208-12:46:24,657 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.657765:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:24,658 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.657765:Found 27 DICOM file(s)
# 240208-12:46:24,658 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.657765:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:24,658 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.657765:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:24,659 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.657765:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T1 (256x256x27x1)
# 240208-12:46:24,729 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.729459:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T1.nii"
# 240208-12:46:24,729 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.729459:Conversion required 0.158101 seconds (0.016214 for core code).
# 240208-12:46:24,896 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.896903:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:24,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.896903:Found 27 DICOM file(s)
# 240208-12:46:24,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.896903:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:24,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.896903:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:24,898 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.896903:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_STERN (216x256x27x1)
# 240208-12:46:24,961 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.961477:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_STERN.nii"
# 240208-12:46:24,961 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:24.961477:Conversion required 0.150602 seconds (0.015479 for core code).
# 240208-12:46:25,123 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.123409:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:25,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.123409:Found 27 DICOM file(s)
# 240208-12:46:25,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.123409:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:25,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.123409:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:25,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.123409:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_FLAIR (208x256x27x1)
# 240208-12:46:25,189 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.189832:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_FLAIR.nii"
# 240208-12:46:25,190 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.189832:Conversion required 0.137396 seconds (0.016291 for core code).
# 240208-12:46:25,355 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.355893:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:25,356 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.355893:Found 27 DICOM file(s)
# 240208-12:46:25,356 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.355893:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:25,356 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.355893:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:25,357 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.355893:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T1CE (256x256x27x1)
# 240208-12:46:25,421 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.421549:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_T1CE.nii"
# 240208-12:46:25,421 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.421549:Conversion required 0.147454 seconds (0.016020 for core code).
# 240208-12:46:25,585 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:25,586 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Found 27 DICOM file(s)
# 240208-12:46:25,586 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:25,586 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:25,586 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:25,587 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:25,587 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.585787:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_DWI (192x192x27x1)
# 240208-12:46:25,645 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.645528:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_DWI.nii"
# 240208-12:46:25,645 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.645528:Conversion required 0.141935 seconds (0.014614 for core code).
# 240208-12:46:25,804 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:25,805 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Found 27 DICOM file(s)
# 240208-12:46:25,805 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:25,805 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:25,805 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:25,805 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:25,806 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.804600:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_ADC (192x192x27x1)
# 240208-12:46:25,835 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.835807:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01056598/1056598_ADC.nii"
# 240208-12:46:25,836 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:25.835807:Conversion required 0.108677 seconds (0.014518 for core code).
#   7%|▋         | 2/29 [00:04<01:02,  2.32s/it]
# 240208-12:46:26,14 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.014764:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:26,15 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.014764:Found 27 DICOM file(s)
# 240208-12:46:26,15 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.014764:Warning: Slice timing appears corrupted (range 4515..4515, TR=4690 ms)
# 240208-12:46:26,15 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.014764:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:26,16 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.014764:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T2 (320x320x27x1)
# 240208-12:46:26,95 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.095067:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T2.nii"
# 240208-12:46:26,95 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.095067:Conversion required 0.166894 seconds (0.020420 for core code).
# 240208-12:46:26,244 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.244152:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:26,244 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.244152:Found 27 DICOM file(s)
# 240208-12:46:26,245 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.244152:Warning: Slice timing appears corrupted (range 480..480, TR=500 ms)
# 240208-12:46:26,245 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.244152:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:26,245 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.244152:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T1 (224x256x27x1)
# 240208-12:46:26,308 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.308694:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T1.nii"
# 240208-12:46:26,309 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.308694:Conversion required 0.127310 seconds (0.016460 for core code).
# 240208-12:46:26,464 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.464139:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:26,464 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.464139:Found 27 DICOM file(s)
# 240208-12:46:26,465 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.464139:Warning: Slice timing appears corrupted (range 897.5..897.5, TR=933 ms)
# 240208-12:46:26,465 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.464139:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:26,465 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.464139:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_STERN (224x256x27x1)
# 240208-12:46:26,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.527714:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_STERN.nii"
# 240208-12:46:26,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.527714:Conversion required 0.136913 seconds (0.016592 for core code).
# 240208-12:46:26,683 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.683745:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:26,684 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.683745:Found 27 DICOM file(s)
# 240208-12:46:26,684 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.683745:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240208-12:46:26,684 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.683745:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:26,685 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.683745:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T1CE (224x256x27x1)
# 240208-12:46:26,749 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.749756:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_T1CE.nii"
# 240208-12:46:26,750 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.749756:Conversion required 0.134760 seconds (0.016789 for core code).
# 240208-12:46:26,926 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:26,927 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Found 27 DICOM file(s)
# 240208-12:46:26,927 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/01773716_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0025-0001-0001.dcm
# 240208-12:46:26,927 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:46:26,927 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:26,927 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:26,928 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:26,928 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:26.926337:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_DWI (384x384x27x1)
# 240208-12:46:27,12 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.012278:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_DWI.nii"
# 240208-12:46:27,12 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.012278:Conversion required 0.178769 seconds (0.019716 for core code).
# 240208-12:46:27,169 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.169651:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:27,170 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.169651:Found 27 DICOM file(s)
# 240208-12:46:27,170 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.169651:Warning: Slice timing appears corrupted (range 67677.5..67677.5, TR=8000 ms)
# 240208-12:46:27,170 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.169651:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:27,170 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.169651:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_FLAIR (224x256x27x1)
# 240208-12:46:27,240 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.240144:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_FLAIR.nii"
# 240208-12:46:27,240 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.240144:Conversion required 0.144373 seconds (0.016944 for core code).
# 240208-12:46:27,413 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:27,413 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Found 27 DICOM file(s)
# 240208-12:46:27,414 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/01773716_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0026-0001-0001.dcm
# 240208-12:46:27,414 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:46:27,414 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:27,414 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.413215:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_ADC (384x384x27x1)
# 240208-12:46:27,463 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.463556:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01773716/1773716_ADC.nii"
# 240208-12:46:27,463 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.463556:Conversion required 0.140334 seconds (0.020351 for core code).
#  10%|█         | 3/29 [00:06<00:52,  2.00s/it]
# 240208-12:46:27,640 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.640799:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:27,641 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.640799:Found 24 DICOM file(s)
# 240208-12:46:27,641 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.640799:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:27,641 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.640799:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:27,642 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.640799:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T1 (368x512x24x1)
# 240208-12:46:27,777 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.777077:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T1.nii"
# 240208-12:46:27,777 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.777077:Conversion required 0.226785 seconds (0.017783 for core code).
# 240208-12:46:27,955 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.955062:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:27,955 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.955062:Found 24 DICOM file(s)
# 240208-12:46:27,955 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.955062:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:27,956 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.955062:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:27,956 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:27.955062:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T2 (384x512x24x1)
# 240208-12:46:28,92 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.092133:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T2.nii"
# 240208-12:46:28,92 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.092133:Conversion required 0.233301 seconds (0.018017 for core code).
# 240208-12:46:28,250 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Found 24 DICOM file(s)
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Warning: interpolated protocol 'ep2d_diff_3scan_trace_s2' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/01878754_ADC_0_ep2d_diff_3scan_trace_s2_ADC+-+7/IM-0137-0001-0001.dcm
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:28,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:28,252 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.250253:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_ADC (320x320x24x1)
# 240208-12:46:28,290 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.290579:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_ADC.nii"
# 240208-12:46:28,290 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.290579:Conversion required 0.116277 seconds (0.015103 for core code).
# 240208-12:46:28,451 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.451934:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:28,452 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.451934:Found 24 DICOM file(s)
# 240208-12:46:28,452 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.451934:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:28,452 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.451934:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:28,453 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.451934:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_FLAIR (320x320x24x1)
# 240208-12:46:28,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.528634:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_FLAIR.nii"
# 240208-12:46:28,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.528634:Conversion required 0.158623 seconds (0.015418 for core code).
# 240208-12:46:28,820 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:28,820 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Found 72 DICOM file(s)
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: interpolated protocol 'ep2d_diff_3scan_trace_s2' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/01878754_DWI_0_ep2d_diff_3scan_trace_s2_TRACEW+-+6/IM-0136-0001-0001.dcm
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Discrepancy between reported (2.6s) and estimated (19.5s) repetition time (issue 560).
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Seconds between volumes varies
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:28,821 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Warning: Volume 2 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:28,822 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.820128:Convert 72 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_DWI (320x320x24x3)
# 240208-12:46:28,979 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.979964:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_DWI.nii"
# 240208-12:46:28,980 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:28.979964:Conversion required 0.369711 seconds (0.035429 for core code).
# 240208-12:46:29,152 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.152107:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:29,152 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.152107:Found 24 DICOM file(s)
# 240208-12:46:29,153 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.152107:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:29,153 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.152107:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:29,153 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.152107:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T1CE (368x512x24x1)
# 240208-12:46:29,283 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.283531:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01878754/1878754_T1CE.nii"
# 240208-12:46:29,283 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.283531:Conversion required 0.221786 seconds (0.017164 for core code).
#  14%|█▍        | 4/29 [00:08<00:48,  1.93s/it]
# 240208-12:46:29,454 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.454323:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:29,455 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.454323:Found 27 DICOM file(s)
# 240208-12:46:29,455 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.454323:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:29,455 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.454323:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:29,455 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.454323:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T1CE (256x256x27x1)
# 240208-12:46:29,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.521369:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T1CE.nii"
# 240208-12:46:29,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.521369:Conversion required 0.150419 seconds (0.016237 for core code).
# 240208-12:46:29,709 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:29,709 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Found 27 DICOM file(s)
# 240208-12:46:29,710 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/02110064_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0283-0001-0001.dcm
# 240208-12:46:29,710 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:29,710 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:29,710 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:29,710 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:29,711 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.709149:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_ADC (384x384x27x1)
# 240208-12:46:29,762 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.762253:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_ADC.nii"
# 240208-12:46:29,762 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.762253:Conversion required 0.158616 seconds (0.019308 for core code).
# 240208-12:46:29,936 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.936837:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:29,937 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.936837:Found 27 DICOM file(s)
# 240208-12:46:29,937 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.936837:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:29,937 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.936837:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:29,938 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:29.936837:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T2 (384x384x27x1)
# 240208-12:46:30,35 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.035904:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T2.nii"
# 240208-12:46:30,36 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.035904:Conversion required 0.193561 seconds (0.018298 for core code).
# 240208-12:46:30,195 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.195842:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:30,196 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.195842:Found 27 DICOM file(s)
# 240208-12:46:30,196 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.195842:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:30,196 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.195842:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:30,196 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.195842:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_STERN (216x256x27x1)
# 240208-12:46:30,261 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.261881:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_STERN.nii"
# 240208-12:46:30,262 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.261881:Conversion required 0.145210 seconds (0.014869 for core code).
# 240208-12:46:30,418 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.418578:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:30,419 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.418578:Found 27 DICOM file(s)
# 240208-12:46:30,419 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.418578:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:30,419 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.418578:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:30,419 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.418578:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_FLAIR (208x256x27x1)
# 240208-12:46:30,484 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.484573:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_FLAIR.nii"
# 240208-12:46:30,484 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.484573:Conversion required 0.142800 seconds (0.015072 for core code).
# 240208-12:46:30,640 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:30,641 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Found 27 DICOM file(s)
# 240208-12:46:30,641 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:30,642 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:30,642 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:46:30,642 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:46:30,642 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.640399:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_DWI (384x384x27x1)
# 240208-12:46:30,728 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.728800:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_DWI.nii"
# 240208-12:46:30,729 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.728800:Conversion required 0.164342 seconds (0.018939 for core code).
# 240208-12:46:30,903 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.902959:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:30,903 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.902959:Found 27 DICOM file(s)
# 240208-12:46:30,903 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.902959:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:30,903 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.902959:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:30,904 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.902959:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T1 (256x256x27x1)
# 240208-12:46:30,970 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.970011:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/02110064/2110064_T1.nii"
# 240208-12:46:30,970 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:30.970011:Conversion required 0.152353 seconds (0.015779 for core code).
#  17%|█▋        | 5/29 [00:10<00:44,  1.84s/it]
# 240208-12:46:31,122 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.122134:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:31,122 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.122134:Found 24 DICOM file(s)
# 240208-12:46:31,122 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.122134:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:31,123 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.122134:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:31,123 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.122134:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_T1 (240x320x24x1)
# 240208-12:46:31,191 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.191831:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_T1.nii"
# 240208-12:46:31,192 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.191831:Conversion required 0.134655 seconds (0.012575 for core code).
# 240208-12:46:31,353 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.353707:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:31,354 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.353707:Found 24 DICOM file(s)
# 240208-12:46:31,354 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.353707:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:31,354 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.353707:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:31,354 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.353707:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_FLAIR (320x320x24x1)
# 240208-12:46:31,434 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.434227:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_FLAIR.nii"
# 240208-12:46:31,434 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.434227:Conversion required 0.161805 seconds (0.014010 for core code).
# 240208-12:46:31,603 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.603416:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:31,604 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.603416:Found 24 DICOM file(s)
# 240208-12:46:31,604 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.603416:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:31,604 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.603416:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:31,604 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.603416:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_T2 (384x384x24x1)
# 240208-12:46:31,702 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.702700:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_T2.nii"
# 240208-12:46:31,703 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.702700:Conversion required 0.186176 seconds (0.014635 for core code).
# 240208-12:46:31,952 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:46:31,953 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Found 72 DICOM file(s)
# 240208-12:46:31,953 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Warning: Discrepancy between reported (4.2s) and estimated (3.16281s) repetition time (issue 560).
# 240208-12:46:31,953 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:46:31,953 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:46:31,953 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:31.952484:Convert 72 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_DWI (192x192x24x3)
# 240208-12:46:32,60 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:32.060722:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01969755/1969755_DWI.nii"
# 240208-12:46:32,61 nipype.interface INFO:
# 	 stdout 2024-02-08T12:46:32.060722:Conversion required 0.276748 seconds (0.024118 for core code).
# 240208-12:46:32,202 nipype.interface INFO:
# ...
# 	 stdout 2024-02-08T12:47:31.322063:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:31,323 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.322063:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:31,323 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.322063:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T1CE (240x320x24x1)
# 240208-12:47:31,532 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.532189:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T1CE.nii"
# 240208-12:47:31,532 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.532189:Conversion required 0.293654 seconds (0.014124 for core code).
# 240208-12:47:31,690 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.690168:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:31,690 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.690168:Found 24 DICOM file(s)
# 240208-12:47:31,691 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.690168:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:31,691 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.690168:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:31,691 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.690168:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T1 (240x320x24x1)
# 240208-12:47:31,917 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.917337:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T1.nii"
# 240208-12:47:31,917 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:31.917337:Conversion required 0.302555 seconds (0.013129 for core code).
# 240208-12:47:32,83 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.083733:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:32,84 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.083733:Found 24 DICOM file(s)
# 240208-12:47:32,84 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.083733:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:32,84 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.083733:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:32,85 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.083733:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_FLAIR (320x320x24x1)
# 240208-12:47:32,337 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.337956:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_FLAIR.nii"
# 240208-12:47:32,338 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.337956:Conversion required 0.339350 seconds (0.014239 for core code).
# 240208-12:47:32,510 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.510429:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:32,511 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.510429:Found 24 DICOM file(s)
# 240208-12:47:32,511 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.510429:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:32,511 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.510429:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:32,511 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.510429:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T2 (384x384x24x1)
# 240208-12:47:32,862 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.862094:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_T2.nii"
# 240208-12:47:32,862 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:32.862094:Conversion required 0.443033 seconds (0.015268 for core code).
# 240208-12:47:33,127 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:33,128 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Found 72 DICOM file(s)
# 240208-12:47:33,128 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Warning: Discrepancy between reported (4.1s) and estimated (3.08719s) repetition time (issue 560).
# 240208-12:47:33,128 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:33,129 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:33,129 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.127657:Convert 72 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_DWI (192x192x24x3)
# 240208-12:47:33,362 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.362792:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_DWI.nii"
# 240208-12:47:33,363 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.362792:Conversion required 0.414969 seconds (0.026255 for core code).
# 240208-12:47:33,522 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:33,522 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Found 24 DICOM file(s)
# 240208-12:47:33,523 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:47:33,523 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:33,523 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:47:33,523 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.522025:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_ADC (192x192x24x1)
# 240208-12:47:33,589 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.589793:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01990699/1990699_ADC.nii"
# 240208-12:47:33,590 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.589793:Conversion required 0.144099 seconds (0.012017 for core code).
#  97%|█████████▋| 28/29 [01:12<00:02,  2.59s/it]
# 240208-12:47:33,771 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.771280:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:33,772 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.771280:Found 27 DICOM file(s)
# 240208-12:47:33,772 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.771280:Warning: Slice timing appears corrupted (range 4517.5..4517.5, TR=4690 ms)
# 240208-12:47:33,772 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.771280:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:33,772 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:33.771280:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T2 (320x320x27x1)
# 240208-12:47:34,44 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.044031:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T2.nii"
# 240208-12:47:34,44 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.044031:Conversion required 0.369335 seconds (0.019073 for core code).
# 240208-12:47:34,243 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.243597:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:34,244 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.243597:Found 27 DICOM file(s)
# 240208-12:47:34,244 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.243597:Warning: Slice timing appears corrupted (range 67677.5..67677.5, TR=8000 ms)
# 240208-12:47:34,244 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.243597:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:34,245 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.243597:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_FLAIR (224x256x27x1)
# 240208-12:47:34,429 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.429224:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_FLAIR.nii"
# 240208-12:47:34,429 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.429224:Conversion required 0.302920 seconds (0.018085 for core code).
# 240208-12:47:34,631 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:34,631 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Found 27 DICOM file(s)
# 240208-12:47:34,631 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/01854308_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0003-0001-0001.dcm
# 240208-12:47:34,632 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:47:34,632 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:34,632 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:47:34,632 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:47:34,632 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.631097:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_DWI (384x384x27x1)
# 240208-12:47:34,975 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.975439:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_DWI.nii"
# 240208-12:47:34,975 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:34.975439:Conversion required 0.462564 seconds (0.021130 for core code).
# 240208-12:47:35,154 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.154844:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:35,155 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.154844:Found 27 DICOM file(s)
# 240208-12:47:35,155 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.154844:Warning: Slice timing appears corrupted (range 900..900, TR=933 ms)
# 240208-12:47:35,156 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.154844:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:35,156 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.154844:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_STERN (224x256x27x1)
# 240208-12:47:35,321 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.321797:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_STERN.nii"
# 240208-12:47:35,322 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.321797:Conversion required 0.265695 seconds (0.017706 for core code).
# 240208-12:47:35,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.527673:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:35,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.527673:Found 27 DICOM file(s)
# 240208-12:47:35,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.527673:Warning: Slice timing appears corrupted (range 482.5..482.5, TR=500 ms)
# 240208-12:47:35,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.527673:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:35,528 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.527673:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T1 (224x256x27x1)
# 240208-12:47:35,697 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.697539:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T1.nii"
# 240208-12:47:35,697 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.697539:Conversion required 0.293620 seconds (0.018926 for core code).
# 240208-12:47:35,896 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.896640:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:35,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.896640:Found 27 DICOM file(s)
# 240208-12:47:35,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.896640:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240208-12:47:35,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.896640:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:35,897 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:35.896640:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T1CE (224x256x27x1)
# 240208-12:47:36,83 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.083843:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_T1CE.nii"
# 240208-12:47:36,84 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.083843:Conversion required 0.304344 seconds (0.017985 for core code).
# 240208-12:47:36,266 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:47:36,267 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Found 27 DICOM file(s)
# 240208-12:47:36,267 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/01854308_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0004-0001-0001.dcm
# 240208-12:47:36,268 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:47:36,268 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:47:36,268 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.266834:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_ADC (384x384x27x1)
# 240208-12:47:36,552 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.552722:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/01854308/1854308_ADC.nii"
# 240208-12:47:36,553 nipype.interface INFO:
# 	 stdout 2024-02-08T12:47:36.552722:Conversion required 0.390552 seconds (0.019723 for core code).
# 100%|██████████| 29/29 [01:15<00:00,  2.61s/it]

# %% [markdown]
# Remove files that are not dicom folders or .txt files

# %%
path_to_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision"

# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_dataset) if os.path.isdir(os.path.join(path_to_dataset, folder))
]

# loop through the patients
for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    files_to_delete = [
        file for file in os.listdir(os.path.join(path_to_dataset, patientFolder)) if not (file.endswith(".txt") or os.path.isdir(os.path.join(path_to_dataset, patientFolder, file)))
    ]

    for file in files_to_delete:
        os.remove(os.path.join(path_to_dataset, patientFolder, file))
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 153.06it/s]

# %% [markdown]
# ## Step 5: Move patients into BIDS directory and convert them to niftis

# %%
# To-do:
# delete all newly created nifti files (= keep only folders and .txt files)
# create bids environment
# run above code and create directory according to bids formatting
# get all the patient files with t1, t1ce, t2 and flair
# create both a raw and a processed files directory in there
# do cool ai shit

# %%
#path_to_bids_entire_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_regensburg"
path_to_bids_entire_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision"

#path_to_all_patients_dicom = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Dataset_DICOM"
path_to_all_patients_dicom = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM"

# loop through patients
# create correct directory structure
# turn into niftis and save at new bids dataset location
# important: fix patient ids
# brain_mets_regensburg
# ├── patients.tsv
# ├── sub-12345678
#     ├── anat
#         ├── sub-12345678_T1w.nii.gz
#├── 
#│   └── 


# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_all_patients_dicom) if os.path.isdir(os.path.join(path_to_all_patients_dicom, folder))
]

# loop through the patients
for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    patientID = patientFolder

    patient = config.patient(id = patientID)

    # get list of sequences
    list_of_sequences = [
        sequenceFolder for sequenceFolder in os.listdir(os.path.join(path_to_all_patients_dicom, patientFolder)) if os.path.isdir(os.path.join(path_to_all_patients_dicom, patientFolder, sequenceFolder))
    ]

    # add all the sequences to the patient object, to check amount of sequences and thus decide wether to rename file or not
    for sequence in list_of_sequences:

        # ignores the ds_folders
        if config.dsStore in sequence:
            continue

        # get type of sequence and sequence name and add to patient
        sequence_type = sequence.split("_")[1]
        sequence_name = sequence.split("_", 3)[3]

        match sequence_type:
            case config.desiredSequences.T1.value:
                patient.T1_sequences.append(sequence_name)

            case config.desiredSequences.T1CE.value:
                patient.T1CE_sequences.append(sequence_name)

            case config.desiredSequences.T2.value:
                patient.T2_sequences.append(sequence_name)

            case config.desiredSequences.FLAIR.value:
                patient.FLAIR_sequences.append(sequence_name)

            case config.desiredSequences.STERN.value:
                patient.STERN_sequences.append(sequence_name)

            case config.desiredSequences.DWI.value:
                patient.DWI_sequences.append(sequence_name)

            case config.desiredSequences.ADC.value:
                patient.ADC_sequences.append(sequence_name)

            case config.desiredSequences.MPR.value:
                patient.MPR_sequences.append(sequence_name)

            case _:
                print(f"other sequence: {sequence}")
                patient.other_sequences.append(sequence.split("_", 1)[1])
    
    # create a new patient folder according to the bids standard
    path_to_bids_patient = funcs.createPatientFolderBIDS(path_to_bids_entire_dataset, patientID = patientID)

    #create an anat directory if there are any anatomical sequences
    path_to_anat_directory = f"{path_to_bids_entire_dataset}/{path_to_bids_patient}/anat"
    if patient.T1_sequences or patient.T1CE_sequences or patient.T2_sequences or patient.FLAIR_sequences or patient.STERN_sequences or patient.MPR_sequences or patient.other_sequences:
        # create anat directory
        os.mkdir(path_to_anat_directory)

    #create a dwo directory if there are any anatomical sequences
    path_to_dwi_directory = f"{path_to_bids_entire_dataset}/{path_to_bids_patient}/dwi"
    if patient.DWI_sequences or patient.ADC_sequences:
        # create dwi directory
        os.mkdir(path_to_dwi_directory)

    for sequence in list_of_sequences:

        # ignores the ds_folders
        if config.dsStore in sequence:
            continue

        # get type of sequence and sequence name and add to patient
        sequence_type = sequence.split("_")[1]
        sequence_name = sequence.split("_", 3)[3]

        match sequence_type:
            case config.desiredSequences.T1.value:
                
                if len(patient.T1_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_T1w"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_T1w"
                    )

            case config.desiredSequences.T1CE.value:
                if len(patient.T1CE_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_T1c"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_T1c"
                    )

            case config.desiredSequences.T2.value:
                if len(patient.T2_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_T2w"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_T2w"
                    )

            case config.desiredSequences.FLAIR.value:
                if len(patient.FLAIR_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_FLAIR"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_FLAIR"
                    )

            case config.desiredSequences.STERN.value:
                if len(patient.STERN_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_T2star"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_T2star"
                    )
            
            case config.desiredSequences.MPR.value:
                if len(patient.MPR_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_MPR"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_MPR"
                    )

            case config.desiredSequences.DWI.value:
                if len(patient.DWI_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_dwi_directory,
                        new_filename = f"sub-{patientID}_dwi"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_dwi_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_dwi"
                    )

            case config.desiredSequences.ADC.value:
                if len(patient.ADC_sequences) == 1:
                    # copy file with new name here sub-ID_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_dwi_directory,
                        new_filename = f"sub-{patientID}_adc"
                    )
                else:
                    # copy file with new name here sub-ID_desc-sequencename_T1w.nii.gz
                    preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_dwi_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_adc"
                    )

            case _:
                print(f"other sequence: {sequence}")
                preprocessing.convert_dicom_to_nifti(
                        path_to_sequence_folder = os.path.join(path_to_all_patients_dicom, patientFolder, sequence),
                        path_to_output_directory = path_to_anat_directory,
                        new_filename = f"sub-{patientID}_desc-{sequence_name}_{sequence_type}"
                )

        
    # create folder for patient sub-[patientID]
    # if there is t1, t1ce, t2, flair or mpr sequence create anat directory
    # if there is a dwi or adc sequence create dwi directory
    # rename files accordingly: sub-[patientID]_[sequenceType].nii.gz
    # if there are more than one of a sequencetype, add the name of the sequence as well: sub-[patientID]_desc-[sequenceName]_[sequenceType].nii.gz
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# 240208-12:53:16,994 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:16.994645:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:16,995 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:16.994645:Found 26 DICOM file(s)
# 240208-12:53:16,995 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:16.994645:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:16,995 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:16.994645:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:16,996 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:16.994645:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_FLAIR (320x320x26x1)
# 240208-12:53:17,72 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.072543:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_FLAIR.nii"
# 240208-12:53:17,72 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.072543:Conversion required 0.159245 seconds (0.016003 for core code).
# 240208-12:53:17,251 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.251743:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:17,252 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.251743:Found 26 DICOM file(s)
# 240208-12:53:17,252 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.251743:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:17,253 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.251743:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:17,253 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.251743:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T1c (224x320x26x1)
# 240208-12:53:17,326 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.326431:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T1c.nii"
# 240208-12:53:17,326 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.326431:Conversion required 0.157606 seconds (0.016141 for core code).
# 240208-12:53:17,514 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.514242:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:17,515 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.514242:Found 26 DICOM file(s)
# 240208-12:53:17,515 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.514242:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:17,515 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.514242:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:17,515 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.514242:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T2w (384x384x26x1)
# 240208-12:53:17,610 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.610419:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T2w.nii"
# 240208-12:53:17,610 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.610419:Conversion required 0.186352 seconds (0.017598 for core code).
# 240208-12:53:17,790 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.790697:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:17,791 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.790697:Found 26 DICOM file(s)
# 240208-12:53:17,792 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.790697:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:17,792 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.790697:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:17,792 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.790697:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T1w (224x320x26x1)
# 240208-12:53:17,858 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.858484:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/anat/sub-01405609_T1w.nii"
# 240208-12:53:17,859 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:17.858484:Conversion required 0.149288 seconds (0.016636 for core code).
# 240208-12:53:18,19 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:18,20 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Found 26 DICOM file(s)
# 240208-12:53:18,20 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:18,20 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:18,21 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:18,21 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.019623:Convert 26 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/dwi/sub-01405609_adc (192x192x26x1)
# 240208-12:53:18,47 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.047604:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/dwi/sub-01405609_adc.nii"
# 240208-12:53:18,47 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.047604:Conversion required 0.100954 seconds (0.013638 for core code).
# 240208-12:53:18,332 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:18,333 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Found 78 DICOM file(s)
# 240208-12:53:18,333 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Warning: Discrepancy between reported (4.9s) and estimated (3.68969s) repetition time (issue 560).
# 240208-12:53:18,333 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:18,334 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:18,334 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.332615:Convert 78 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/dwi/sub-01405609_dwi (192x192x26x3)
# 240208-12:53:18,417 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.417645:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01405609/dwi/sub-01405609_dwi.nii"
# 240208-12:53:18,418 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.417645:Conversion required 0.273177 seconds (0.030833 for core code).
#   3%|▎         | 1/29 [00:01<00:45,  1.62s/it]
# 240208-12:53:18,622 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.622842:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:18,623 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.622842:Found 27 DICOM file(s)
# 240208-12:53:18,624 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.622842:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:18,624 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.622842:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:18,624 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.622842:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T2w (384x384x27x1)
# 240208-12:53:18,758 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.758477:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T2w.nii"
# 240208-12:53:18,758 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.758477:Conversion required 0.235401 seconds (0.021583 for core code).
# 240208-12:53:18,930 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.930336:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:18,931 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.930336:Found 27 DICOM file(s)
# 240208-12:53:18,931 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.930336:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:18,931 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.930336:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:18,931 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.930336:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T1w (256x256x27x1)
# 240208-12:53:18,996 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.996343:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T1w.nii"
# 240208-12:53:18,996 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:18.996343:Conversion required 0.142255 seconds (0.017614 for core code).
# 240208-12:53:19,162 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.162453:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:19,163 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.162453:Found 27 DICOM file(s)
# 240208-12:53:19,163 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.162453:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:19,163 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.162453:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:19,163 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.162453:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T2star (216x256x27x1)
# 240208-12:53:19,226 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.226086:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T2star.nii"
# 240208-12:53:19,226 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.226086:Conversion required 0.142279 seconds (0.016332 for core code).
# 240208-12:53:19,394 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.394888:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:19,395 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.394888:Found 27 DICOM file(s)
# 240208-12:53:19,395 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.394888:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:19,396 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.394888:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:19,396 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.394888:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_FLAIR (208x256x27x1)
# 240208-12:53:19,455 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.455787:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_FLAIR.nii"
# 240208-12:53:19,456 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.455787:Conversion required 0.142410 seconds (0.015522 for core code).
# 240208-12:53:19,600 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.600602:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:19,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.600602:Found 27 DICOM file(s)
# 240208-12:53:19,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.600602:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:19,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.600602:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:19,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.600602:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T1c (256x256x27x1)
# 240208-12:53:19,663 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.663449:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/anat/sub-01056598_T1c.nii"
# 240208-12:53:19,663 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.663449:Conversion required 0.128912 seconds (0.014556 for core code).
# 240208-12:53:19,809 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:19,809 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Found 27 DICOM file(s)
# 240208-12:53:19,809 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:19,810 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:19,810 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:19,810 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:19,810 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.808933:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/dwi/sub-01056598_dwi (192x192x27x1)
# 240208-12:53:19,865 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.865837:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/dwi/sub-01056598_dwi.nii"
# 240208-12:53:19,866 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:19.865837:Conversion required 0.120441 seconds (0.013831 for core code).
# 240208-12:53:20,26 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:20,26 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Found 27 DICOM file(s)
# 240208-12:53:20,26 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:20,27 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:20,27 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:20,27 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:20,27 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.025998:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/dwi/sub-01056598_adc (192x192x27x1)
# 240208-12:53:20,54 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.054636:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01056598/dwi/sub-01056598_adc.nii"
# 240208-12:53:20,54 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.054636:Conversion required 0.102876 seconds (0.016198 for core code).
#   7%|▋         | 2/29 [00:03<00:44,  1.63s/it]
# 240208-12:53:20,263 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.263426:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:20,264 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.263426:Found 27 DICOM file(s)
# 240208-12:53:20,264 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.263426:Warning: Slice timing appears corrupted (range 4515..4515, TR=4690 ms)
# 240208-12:53:20,264 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.263426:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:20,264 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.263426:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T2w (320x320x27x1)
# 240208-12:53:20,343 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.343346:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T2w.nii"
# 240208-12:53:20,343 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.343346:Conversion required 0.181746 seconds (0.020043 for core code).
# 240208-12:53:20,520 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.520428:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:20,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.520428:Found 27 DICOM file(s)
# 240208-12:53:20,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.520428:Warning: Slice timing appears corrupted (range 480..480, TR=500 ms)
# 240208-12:53:20,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.520428:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:20,521 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.520428:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T1w (224x256x27x1)
# 240208-12:53:20,587 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.587338:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T1w.nii"
# 240208-12:53:20,587 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.587338:Conversion required 0.158209 seconds (0.017769 for core code).
# 240208-12:53:20,763 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.763023:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:20,763 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.763023:Found 27 DICOM file(s)
# 240208-12:53:20,763 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.763023:Warning: Slice timing appears corrupted (range 897.5..897.5, TR=933 ms)
# 240208-12:53:20,764 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.763023:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:20,764 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.763023:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T2star (224x256x27x1)
# 240208-12:53:20,833 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.833118:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T2star.nii"
# 240208-12:53:20,833 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:20.833118:Conversion required 0.162906 seconds (0.017984 for core code).
# 240208-12:53:21,12 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.012387:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:21,13 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.012387:Found 27 DICOM file(s)
# 240208-12:53:21,13 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.012387:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240208-12:53:21,13 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.012387:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:21,13 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.012387:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T1c (224x256x27x1)
# 240208-12:53:21,80 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.080515:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_T1c.nii"
# 240208-12:53:21,80 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.080515:Conversion required 0.164577 seconds (0.017910 for core code).
# 240208-12:53:21,276 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:21,277 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Found 27 DICOM file(s)
# 240208-12:53:21,277 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01773716/01773716_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0025-0001-0001.dcm
# 240208-12:53:21,277 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:53:21,278 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:21,278 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:21,278 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:21,278 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.276832:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/dwi/sub-01773716_dwi (384x384x27x1)
# 240208-12:53:21,365 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.365683:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/dwi/sub-01773716_dwi.nii"
# 240208-12:53:21,366 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.365683:Conversion required 0.202405 seconds (0.020973 for core code).
# 240208-12:53:21,525 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.525434:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:21,526 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.525434:Found 27 DICOM file(s)
# 240208-12:53:21,526 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.525434:Warning: Slice timing appears corrupted (range 67677.5..67677.5, TR=8000 ms)
# 240208-12:53:21,526 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.525434:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:21,526 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.525434:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_FLAIR (224x256x27x1)
# 240208-12:53:21,588 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.588709:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/anat/sub-01773716_FLAIR.nii"
# 240208-12:53:21,589 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.588709:Conversion required 0.137372 seconds (0.016851 for core code).
# 240208-12:53:21,765 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:21,766 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Found 27 DICOM file(s)
# 240208-12:53:21,766 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01773716/01773716_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0026-0001-0001.dcm
# 240208-12:53:21,766 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:53:21,766 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:21,767 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.765468:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/dwi/sub-01773716_adc (384x384x27x1)
# 240208-12:53:21,814 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.814144:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01773716/dwi/sub-01773716_adc.nii"
# 240208-12:53:21,814 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:21.814144:Conversion required 0.142325 seconds (0.018668 for core code).
#  10%|█         | 3/29 [00:05<00:43,  1.68s/it]
# 240208-12:53:22,0 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.000060:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:22,0 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.000060:Found 24 DICOM file(s)
# 240208-12:53:22,1 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.000060:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:22,1 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.000060:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:22,1 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.000060:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T1w (368x512x24x1)
# 240208-12:53:22,134 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.134015:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T1w.nii"
# 240208-12:53:22,134 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.134015:Conversion required 0.227743 seconds (0.019180 for core code).
# 240208-12:53:22,311 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.311504:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:22,312 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.311504:Found 24 DICOM file(s)
# 240208-12:53:22,312 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.311504:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:22,312 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.311504:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:22,312 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.311504:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T2w (384x512x24x1)
# 240208-12:53:22,452 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.452546:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T2w.nii"
# 240208-12:53:22,452 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.452546:Conversion required 0.235951 seconds (0.017868 for core code).
# 240208-12:53:22,624 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:22,625 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Found 24 DICOM file(s)
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Warning: interpolated protocol 'ep2d_diff_3scan_trace_s2' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01878754/01878754_ADC_0_ep2d_diff_3scan_trace_s2_ADC+-+7/IM-0137-0001-0001.dcm
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:22,626 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.624845:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/dwi/sub-01878754_adc (320x320x24x1)
# 240208-12:53:22,661 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.661405:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/dwi/sub-01878754_adc.nii"
# 240208-12:53:22,661 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.661405:Conversion required 0.124148 seconds (0.014707 for core code).
# 240208-12:53:22,823 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.823399:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:22,824 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.823399:Found 24 DICOM file(s)
# 240208-12:53:22,824 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.823399:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:22,824 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.823399:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:22,824 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.823399:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_FLAIR (320x320x24x1)
# 240208-12:53:22,902 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.902143:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_FLAIR.nii"
# 240208-12:53:22,902 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:22.902143:Conversion required 0.155548 seconds (0.013774 for core code).
# 240208-12:53:23,209 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:23,210 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Found 72 DICOM file(s)
# 240208-12:53:23,210 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: interpolated protocol 'ep2d_diff_3scan_trace_s2' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01878754/01878754_DWI_0_ep2d_diff_3scan_trace_s2_TRACEW+-+6/IM-0136-0001-0001.dcm
# 240208-12:53:23,210 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Discrepancy between reported (2.6s) and estimated (19.5s) repetition time (issue 560).
# 240208-12:53:23,210 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Seconds between volumes varies
# 240208-12:53:23,210 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:23,211 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:23,211 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:23,211 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Warning: Volume 2 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:23,211 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.209272:Convert 72 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/dwi/sub-01878754_dwi (320x320x24x3)
# 240208-12:53:23,374 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.374587:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/dwi/sub-01878754_dwi.nii"
# 240208-12:53:23,375 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.374587:Conversion required 0.389460 seconds (0.032357 for core code).
# 240208-12:53:23,565 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.565146:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:23,566 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.565146:Found 24 DICOM file(s)
# 240208-12:53:23,566 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.565146:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:23,566 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.565146:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:23,566 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.565146:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T1c (368x512x24x1)
# 240208-12:53:23,703 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.703128:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01878754/anat/sub-01878754_T1c.nii"
# 240208-12:53:23,703 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.703128:Conversion required 0.233481 seconds (0.019111 for core code).
#  14%|█▍        | 4/29 [00:06<00:44,  1.77s/it]
# 240208-12:53:23,888 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.888349:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:23,889 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.888349:Found 27 DICOM file(s)
# 240208-12:53:23,889 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.888349:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:23,889 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.888349:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:23,890 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.888349:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T1c (256x256x27x1)
# 240208-12:53:23,958 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.958336:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T1c.nii"
# 240208-12:53:23,958 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:23.958336:Conversion required 0.150282 seconds (0.015912 for core code).
# 240208-12:53:24,131 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:24,132 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Found 27 DICOM file(s)
# 240208-12:53:24,132 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/02110064/02110064_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0283-0001-0001.dcm
# 240208-12:53:24,132 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:24,133 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:24,133 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:24,133 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:24,133 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.131835:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/dwi/sub-02110064_adc (384x384x27x1)
# 240208-12:53:24,178 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.178525:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/dwi/sub-02110064_adc.nii"
# 240208-12:53:24,178 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.178525:Conversion required 0.136679 seconds (0.017725 for core code).
# 240208-12:53:24,337 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.337672:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:24,338 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.337672:Found 27 DICOM file(s)
# 240208-12:53:24,338 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.337672:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:24,338 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.337672:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:24,338 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.337672:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T2w (384x384x27x1)
# 240208-12:53:24,431 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.431010:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T2w.nii"
# 240208-12:53:24,431 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.431010:Conversion required 0.174349 seconds (0.016929 for core code).
# 240208-12:53:24,592 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.592089:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:24,592 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.592089:Found 27 DICOM file(s)
# 240208-12:53:24,593 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.592089:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:24,593 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.592089:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:24,593 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.592089:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T2star (216x256x27x1)
# 240208-12:53:24,657 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.657367:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T2star.nii"
# 240208-12:53:24,657 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.657367:Conversion required 0.149979 seconds (0.015233 for core code).
# 240208-12:53:24,829 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.829347:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:24,830 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.829347:Found 27 DICOM file(s)
# 240208-12:53:24,830 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.829347:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:24,830 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.829347:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:24,830 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.829347:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_FLAIR (208x256x27x1)
# 240208-12:53:24,893 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.893760:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_FLAIR.nii"
# 240208-12:53:24,894 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:24.893760:Conversion required 0.154435 seconds (0.015564 for core code).
# 240208-12:53:25,85 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Found 27 DICOM file(s)
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:53:25,86 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.085477:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/dwi/sub-02110064_dwi (384x384x27x1)
# 240208-12:53:25,176 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.176336:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/dwi/sub-02110064_dwi.nii"
# 240208-12:53:25,176 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.176336:Conversion required 0.202607 seconds (0.019592 for core code).
# 240208-12:53:25,349 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.349221:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:25,350 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.349221:Found 27 DICOM file(s)
# 240208-12:53:25,350 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.349221:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:25,350 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.349221:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:25,350 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.349221:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T1w (256x256x27x1)
# 240208-12:53:25,431 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.431353:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-02110064/anat/sub-02110064_T1w.nii"
# 240208-12:53:25,431 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.431353:Conversion required 0.174692 seconds (0.017105 for core code).
#  17%|█▋        | 5/29 [00:08<00:42,  1.75s/it]
# 240208-12:53:25,600 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.600746:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:25,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.600746:Found 24 DICOM file(s)
# 240208-12:53:25,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.600746:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:25,601 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.600746:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:25,602 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.600746:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_T1w (240x320x24x1)
# 240208-12:53:25,674 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.674285:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_T1w.nii"
# 240208-12:53:25,674 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.674285:Conversion required 0.150729 seconds (0.013247 for core code).
# 240208-12:53:25,845 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.845273:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:25,845 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.845273:Found 24 DICOM file(s)
# 240208-12:53:25,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.845273:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:25,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.845273:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:25,846 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.845273:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_FLAIR (320x320x24x1)
# 240208-12:53:25,925 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.925462:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_FLAIR.nii"
# 240208-12:53:25,925 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:25.925462:Conversion required 0.169424 seconds (0.014890 for core code).
# 240208-12:53:26,93 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.093775:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:26,94 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.093775:Found 24 DICOM file(s)
# 240208-12:53:26,94 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.093775:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:53:26,94 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.093775:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:53:26,95 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.093775:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_T2w (384x384x24x1)
# 240208-12:53:26,183 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.183484:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01969755/anat/sub-01969755_T2w.nii"
# 240208-12:53:26,183 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.183484:Conversion required 0.176700 seconds (0.015725 for core code).
# 240208-12:53:26,450 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.450621:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:53:26,451 nipype.interface INFO:
# 	 stdout 2024-02-08T12:53:26.450621:Found 72 DICOM file(s)
# 240208-12:53:26,451 nipype.interface INFO:
# ...
# 	 stdout 2024-02-08T12:54:06.323198:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T1c (240x320x24x1)
# 240208-12:54:06,532 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.532973:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T1c.nii"
# 240208-12:54:06,533 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.532973:Conversion required 0.283925 seconds (0.013092 for core code).
# 240208-12:54:06,686 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.686547:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:06,687 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.686547:Found 24 DICOM file(s)
# 240208-12:54:06,687 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.686547:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:54:06,687 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.686547:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:06,688 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.686547:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T1w (240x320x24x1)
# 240208-12:54:06,894 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.894732:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T1w.nii"
# 240208-12:54:06,895 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:06.894732:Conversion required 0.275547 seconds (0.012607 for core code).
# 240208-12:54:07,73 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.073084:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:07,73 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.073084:Found 24 DICOM file(s)
# 240208-12:54:07,74 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.073084:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:54:07,74 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.073084:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:07,74 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.073084:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_FLAIR (320x320x24x1)
# 240208-12:54:07,330 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.330243:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_FLAIR.nii"
# 240208-12:54:07,330 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.330243:Conversion required 0.355323 seconds (0.014063 for core code).
# 240208-12:54:07,493 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.493505:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:07,494 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.493505:Found 24 DICOM file(s)
# 240208-12:54:07,494 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.493505:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:54:07,494 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.493505:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:07,494 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.493505:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T2w (384x384x24x1)
# 240208-12:54:07,843 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.843191:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/anat/sub-01990699_T2w.nii"
# 240208-12:54:07,843 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:07.843191:Conversion required 0.433146 seconds (0.015249 for core code).
# 240208-12:54:08,124 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:08,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Found 72 DICOM file(s)
# 240208-12:54:08,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Warning: Discrepancy between reported (4.1s) and estimated (3.08719s) repetition time (issue 560).
# 240208-12:54:08,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:54:08,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:08,125 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.124554:Convert 72 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/dwi/sub-01990699_dwi (192x192x24x3)
# 240208-12:54:08,376 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.376032:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/dwi/sub-01990699_dwi.nii"
# 240208-12:54:08,376 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.376032:Conversion required 0.452851 seconds (0.027656 for core code).
# 240208-12:54:08,525 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:08,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Found 24 DICOM file(s)
# 240208-12:54:08,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240208-12:54:08,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:08,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:54:08,527 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.525803:Convert 24 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/dwi/sub-01990699_adc (192x192x24x1)
# 240208-12:54:08,610 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.610619:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01990699/dwi/sub-01990699_adc.nii"
# 240208-12:54:08,611 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.610619:Conversion required 0.155300 seconds (0.011676 for core code).
#  97%|█████████▋| 28/29 [00:51<00:02,  2.33s/it]
# 240208-12:54:08,787 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.787291:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:08,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.787291:Found 27 DICOM file(s)
# 240208-12:54:08,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.787291:Warning: Slice timing appears corrupted (range 4517.5..4517.5, TR=4690 ms)
# 240208-12:54:08,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.787291:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:08,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:08.787291:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T2w (320x320x27x1)
# 240208-12:54:09,59 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.059589:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T2w.nii"
# 240208-12:54:09,59 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.059589:Conversion required 0.361691 seconds (0.018111 for core code).
# 240208-12:54:09,222 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.222076:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:09,223 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.222076:Found 27 DICOM file(s)
# 240208-12:54:09,223 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.222076:Warning: Slice timing appears corrupted (range 67677.5..67677.5, TR=8000 ms)
# 240208-12:54:09,223 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.222076:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:09,223 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.222076:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_FLAIR (224x256x27x1)
# 240208-12:54:09,406 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.406725:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_FLAIR.nii"
# 240208-12:54:09,407 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.406725:Conversion required 0.266169 seconds (0.017488 for core code).
# 240208-12:54:09,606 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:09,607 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Found 27 DICOM file(s)
# 240208-12:54:09,607 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01854308/01854308_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0003-0001-0001.dcm
# 240208-12:54:09,607 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:54:09,607 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:09,608 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Warning: This diffusion series does not have a B0 (reference) volume
# 240208-12:54:09,608 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240208-12:54:09,608 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.606540:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/dwi/sub-01854308_dwi (384x384x27x1)
# 240208-12:54:09,951 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.951917:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/dwi/sub-01854308_dwi.nii"
# 240208-12:54:09,952 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:09.951917:Conversion required 0.464456 seconds (0.020948 for core code).
# 240208-12:54:10,117 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.117152:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:10,117 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.117152:Found 27 DICOM file(s)
# 240208-12:54:10,118 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.117152:Warning: Slice timing appears corrupted (range 900..900, TR=933 ms)
# 240208-12:54:10,118 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.117152:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:10,118 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.117152:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T2star (224x256x27x1)
# 240208-12:54:10,278 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.278702:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T2star.nii"
# 240208-12:54:10,279 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.278702:Conversion required 0.247748 seconds (0.017586 for core code).
# 240208-12:54:10,461 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.461102:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:10,461 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.461102:Found 27 DICOM file(s)
# 240208-12:54:10,462 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.461102:Warning: Slice timing appears corrupted (range 482.5..482.5, TR=500 ms)
# 240208-12:54:10,462 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.461102:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:10,462 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.461102:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T1w (224x256x27x1)
# 240208-12:54:10,624 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.624601:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T1w.nii"
# 240208-12:54:10,625 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.624601:Conversion required 0.266086 seconds (0.016914 for core code).
# 240208-12:54:10,787 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.787074:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:10,787 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.787074:Found 27 DICOM file(s)
# 240208-12:54:10,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.787074:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240208-12:54:10,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.787074:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:10,788 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.787074:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T1c (224x256x27x1)
# 240208-12:54:10,967 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.967943:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/anat/sub-01854308_T1c.nii"
# 240208-12:54:10,968 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:10.967943:Conversion required 0.263242 seconds (0.017130 for core code).
# 240208-12:54:11,148 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240208-12:54:11,149 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Found 27 DICOM file(s)
# 240208-12:54:11,149 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/01854308/01854308_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0004-0001-0001.dcm
# 240208-12:54:11,149 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240208-12:54:11,150 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240208-12:54:11,150 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.148700:Convert 27 DICOM as /Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/dwi/sub-01854308_adc (384x384x27x1)
# 240208-12:54:11,435 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.435206:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/sub-01854308/dwi/sub-01854308_adc.nii"
# 240208-12:54:11,435 nipype.interface INFO:
# 	 stdout 2024-02-08T12:54:11.435206:Conversion required 0.386575 seconds (0.020114 for core code).
# 100%|██████████| 29/29 [00:54<00:00,  1.88s/it]

# %% [markdown]
# add the patients.tsv file to the BIDS directory

# %%
import math

def convert_patientID_to_BIDS(id):
    length_of_id = int(math.log10(id))+1
    if length_of_id < 8:
        num_of_zeros = 8 - length_of_id
        bids_subject_id = "sub-" + num_of_zeros * "0" + str(int(id))
    else:
        bids_subject_id = "sub-" + str(int(id))
    return bids_subject_id

#path_to_tsf = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Dataset_DICOM/_patientData.tsv"
path_to_tsf = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_DICOM/_patientData.tsv"

tsf_dataset = pd.read_csv(path_to_tsf, sep="\t")

tsf_dataset["ID"] = tsf_dataset["ID"].apply(convert_patientID_to_BIDS)

tsf_dataset = tsf_dataset.rename(columns={"ID":"participant_id"})

#tsf_dataset.to_csv("/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_regensburg/participants.tsv", index=False, sep="\t")
tsf_dataset.to_csv("/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/participants.tsv", index=False, sep="\t")

# function
# if length of patientID < 9:
# add enough 0 before until lenght of patientID == 9

# %% [markdown]
# ## Step 6: Copy all the patients with T1, T1c, T2 and FLAIR sequences into new directory

# %% [markdown]
# copy files

# %%
#path_to_bids_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_regensburg"
path_to_bids_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision"

#path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_classification/rawdata"
path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_classification/rawdata"

# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_bids_dataset) if os.path.isdir(os.path.join(path_to_bids_dataset, folder))
]

# loop through the patients
for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue

    patientID = patientFolder

    patient = config.patient(id = patientID)

    # get list of sequences
    list_of_sequences = [
        sequence for sequence in os.listdir(os.path.join(path_to_bids_dataset, patientFolder, "anat")) if (".nii" in sequence)
    ]

    for sequence in list_of_sequences:
        if "T1w.nii" in sequence:
            patient.T1_sequences.append(sequence)
        elif "T1c.nii" in sequence:
            patient.T1CE_sequences.append(sequence)
        elif "T2w.nii" in sequence:
            patient.T2_sequences.append(sequence)
        elif "FLAIR.nii" in sequence:
            patient.FLAIR_sequences.append(sequence)

    
    if len(patient.T1_sequences) and len(patient.T1CE_sequences) and len(patient.T2_sequences) and len(patient.FLAIR_sequences) > 0:

        # create new patient directory
        funcs.createFolderForPatient(path = path_to_classification_dataset, patientID = patientID)

        # create anat file at patient directory
        anat_dir_created = False
        path_to_anat_directory = f"{path_to_classification_dataset}/{patientFolder}/anat"
        if not anat_dir_created:
            os.mkdir(path_to_anat_directory)
            anat_dir_created = True


        for sequence_list in [patient.T1_sequences, patient.T1CE_sequences, patient.T2_sequences, patient.FLAIR_sequences]:
            if len(sequence_list) > 1:
                print(f"check duplicates: {sequence_list}")
            
            for sequence in sequence_list:
                # copy file to new directory
                # shutil.copy(src, dir)
                path_to_source = os.path.join(path_to_bids_dataset, patientFolder, "anat", sequence)
                path_to_destination_directory = os.path.join(path_to_classification_dataset, patientFolder, "anat")
                shutil.copy(path_to_source, path_to_destination_directory)
                #print(f"{path_to_source} TO {path_to_destination_directory}")
# Out:
# 100%|██████████| 29/29 [00:08<00:00,  3.55it/s]

# %% [markdown]
# makes sure that there are 4 sequences for each patient

# %%
#path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_classification/rawdata"
path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_classification/rawdata"

# get patient folders
patientFolders = [
    folder for folder in os.listdir(path_to_classification_dataset) if os.path.isdir(os.path.join(path_to_classification_dataset, folder))
]

# loop through the patients
for patientFolder in tqdm(patientFolders):

    # ignores the ds_folders
    if config.dsStore in patientFolder:
        continue
    
    list_of_sequences = [
        sequence for sequence in os.listdir(os.path.join(path_to_classification_dataset, patientFolder, "anat")) if (".nii" in sequence)
    ]

    if len(list_of_sequences) > 4:
        print(f"#{len(list_of_sequences)} {patientFolder}, {list_of_sequences}")
    elif len(list_of_sequences) < 4:
        print(f"#{len(list_of_sequences)} {patientFolder}, {list_of_sequences}")
    elif len(list_of_sequences) == 4:
        print(f"{patientFolder}: all good")
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 3429.42it/s]
# sub-01405609: all good
# sub-01056598: all good
# sub-01773716: all good
# sub-01878754: all good
# sub-02110064: all good
# sub-01969755: all good
# sub-01798755: all good
# sub-01961554: all good
# sub-02188930: all good
# sub-02036130: all good
# sub-01781732: all good
# sub-01592849: all good
# sub-01549022: all good
# sub-01881784: all good
# sub-01983705: all good
# sub-01349100: all good
# sub-02015335: all good
# sub-01231700: all good
# sub-02145870: all good
# sub-02126982: all good
# sub-01288036: all good
# sub-01947074: all good
# sub-02119712: all good
# sub-01804484: all good
# sub-01914558: all good
# sub-01812578: all good
# sub-02132336: all good
# sub-01990699: all good
# sub-01854308: all good

# %% [markdown]
# copy patientlist.tsv with only the right patients

# %%
#path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_classification/rawdata"
path_to_classification_dataset = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_classification/rawdata"

#path_to_tsf = "/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_regensburg/participants.tsv"
path_to_tsf = "/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision/participants.tsv"

all_patients = pd.read_csv(path_to_tsf, sep="\t")

# get patient folders
patientIds = [
    folder for folder in os.listdir(path_to_classification_dataset) if os.path.isdir(os.path.join(path_to_classification_dataset, folder))
]

classification_patients = all_patients[all_patients["participant_id"].isin(patientIds)]

#classification_patients.to_csv("/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_classification/rawdata/participants.tsv", index=False, sep="\t")
classification_patients.to_csv("/Volumes/BrainMets/Rgb_Brain_Mets/Rgb_Brain_Mets_Revision_classification/rawdata/participants.tsv", index=False, sep="\t")

# %% [markdown]
# # Compare participants.tsv with the excel patients

# %%
#path_to_tsv = Path("/Volumes/BrainMets/Rgb_Brain_Mets/brain_mets_classification/rawdata/participants.tsv")
path_to_tsv = Path("/Users/LennartPhilipp/Desktop/Uni/Prowiss/Dateien/participants.tsv")
path_to_excel_patients = Path("/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/patientsIDsexbirthdateprimary_04_09_24.csv")

participants = pd.read_csv(path_to_tsv, sep="\t")
excel_patients = pd.read_csv(path_to_excel_patients)

# %% [markdown]
# add "sub-" before each participants ID

# %%
import math

def convert_patientID_to_BIDS(id):
    length_of_id = int(math.log10(id))+1
    if length_of_id < 8:
        num_of_zeros = 8 - length_of_id
        bids_subject_id = "sub-" + num_of_zeros * "0" + str(int(id))
    else:
        bids_subject_id = "sub-" + str(int(id))
    return bids_subject_id


excel_patients["ID"] = excel_patients["ID"].apply(convert_patientID_to_BIDS)

# %% [markdown]
# compare primaries of excel sheet with participants.tsv
# and save all participants that are both in the .tsv and in the excel sheets

# %%
counter = 0

updated_participants_dataset = pd.DataFrame(columns=participants.columns)

for index, row in participants.iterrows():
    participant_id = row["participant_id"]
    tsv_primary = row["primary"]
    excel_primary = excel_patients[excel_patients["ID"] == participant_id]["primary_coded_newv"].values

    if len(excel_primary) == 0:
        continue

    if tsv_primary != excel_primary[0]:
        print(f"{participant_id}: {tsv_primary} != {excel_primary[0]}")

    if participant_id in excel_patients["ID"].values:
        updated_participants_dataset.loc[counter] = row
        counter += 1

print(counter)
# Out:
# 473

# %% [markdown]
# save all participants in a new .tsv

# %%
updated_participants_dataset.to_csv("/Users/LennartPhilipp/Desktop/Uni/Prowiss/Dateien/participants_04_09_24.tsv", index=False, sep="\t")

# %% [markdown]
# apparently there are no primary differences, which means that this at least seems to be correct
