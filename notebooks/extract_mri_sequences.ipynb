# %%
import os
import sys
sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification")

from tqdm import tqdm
from datetime import datetime
import shutil
import pandas as pd

import brain_mets_classification.config as config
import brain_mets_classification.custom_funcs as funcs

# %%
path_to_folder = f"{config.path}/originalPatientFiles"
#path_to_folder = f"{config.path}/RgbBrainMetsSampleN30"
pathToCleanMRIList = ""

# %%
#Example file structure
#├── Anonymized - 01005097
#│   └── Mrt Body
#│       ├── Diffusion trace tra schnell_ADC - 8
#│       │   ├── IM-2330-0001-0001.dcm
#│       │   ├── IM-2330-0002-0001.dcm
#...
#│       │   ├── IM-2469-0026-0001.dcm
#│       │   └── IM-2469-0027-0001.dcm
#│       ├── Diffusion trace tra schnell_TRACEW - 7
#│       │   ├── IM-2329-0001-0001.dcm
#│       │   ├── IM-2329-0002-0001.dcm
#...
#│       │   ├── IM-2468-0026-0001.dcm
#│       │   └── IM-2468-0027-0001.dcm
#│       ├── T1 mp-rage3d we sag 1mm KM - 13
#│       │   ├── IM-2335-0001-0001.dcm
#│       │   ├── IM-2335-0002-0001.dcm
#...
#│       │   ├── IM-2474-0159-0001.dcm
#│       │   └── IM-2474-0160-0001.dcm
#├── Anonymized - 12345678
#...

blackList = ["auswertung_fmrt", "fmri", "thorax", "lws", "hws", "bws", "hand", "posdisp", "cor", "sag", "cest", "ciss", "dti", "evidence", "reading", "field", "evaseries", "ct", "lokalizer", "localizer", "mip", "protocol", "resolve", "results", "screen save", "sub", "svs", "tof", "mean_"]

# Creates a new directory for all the patient folders
pathToCleanMRIList = funcs.createNewPreprocessingStepFolder(step=0)

# Goes through list of files/folders at path_to_folder and only adds the directories to the list
folderList = [
    folder for folder in os.listdir(path_to_folder) if os.path.isdir(os.path.join(path_to_folder, folder))
]

patientIDs = []

sequencesList = []


# Loops through all the "Anonymized - #######" folders
for patient_folder in tqdm(folderList):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue

    # all folders are named like "Anonymized - 12345678"
    patientID = patient_folder.split(" - ")[1]

    # adds the patientID to the list patientIDS if it hasn't been added before
    if patientID not in patientIDs:
        patientIDs.append(patientID)

    path_to_MRI_session_folders = os.path.join(path_to_folder, patient_folder)
    MRI_session_folders = os.listdir(path_to_MRI_session_folders)

    # loops through the different MRI sessions
    for mri_session in MRI_session_folders:
        
        # ignores the ds_folders
        if config.dsStore in mri_session:
            continue

        # get a list of all the sequences in the mri_sequences
        path_to_mri_sequences = os.path.join(path_to_MRI_session_folders, mri_session)
        mri_sequences = os.listdir(path_to_mri_sequences)

        # loops through the different sequences created during each MRI session
        for sequence in mri_sequences:

            # ignores the ds_folders
            if config.dsStore in sequence:
                continue

            sequences_lower_cased = sequence.lower()

            if not any(blackListSeq in sequences_lower_cased for blackListSeq in blackList):

                # create folder for patient
                funcs.createFolderForPatient(
                    path = pathToCleanMRIList,
                    patientID = patientID
                )

                # # create new folder as pathToCleanMRIList/patientID/T1CE
                # path_to_sequence = funcs.createSequenceFolder(
                #     path = os.path.join(pathToCleanMRIList, patientID),
                #     patientID = patientID,
                #     sequence = "",
                #     sequence_list = [],
                #     original_sequence_name = sequence
                # )

                pathToPatient = os.path.join(pathToCleanMRIList, patientID)
                folderName = f"{patientID}_{sequence}"
                path_to_sequence = os.path.join(pathToPatient, folderName)
                # check if path_to_sequence already exists then create directory
                sequences = os.listdir(pathToPatient)
                counter = sequences.count(folderName)
                if counter >= 1:
                    path_to_sequence = f"{path_to_sequence}{counter + 1}"
                    os.mkdir(path_to_sequence)
                else:
                    os.mkdir(path_to_sequence)

                # get list of all the dicom files for the T1CE sequence
                dicomFiles = os.listdir(os.path.join(path_to_mri_sequences, sequence))

                # loops through the list of dicom files
                for dicomFile in dicomFiles:
                    # ignores the ds_folders
                    if config.dsStore in dicomFile:
                        continue

                    # copy each file individually into the path_to_sequence folder
                    shutil.copyfile(os.path.join(path_to_mri_sequences, sequence, dicomFile), os.path.join(path_to_sequence, dicomFile))



#             sequencesList.append(sequences_lower_cased)

# cleanList = list(dict.fromkeys(sorted(sequencesList)))

# minusNumberList = []

# for sequence in cleanList:
#     sequenceWithoutNumber = sequence.split(" - ")[0]
#     minusNumberList.append(sequenceWithoutNumber)

# cleanMinusNumber = list(dict.fromkeys(minusNumberList))









# removedSequences = []

# for sequence in cleanMinusNumber:
#     if not any(backListSequ in sequence for backListSequ in blackList): #and any(whiteListSeq in sequence for whiteListSeq in whiteList):
#         print(sequence)
#     else:
#         removedSequences.append(sequence)

# print(f"\n\nRemoved Sequences: {len(removedSequences)}")
# for removedSequence in removedSequences:
#     print(removedSequence)
# Out:
# 100%|██████████| 374/374 [29:16<00:00,  4.70s/it]

# %% [markdown]
# removes the patients with less than 4 sequences

# %%
filterFolderList = [
    folder for folder in os.listdir(pathToCleanMRIList) if os.path.isdir(os.path.join(pathToCleanMRIList, folder))
]

# loops through all the "12345678" folders
for patient_folder in tqdm(filterFolderList):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue
    
    path_to_patient = os.path.join(pathToCleanMRIList, patient_folder)

    # list to the mri sessions folders
    mri_sessions = os.listdir(path_to_patient)

    if len(mri_sessions) < 4:
        os.system(f"rm -r {path_to_patient}")
# Out:
# 100%|██████████| 370/370 [00:04<00:00, 84.25it/s]

# %% [markdown]
# To-Do:
# - rename sequences

# %%
print(pathToCleanMRIList)
# Out:
# /Volumes/BrainMets/Rgb_Brain_Mets/allPatients/Rgb_Brain_Mets_Preprocessing0_20240109-154442

# %%
pathToPreprocess1 = funcs.createNewPreprocessingStepFolder(step=1)

FLAIRList = ["flair"]
KMList = ["km"]
T2SternList = ["stern", "hemo"]
ADCList = ["adc"]
DWIList = ["diffusion"]

# list of patientIDs
folderPreprocess0List = [
    folder for folder in os.listdir(pathToCleanMRIList) if os.path.isdir(os.path.join(pathToCleanMRIList, folder))
]

# Loops through all the "Anonymized - #######" folders
for patient_folder in tqdm(folderPreprocess0List):

    # ignores the ds_folders
    if config.dsStore in patient_folder:
        continue
    
    path_to_patient_sequences = os.path.join(pathToCleanMRIList, patient_folder)
    mri_sequences = os.listdir(path_to_patient_sequences)

    # create new folder for patient in pathToPreprocess1

    # loop through the sequences for each patient
    for sequence in mri_sequences:

        # only get the sequence name, folder names: "12345678_SEQUENCENAME"
        sequence_lower_cased = sequence.split("_")[1].lower()

        # check if the name fits to a sequence
        # if so: create a new folder name in pathToPreprocess1 / patientID with the updated sequence name
        # find a way to note how many sequences of each kind exist for each patient
        # create a list of patients with sequences that didn't fit the criteria
        # look through those patients manually
        # ?
        # profit
# Out:
# 100%|██████████| 321/321 [00:00<00:00, 6870.72it/s]
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2
# t1
# ep2d
# t1
# ep2d
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km schnell - 15
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# phoenixzipreport - 99
# diffusion trace tra schnell
# t1 tse tra km - 25
# t1 tse tra km - 24
# t2 stern flash tra schnell - 9
# t1 se tra schnell - 18
# diffusion trace tra schnell
# t1 se tra km schnell - 19
# t2 tse tra - 6
# t2 flair tra - 5
# t2 tse tra - 16
# t2 tse tra - 17
# t2 tse tra schnell - 10
# diffusion trace tra schnell
# t1 se tra schnell - 16
# t2 stern flash tra schnell - 15
# diffusion trace tra schnell
# t1 se tra km schnell - 17
# t2 blade flair tra - 11
# t2 blade tra - 12
# t2 flair tra schnell - 9
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# mpr ax - 5003
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 tse tra km ws - 32
# diffusion trace tra schnell
# t1 se tra schnell - 10
# t2 tse tra schnell - 7
# t2 tse tra - 23
# diffusion trace tra schnell
# t2 tse tra - 22
# t1 se tra km schnell - 28
# t1 tse tra km ws - 31
# t1 tse tra km ws - 30
# t2 flair tra schnell - 6
# t2 tse tra - 21
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 flash tra km - 13
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t2 tseb 384
# axial diff 3scans trace
# axial t1
# axial t2 flairb 384
# axial diff 3scans trace - 4
# axial t1 km
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1002
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t1 fl90 320 km - 9
# axial t2 flair 320 - 2
# axial t2 tserb 384 2 5mm!! - 8
# axial t2 fl30 hemo p2 - 3
# axial diff 3scan trace p2 192
# axial diff 3scan trace p2 192 - 4
# dwi
# ax - 603
# t1w
# t2w
# cs
# t1w
# flair
# ddwi
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 3
# mpr
# t1 se tra - 8
# t1 flash tra km - 38
# t1 se tra km - 36
# diffusion orthog.+-trace tra
# diffusion orthog.+-trace tra
# diffusion orthog.+-trace tra - 4
# t2 stern flash tra - 7
# t2 flair tra - 2
# ax t1 2mm km - 9
# 3d ax t2 cube hypersense - 6
# akn - 650
# adc (10 -6 mm²-s)-mar 29 2021 09-11-13 - 550
# ax dwi - 5
# ax t1 3d km 1mm - 8
# eadc-mar 29 2021 09-11-13 - 551
# fl-b-ax t2 flair propeller - 400
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# report data - 1975
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 blade flair tra - 7
# t1 se tra schnell - 11
# diffusion trace tra schnell
# t2 stern flash tra schnell - 10
# t2 blade tra - 6
# t1 se tra km schnell - 12
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km - 24
# t1 se tra - 23
# t2 tse tra - 12
# t2 tse tra - 13
# t2 flair tra - 18
# t2 stern flash tra - 22
# diffusion trace tra
# diffusion trace tra
# t1 tse tra km - 34
# t1 tse tra km - 33
# t2 tse tra - 19
# cbv
# axial flash 3mm - 9
# patientenprotokoll - 501
# head seq 4.0 h20s - 2
# ttp
# axial t1 km 3mm - 27
# cbf
# mtt
# ax diff - 10
# axial t2 tse 3mm - 26
# ax adc - 12
# ax trace - 11
# axial t1 3mm - 14
# axial flair 3mm - 5
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# le 5 00 bv36 s3 ax - 4
# axial t2 tserb 384 - 6
# axial t1 320 km - 9
# axial t1 320 - 7
# axial t1 320 - 8
# axial t2 flairb 320 p2 - 2
# axial diff 3scan trace p2 192
# axial diff 3scan trace p2 192 - 4
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km wdhg. - 13
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 stern flash tra - 10
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial flash 3mm - 9
# mtt
# axial t1 km - 31
# cbf
# axial flair - 5
# ax diff - 10
# cbv
# axial t2 tse 3mm - 26
# ttp
# ax adc - 12
# ax trace - 11
# axial t1 - 14
# flair tra blade 384 - 5
# t2
# ep2d
# t1
# ep2d
# ep2d
# t1
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# tra - 5002
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 15
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# cbf
# axial flash 5mm - 13
# mtt
# ax adc - 11
# axial t1 km - 28
# ax diff - 9
# axial t2 tse 3mm - 12
# ax rec mpr 2-2-35 - 5003
# axial flair - 5
# cbv
# ax trace - 10
# ttp
# axial t1 - 14
# diffusion trace tra schnell
# axial 1mm - 5003
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 flair tra schnell - 4
# diffusion trace tra schnell - 5
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# t2 tse tra schnell - 10
# diffusion trace tra schnell
# t2 stern flash tra schnell - 13
# t1 se tra schnell - 14
# t2 flair tra schnell - 9
# diffusion trace tra schnell
# t1 se tra km schnell - 15
# t2
# pha
# swi
# mpr
# t1
# t2
# mag
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial flash 3mm - 12
# axial perf 21 sl
# mtt
# axial t1 km 3mm - 30
# ax adc - 11
# ax diff - 9
# cbf
# cbv
# ax trace - 10
# ttp
# axial t2 tse 3mm - 27
# axial t1 3mm - 14
# axial flair 3mm - 5
# axial t1 320 km - 9
# axial t2 tseb 384 - 4
# axial t1 320 - 8
# axial diff 192 trace
# axial t2 flair 320 moco - 3
# axial diff 192 trace - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t1 se tra schnell - 11
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1002
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 13
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra wdhg. - 9
# t1 se tra schnell - 11
# t2 stern flash tra - 10
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 12
# t1 flash tra km schnell - 16
# axial t1 km - 10
# axial diff
# axial diff
# axial t1 - 8
# axial pd t2 - 9
# ep2d diff tra
# mpr tra - 5005
# ep2d diff tra - 6
# pc-2d-projektion
# t1 se tra - 3
# flair tra - 4
# t2 tse tra - 8
# ep2d diff tra - 5
# t1 se tra - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 stern flash tra blutung schnell - 9
# t1 se tra schnell - 10
# diffusion trace tra schnell
# t2 flair blade tra - 5
# t2 blade tra - 6
# t1 se tra km schnell - 15
# ax dwi 1000b - 3
# ax t2* gre - 6
# ax t2 fse prop - 4
# fl-a-ax t2 flair prop - 500
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1002
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 3
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra - 8
# t1 se tra km - 9
# t2 stern flash tra - 6
# t2 flair tra - 2
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra - 9
# t1 se tra km - 10
# t2 tse tra - 6
# diffusion trace tra
# t2 flair tra - 5
# diffusion trace tra
# et2* ffe tra - 302
# et2w
# t2w
# eflair
# dwi
# ddwi hr tra adc iso - 402
# 3 mm tra - 805
# et1 se tra - 502
# est1w
# rad - 804
# flair ax - 402
# t1w
# t2w
# dadc - 302
# sdwi
# t1w
# t1 3d cs ax - 202
# cs
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t2 blade tra - 6
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr 2mm range - 1004
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# phoenixzipreport - 99
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra
# diffusion trace tra - 3
# diffusion trace tra - 4
# t1 se tra - 6
# t2 fl2d tra blutung - 7
# t1 se tra+km - 12
# t2 flair tra - 2
# t2 tse tra - 11
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 11
# t2 stern flash tra - 6
# t2 flair tra - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t2 tseb 384
# axial diff 3scans trace
# axial t2 flairb 384
# axial t1
# axial diff 3scans trace - 4
# axial t1 km
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# ax - 5003
# t1
# t2
# ep2d
# ep2d
# t1
# t1
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# tra 1mm - 1033
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2
# t1
# ep2d
# t1
# ep2d
# t1 flash tra km - 13
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# t2
# ep2d
# t2
# t1
# ep2d
# t1
# t2 flair space3d ax - 5
# lunge mpr 10.0mm - 1037
# pet wb - 102
# axialfusion - 1035
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km - 6
# mpr ax - 8
# t1 se tra - 3
# t2 stern flash tra - 34
# t2 flair space3d ax - 4
# t2 space3d ax - 12
# diffusion trace tra
# diffusion trace tra
# ep2d
# mpr tra 1mm - 1079
# t1
# t1
# ep2d
# t2
# t2
# t1
# t1
# ep2d
# ep2d
# t2
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t1
# t1w
# edwi sense - 503
# 3di
# dwi tra - 501
# ddwi sense - 502
# t1w
# smartbrain - 101
# t2
# 3di
# t2w
# einflow tra rl - 706
# patient aligned mpr - 103
# smartbrain - 102
# t2 ffe * tra - 901
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# diffusion orthog.+-trace tra - 9
# t2 flair tra - 7
# t1 se tra - 13
# t2 flair space3d ax - 3
# t1 se tra km - 65
# diffusion orthog.+-trace tra
# t2 stern flash tra - 12
# t2 tse tra - 8
# t1 flash tra km - 66
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# diffusion trace tra schnell - 3
# t2 flair tra schnell - 2
# t1 se tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 6
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# t1 se tra km schnell - 17
# diffusion trace tra schnell
# t2 tse tra oa - 14
# t1 se fs tra km oa - 16
# t2 tse tra schnell - 3
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# swi
# t1 se tra schnell - 20
# press
# t2 flair tra schnell - 5
# adjgre - 14
# t1 se tra km schnell - 21
# diffusion trace tra schnell
# t2 tse tra schnell - 12
# press
# t1
# pha
# mpr tra km - 37
# mag
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 52
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial flash 3mm - 12
# mtt
# cbv
# ax adc - 11
# ax diff - 9
# axial flair 3mm - 13
# cbf
# ax trace - 10
# axial t1 3mm - 15
# axial t1 km 3mm schnell - 41
# axial t2 tse 3mm - 27
# ttp
# axial flair 3mm - 5
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1002
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t2 tse - 12
# axial flash - 13
# ax adc - 11
# ax diff - 9
# axial flair - 5
# ax trace - 10
# axial t1 - 14
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 21
# t1 tse tra km ws - 25
# t2
# t1
# pd+t2
# t1
# axial t1 fl90 320 km - 7
# axial t2 flair 320 - 2
# axial diff 3scan trace p2 192
# axial diff 3scan trace p2 192 - 3
# t1
# t1
# t2
# ep2d
# t2
# ep2d
# t2
# diffusion trace tra schnell
# t2 tse tra schnell - 9
# t1 se tra schnell - 11
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t2 stern flash tra schnell - 10
# t1 se tra km schnell - 12
# rad - 804
# t2w
# isodwi - 304
# cs
# t1 3d cs ax - 1002
# dadc - 303
# t1w
# dwi tra - 301
# t1w
# flair
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# axial t1 5mm - 7
# axial t2 diffusion neu
# axial t2 hemo 5 mm - 10
# axial t1 5mm - 14
# axial t2 diffusion neu
# t2
# t1w
# patient aligned mpr awplan
# flair tra - 201
# diffusion tra - 301
# t1w
# t2w
# smartbrain - 101
# dadc - 302
# flair tra - 202
# smartbrain - 102
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# press
# adjgre - 12
# mag
# t2 tse tra schnell - 5
# press
# t1
# mpr tra km - 30
# swi
# pha
# axial flash 5mm - 13
# ax adc - 11
# ax diff - 9
# axial t2 tse 3mm - 12
# axial flair 41sl - 5
# ax trace - 10
# axial t1 km - 15
# axial t1 - 14
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 3
# diffusion trace tra - 4
# t2 fl2d tra blutung - 6
# t2 blade tra - 8
# t2 flair tra - 2
# t1 se tra+km - 9
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra
# t1 se tra - 7
# diffusion trace tra - 3
# t2 tse tra - 5
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# <mpr-dickschicht serie> - 5003
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# adjgre - 8
# mpr tra km - 21
# press
# press
# t2 flair tra - 6
# t1
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# t1 se tra - 15
# t1 se tra km - 16
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# diffusion trace tra
# v3d tra - 402
# v3d tra - 902
# swip fast blutung tra - 501
# vswip fast blutung tra - 502
# s3di mc - 601
# dadc - 305
# sb1000 - 304
# sb0 - 303
# 3d flair 3mm tra - 201
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# mpr tra - 3
# t1 se tra km - 14
# apt standard 4.4mm
# mtt - 26
# apt standard 4.4mm
# apt standard 4.4mm
# cbv - 27
# pbp - 25
# adjgre - 3
# perfusion tra
# apt standard 4.4mm
# ttp - 24
# apt standard 4.4mm
# cbf - 28
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2
# t1
# ep2d
# t1
# ep2d
# v3d tra - 402
# swip fast blutung tra - 501
# vswip fast blutung tra - 502
# v3d tra - 802
# dadc - 305
# sb1000 - 304
# sb0 - 303
# 3d flair 3mm tra - 201
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# ddw-ssh fl - 602
# t2w-tse-5mm - 301
# ddw-ssh fl - 604
# edw-ssh fl - 603
# smartbrain - 101
# flair neu - 201
# t1512+km - 701
# t1512+km - 901
# t1w
# dw-ssh fl - 601
# smartbrain - 102
# t1-se-512+km - 801
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diff - 14
# axial -t1-halffourier km - 13
# axial t1 halffourier - 9
# axial t1 flash 2d - 8
# axial t2 tse - 7
# trace - 16
# axial flair - 3
# adc - 15
# diffusion trace tra - 5
# t1 se tra - 7
# diffusion trace tra - 4
# t1 se tra+km - 10
# t2 fl2d tra blutung - 8
# t2 tse tra - 9
# diffusion trace tra
# t2 flair tra - 3
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 19
# mag
# t1
# t2 flair tra schnell - 5
# adjgre - 13
# diffusion trace tra schnell
# t1 se tra km schnell - 20
# pha
# swi
# t2 tse tra schnell - 12
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 52
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# axial t1 320 - 10
# axial diff 3scan trace p2 192
# axial t2 fl30 hemo p2 - 8
# axial t1 320 km - 12
# axial t2 flairb 320 p2 - 5
# axial diff 3scan trace p2 192
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# mpr tra 1mm - 1001
# t1 se tra km schnell - 11
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# axial flash - 9
# axial diff +- adc
# axial t1 - 10
# axial diff +- adc
# axial t2 tse - 11
# axial flair - 5
# axial t1 km - 12
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t1 320 km - 9
# axial t2 tseb 384 - 4
# axial t1 320 - 8
# mpr ax - 5010
# axial diff 192 trace
# axial t2 flair 320 moco - 3
# axial diff 192 trace - 5
# eeadc - 204
# dadc - 203
# t1 se tra - 901
# t2 tra - 1001
# 3d
# t2 tse tra - 501
# flair tra - 401
# isodwi1000 - 202
# le 5 00 bv36 s3 ax - 5
# t1 se tra km - 24
# t2 stern flash tra - 10
# t2 tse tra - 7
# diffusion trace tra
# t1 se tra - 11
# t2 flair tra - 5
# diffusion trace tra
# ax trace - 100
# axial t1 5mm - 10
# axial t1 5mm - 11
# ax adc - 101
# axial t2 tse 5mm
# axial t2 flash 5mm - 9
# axial flair 5mm - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1004
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 mp-rage3d tra 1mm - 6
# t2 tse tra - 5
# t2 flair tra - 7
# diffusion trace tra
# t1 mp-rage3d we tra 1mm km - 10
# diffusion trace tra
# t2 tse tra schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 11
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 12
# t1 se tra km - 17
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# t1 se tra km - 40
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# t2 space3d ax - 5002
# diffusion trace tra
# t2 stern flash tra - 6
# t2 flair tra - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial trace - 10
# axial flash 5mm - 13
# ttp
# axial t2 tse 3mm - 12
# mtt
# cbv
# axial flair - 5
# cbf
# axial t1 km - 22
# axial diff - 9
# axial t1 - 14
# axial adc - 11
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t1
# axial t2 tse - 14
# axial flair - 6
# axial flash - 15
# ax trace - 12
# axial flair - 5
# ax diff - 11
# axial t1 km
# ax adc - 13
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# axial t2 tse - 15
# axial diff +- adc
# axial flash - 13
# axial t1 km - 16
# axial diff +- adc
# axial flair - 5
# axial t1 - 14
# ax dwi - 6
# ax t2* gre haemosequenz - 4
# adc (10 -6 mm²-s)-may 29 2020 16-01-14 - 650
# 3d t1 fspgr km mpr axial - 900
# ax t1 fspgr 3d+12ml dotavision - 9
# eadc-may 29 2020 16-01-14 - 651
# ax t1 propeller+ 12ml dotavision - 10
# ax t1 propeller - 7
# (48439-10-1..29)-(48439-7-1..29) - 100
# ax t2 propeller - 8
# t1 se tra schnell - 8
# t2 tse tra schnell - 6
# t2 stern flash tra schnell - 7
# t2 flair tra schnell - 5
# t1 se tra km schnell - 9
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# tra - 5003
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# t2
# t1
# ep2d
# t2
# t2
# ep2d
# t1
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# ep2d diff tra
# ep2d diff tra - 7
# t1 se tra - 9
# ep2d diff tra - 6
# t1 se tra - 12
# mpr tra - 14
# t2 hemo tra - 10
# flair tra - 3
# axial t1 320 km - 8
# axial t1 320 - 7
# axial t2 flairb 320 p2 - 2
# axial t2 tserb 384 - 3
# axial diff 3scan trace p2 192
# axial diff 3scan trace p2 192 - 4
# t1 flash tra km - 13
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# t1 se tra km - 12
# t2 stern flash tra - 10
# diffusion trace tra
# t2 tse tra - 6
# t1 se tra - 11
# t2 flair tra - 5
# diffusion trace tra
# fl
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# adc (10 -6 mm²-s) - 850
# adc (10 -6 mm²-s) - 250
# ax t1 se mt - 10
# ax dwi all b1000 - 2
# ax t2 5mm dl - 3
# ax t2 flair fs 5mm dl - 4
# ax t2* fgre - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 4
# diffusion trace tra - 5
# t1 se tra - 8
# t1 se tra km - 9
# diffusion trace tra
# t2 stern flash tra - 7
# t2 flair tra - 3
# t1 se tra schnell - 9
# t2 flair tra schnell - 5
# t1 tse tra km ws - 29
# t1 tse tra km ws - 27
# t1 tse tra km ws - 28
# t1 se tra km schnell - 23
# t2 tse tra - 18
# t2 tse tra - 17
# t2 tse tra - 19
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 13
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# mpr ax - 5002
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial flash 3mm - 12
# cbf
# axial t1 km 3mm - 22
# mtt
# ax adc - 11
# ax diff - 9
# cbv
# ax trace - 10
# axial t2 tse 3mm - 21
# ttp
# axial t1 3mm - 14
# axial flair 3mm - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t1 320 km - 7
# adc
# axial t2 tseb 384 - 3
# axial t1 320 - 6
# axial t2 flair 320 moco - 2
# axial diff 192 trace - 4
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra schnell - 8
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 12
# t2 stern flash tra schnell - 11
# t2 flair tra schnell - 7
# t1 se tra km schnell - 13
# diffusion trace tra
# diffusion trace tra - 3
# diffusion trace tra - 4
# t1 se tra - 6
# t1 se tra km - 9
# t2 fl2d tra blutung - 7
# t2 tse tra - 8
# t2 flair tra - 2
# t2 tse tra schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 11
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 flash tra schnell km - 16
# t1 se tra km schnell - 12
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial diff +- adc 3mm
# axial flash - 12
# axial diff +- adc 3mm
# axial flair 3mm - 6
# axial t1 km 3mm - 18
# axial t1 3mm - 5
# axial t2 3mm - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# <mpr thick range> - 101
# diff. tra
# t2 nav - 7
# diff. tra
# t1 tra mpr - 8
# t1 tra mpr km - 12
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# mpr ax - 5002
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diff
# t1
# mpr
# t1
# diff
# t2
# t2
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion orthog.+trace tra - 5
# t2 tse tra - 3
# t1 se tra - 8
# t1 se tra km - 9
# t2 stern flash tra - 7
# t2 flair tra - 2
# mpr ax - 5002
# diffusion orthog.+trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# mpr cot - 5002
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial flash 5mm - 13
# ax adc - 11
# ax diff - 9
# axial t2 tse 3mm - 12
# axial flair 41sl - 5
# ax trace - 10
# axial t1 km - 15
# axial t1 - 14
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 3mm - 1017
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# axial t1 320 km - 10
# axial t2 fl30 hemo p2 - 9
# axial t1 320 - 8
# axial t2 flairb 320 p2 - 2
# axial t2 tserb 384 - 3
# axial diff 3scan trace p2 192
# axial diff 3scan trace p2 192 - 4
# adc (10 -6 mm²-s) - 250
# ax dwi all b1000 - 2
# ax t1 se mt km - 9
# ax t2 5mm dl - 3
# ax t2 flair fs 5mm dl - 4
# ax t2* fgre - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# phoenixzipreport - 99
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# t1 flash tra km - 13
# t1 se tra km - 11
# t2 tse tra - 6
# diffusion trace tra
# t2 stern flash tra - 9
# t2 flair tra - 5
# t1 se tra - 10
# diffusion trace tra
# ax diff - 5002
# ax trace - 5003
# ax adc - 5004
# axial t1 - 11
# axial t2 tse - 9
# axial flair - 5
# axial flash - 10
# axial t1 km - 12
# axial diff 192 trace
# axial t1 320 km - 10
# axial t1 320 - 8
# axial t2 flair 320 moco - 3
# axial diff 192 trace - 4
# mpr 5 mm ax - 5005
# axial t2 hemo - 6
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# dwi
# ax - 603
# t1w
# t2w
# swip tra cs - 801
# cs
# t1w
# vswip tra - 802
# flair
# ddwi
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# <mpr-dickschicht serie> - 5002
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# ax t2 tse drive - 601
# ax t1 se - 501
# ax diffusion - 301
# smartbrain - 101
# mpr ax t1
# st1
# eadc - 304
# dadc - 303
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# axial t1 320 km - 9
# axial diff 3scan trace p2 192
# axial t1 320 - 7
# axial t2 flairb 320 p2 - 3
# axial t2 tserb 384 - 4
# axial diff 3scan trace p2 192 - 5
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# mpr tra 1mm range - 1002
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# mpr ax - 5002
# mpr ax - 5003
# t2 tse tra - 3
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 4
# t1 se tra km - 8
# t2 stern flash tra - 6
# t2 flair tra - 2
# axial t2 tse 3mm - 9
# axial flash 5mm - 13
# axial flair 41sl - 5
# ax diff - 10
# ax adc - 12
# ax trace - 11
# axial t1 km - 15
# axial t1 - 14
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# tra - 5002
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 tse tra km - 30
# diffusion trace tra schnell
# t1 tse tra km - 31
# t1 se tra km schnell - 21
# t1 tse tra km - 29
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra - 9
# t2 tse tra - 5
# t1 se tra km - 10
# t2 stern flash tra - 8
# diffusion trace tra - 6
# diffusion trace tra
# t2 flair tra - 4
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 tse tra km ws comp. - 5011
# t1 se tra km schnell - 23
# diffusion orthog.+trace tra - 5
# t2 tse tra - 3
# t1 se tra - 7
# t1 se tra km - 8
# t2 flair tra - 2
# diffusion orthog.+trace tra
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# mpr 1mm range - 1002
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t1 se tra schnell - 9
# t2 tse tra schnell - 6
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 10
# axial t2 tse 512 - 4
# axial flairb 384 - 3
# axial diff trace 3scans 210 - 5
# axial diff trace 3scans 210
# axial t1 fl90 512 - 7
# axial t1 fl90 512 - 9
# befund - 1
# phoenixzipreport - 99
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 7
# t2 stern flash tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t1 se tra km schnell - 8
# t2 tse tra schnell - 3
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra schnell - 6
# diffusion trace tra schnell - 4
# t2 flair tra schnell - 2
# diffusion trace tra schnell
# t2 tse tra schnell - 3
# t1 se tra km schnell - 7
# t1 se tra schnell - 8
# diffusion trace tra schnell
# t2 flair tra schnell - 5
# diffusion trace tra schnell
# t1 se tra km schnell - 9
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# diffusion trace tra schnell
# t2 tse tra schnell - 6
# t1 se tra schnell - 10
# t2 stern flash tra schnell - 9
# t2 flair tra schnell - 5
# t1 se tra km schnell - 11
# diffusion trace tra schnell
# t1 se tra - 7
# diffusion trace tra
# diffusion trace tra - 3
# diffusion trace tra - 4
# t2 fl2d tra blutung - 6
# t2 tse tra - 8
# t2 flair tra - 2
# t1 se tra+km - 9
# flair tra 3d - 401
# mtt - 754
# t2* tra (hämo) - 2
# dwi tra - 3
# t1 leakage indicator - 756
# graph - 751
# rcbv - 752
# t1 fs tra (3d) - 5
# t2 tra 1mm - 6
# t2* leakage indicator - 757
# ttp - 755
# adc (10 -6 mm²-s) - 350
# t1 fs tra km (3d) - 8
# rcbf - 753
