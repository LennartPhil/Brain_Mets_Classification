# %% [markdown]
# # Preprocessing all at once
# This notebook is meant to run the preprocessing code found in the scripts directory all at once\
# If you'd rather run the code step by step go to the `02_preprocessing_step_by_step.ipynb` file\
# The preprocesing steps include
# 1. convert dicom to nifti using [Dcm2niix](https://github.com/rordenlab/dcm2niix)
# 2. reorient images
# 3. extract brain using [HD-BET](https://github.com/MIC-DKFZ/HD-BET)
# 4. N4 bias correction
# 5. Coregister images
# 6. Resample images
# 7. Z-score normalize images

# %% [markdown]
# ## Import necessary libraries

# %%
import sys
sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification")
#sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/HD-BET/HD_BET")
import brain_mets_classification.config as config
import brain_mets_classification.custom_funcs as funcs

from tqdm import tqdm
from datetime import datetime
import subprocess

import pandas as pd
import os
import pathlib
import ants
from typing import Union, List, Tuple
import multiprocessing
import SimpleITK as sitk
from nipype.interfaces.dcm2nii import Dcm2niix
import numpy as np
#from HD_BET.run import run_hd_bet
#import HD_BET
from nipype.interfaces import fsl
from intensity_normalization.normalize.zscore import ZScoreNormalize

# %% [markdown]
# ## Helper Functions

# %%
N_PROC = multiprocessing.cpu_count() - 1

def dcm_to_nifti_conversion(
        path_to_folder: Union[str, pathlib.Path],
        path_to_output: Union[str, pathlib.Path],
        out_filename: str):

    # new sequence name: {patientID}_{sequence}_{preprocessingStep}
    converter = Dcm2niix()
    converter.inputs.source_dir = path_to_folder
    converter.inputs.compress = "y" # uses compression, "y" = yes
    converter.inputs.merge_imgs = True
    # converter.inputs.compression = 5
    converter.inputs.out_filename = out_filename
    converter.inputs.output_dir = path_to_output
    converter.run()
    

def reorient_brain(
    path_to_input_image: Union[str, pathlib.Path],
    path_to_output_image: Union[str, pathlib.Path],
):
    """
    applies FSL.Reorient2Std() to input brain scan
    and returns reoriented image

    Keyword Arguments:
    path_to_input_image: Union[str, pathlib.Path] = file path to input image (brain scan)
    path_to_output_image: Union[str, pathlib.Path] = location to store reoriented image
    """

    # Alternative: torchio tocanonical
    reorient = fsl.Reorient2Std()
    reorient.inputs.in_file = path_to_input_image
    reorient.inputs.out_file = path_to_output_image
    reorient.run()

    #run_hd_bet(mri_fnames=path_to_output_image, output_fnames=path_to_output_image)
    #os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_image} -device cpu -mode fast -tta 0")

def extract_brain(path_to_input_image: Union[str, pathlib.Path],
                  path_to_output_image: Union[str, pathlib.Path],
                  device: str):
    """
    runs the hd-bet brain extraction on the input image and returns the extracted brain
    
    Keyword Arguments:
    path_to_input_image: Union[str, pathlib.Path] = file path to input image (brain scan)
    path_to_output_image: Union[str, pathlib.Path] = location to store brain extracted image
    device: str = either "cpu" or "gpu", if you're running this on a macbook, choose "cpu"
    """

    # os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_extractedImage} -device cpu -mode fast -tta 0")
    if device == "cpu":
        subprocess.call(["hd-bet", "-i", f"{path_to_input_image}", "-o", f"{path_to_output_image}", "-device", "cpu", "-mode", "fast", "-tta", "0"], stdout=open(os.devnull, "w"), stderr=subprocess.STDOUT)
    elif device == "gpu":
        subprocess.call(["hd-bet", "-i", f"{path_to_input_image}", "-o", f"{path_to_output_image}"], stdout=open(os.devnull, "w"), stderr=subprocess.STDOUT)
    else:
        raise Exception("Wrong device input for the extract_brain method, please use either \"cpu\" or \"gpu\"")


def fill_holes(
    binary_image: sitk.Image,
    radius: int = 3,
) -> sitk.Image:
    """
    Fills holes in binary segmentation

    Keyword Arguments:
    - binary_image: sitk.Image = binary brain segmentation
    - radius: int = kernel radius

    Returns:
    - closed_image: sitk.Image = binary brain segmentation with holes filled
    """

    closing_filter = sitk.BinaryMorphologicalClosingImageFilter()
    closing_filter.SetKernelRadius(radius)
    closed_image = closing_filter.Execute(binary_image)

    return closed_image


def binary_segment_brain(
    image: sitk.Image,
) -> sitk.Image:
    """
    Returns binary segmentation of brain from brain-extracted scan via otsu thresholding

    Keyword Arguments:
    - image: sitk.Image = brain-extracted scan

    Returns:
    - sitk.Image = binary segmentation of brain scan with filled holes
    """

    otsu_filter = sitk.OtsuThresholdImageFilter()
    otsu_filter.SetInsideValue(0)
    otsu_filter.SetOutsideValue(1)
    binary_mask = otsu_filter.Execute(image)

    return fill_holes(binary_mask)


def get_bounding_box(
    image: sitk.Image,
) -> Tuple[int]:
    """
    Returns bounding box of brain-extracted scan

    Keyword Arguments:
    - image: sitk.Image = brain-extracted scan

    Returns
    - bounding_box: Tuple(int) = bounding box (startX, startY, startZ, sizeX, sizeY, sizeZ)
    """

    mask_image = binary_segment_brain(image)

    lsif = sitk.LabelShapeStatisticsImageFilter()
    lsif.Execute(mask_image)
    bounding_box = np.array(lsif.GetBoundingBox(1))

    return bounding_box


def apply_bounding_box(
    image: sitk.Image,
    bounding_box: Tuple[int],
) -> sitk.Image:
    """
    Returns image, cropped to bounding box

    Keyword Arguments:
    - image: sitk.Image = image
    - bounding_box: Tuple(ing) = bounding box of kind (startX, startY, startZ, sizeX, sizeY, sizeZ)

    Returns
    - cropped_image: sitk.Image = cropped image
    """

    cropped_image = image[
        bounding_box[0] : bounding_box[3] + bounding_box[0],
        bounding_box[1] : bounding_box[4] + bounding_box[1],
        bounding_box[2] : bounding_box[5] + bounding_box[2],
    ]

    return cropped_image


def apply_bias_correction(
    image: sitk.Image,
) -> sitk.Image:
    """applies N4 bias field correction to image but keeps background at zero

    Keyword Arguments:
    image: sitk.Image = image to apply bias correction to

    Returns:
    image_corrected_masked: sitk.Image = N4 bias field corrected image
    """

    mask_image = binary_segment_brain(image)
    float_image = sitk.Cast(image, sitk.sitkFloat32) # apparently n4biasfieldcorrectionimagefilter doesn't take int16, that's why i added this line
    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    image_corrected = corrector.Execute(float_image, mask_image)

    mask_filter = sitk.MaskImageFilter()
    mask_filter.SetOutsideValue(0)
    image_corrected_masked = mask_filter.Execute(image_corrected, mask_image)

    return image_corrected_masked


def coregister_antspy(
    fixed_path: Union[str, pathlib.Path],
    moving_path: Union[str, pathlib.Path],
    out_path: Union[str, pathlib.Path],
    num_threads=N_PROC,
) -> ants.core.ants_image.ANTsImage:
    """
    Coregister moving image to fixed image. Return warped image and save to disk.

    Keyword Arguments:
    fixed_path: path to fixed image
    moving_path: path to moving image
    out_path: path to save warped image to
    num_threads: number of threads
    """

    os.environ["ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS"] = str(num_threads)

    res = ants.registration(
        fixed=ants.image_read(fixed_path),
        moving=ants.image_read(moving_path),
        type_of_transform="antsRegistrationSyNQuick[s]",  # or "SyNRA"
        initial_transform=None,
        outprefix="",
        mask=None,
        moving_mask=None,
        mask_all_stages=False,
        grad_step=0.2,
        flow_sigma=3,
        total_sigma=0,
        aff_metric="mattes",
        aff_sampling=32,
        aff_random_sampling_rate=0.2,
        syn_metric="mattes",
        syn_sampling=32,
        reg_iterations=(40, 20, 0),
        aff_iterations=(2100, 1200, 1200, 10),
        aff_shrink_factors=(6, 4, 2, 1),
        aff_smoothing_sigmas=(3, 2, 1, 0),
        write_composite_transform=False,
        random_seed=None,
        verbose=False,
        multivariate_extras=None,
        restrict_transformation=None,
        smoothing_in_mm=False,
    )

    warped_moving = res["warpedmovout"]

    ants.image_write(warped_moving, out_path)

    return warped_moving


def resample(
    itk_image: sitk.Image,
    out_spacing: Tuple[float, ...],
    is_mask: bool,
) -> sitk.Image:
    """
    Resamples sitk image to expected output spacing

    Keyword Arguments:
    itk_image: sitk.Image
    out_spacing: Tuple
    is_mask: bool = True if input image is label mask -> NN-interpolation

    Returns
    output_image: sitk.Image = image resampled to out_spacing
    """

    original_spacing = itk_image.GetSpacing()
    original_size = itk_image.GetSize()

    out_size = [
        int(round(osz * osp / nsp))
        for osz, osp, nsp in zip(original_size, original_spacing, out_spacing)
    ]

    resample = sitk.ResampleImageFilter()
    resample.SetOutputSpacing(out_spacing)
    resample.SetSize(out_size)
    resample.SetOutputDirection(itk_image.GetDirection())
    resample.SetOutputOrigin(itk_image.GetOrigin())
    resample.SetTransform(sitk.Transform())
    resample.SetDefaultPixelValue(0)

    if is_mask:
        resample.SetInterpolator(sitk.sitkNearestNeighbor)

    else:
        resample.SetInterpolator(
            sitk.sitkBSpline
        )  # sitk.sitkLinear sitk.sitkNearestNeighbor

    output_image = resample.Execute(itk_image)

    return output_image


def zscore_normalize(image: sitk.Image) -> sitk.Image:
    """
    Applies z score normalization to brain scan using a brain mask

    Keyword Arguments:
    image: sitk.Image = input brain scan

    Returns:
    normalized_brain_image: sitk.Image = normalized brain scan
    """

    brain_mask = binary_segment_brain(image)

    normalizer = ZScoreNormalize()
    normalized_brain_array = normalizer(
        sitk.GetArrayFromImage(image),
        sitk.GetArrayFromImage(brain_mask),
    )

    normalized_brain_image = sitk.GetImageFromArray(normalized_brain_array)
    normalized_brain_image.CopyInformation(image)

    return normalized_brain_image

# %% [markdown]
# ## Run preprocessing
# Input arguments:\
# path_to_patients: str,\
# path_to_output: str,
#
# The `path_to_patients` variable should lead to a directory, where all the patients directories can be found, in which all the sequences are storted as directories full of dicom files

# %%
path_to_patients = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443"
path_to_output = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30"

N_PROC = multiprocessing.cpu_count() - 1

# %%
# create folder at path to output called Rgb_Brain_Mets_preprocessed
now = datetime.now()
timeFormatted = now.strftime("%Y%m%d-%H%M%S")
path_to_preprocessed_files = f"{path_to_output}/Rgb_Brain_Mets_preprocessed_{timeFormatted}"
os.mkdir(path_to_preprocessed_files)

# gets only the folders at path and puts them in an array 
patient_folders = [
    folder for folder in os.listdir(path_to_patients) if os.path.isdir(os.path.join(path_to_patients, folder))
]

for patient in tqdm(patient_folders):

     # ignores the ds_folders
    if config.dsStore in patient:
        continue
    
    patientID = patient

    # create folder for patient in path_to_preprocessed_files
    funcs.createFolderForPatient(path_to_preprocessed_files, patientID)

    # get the different sequences (stored in folders) for each patient and put them in an array
    dicomSequences = [
        sequenceFolder for sequenceFolder in os.listdir(os.path.join(path_to_patients, patient)) if os.path.isdir(os.path.join(path_to_patients, patient, sequenceFolder))
    ]

    print(f"{patientID}: Starting nifti conversion...")
    # loop through the dicom sequences
    for dicomSequenceFolder in dicomSequences:
        # turn each sequence into nifti file
        # save the nifti file in each patient folder
        path_to_folder = os.path.join(path_to_patients, patient, dicomSequenceFolder)
        path_to_nifti = os.path.join(path_to_patients, patient)
        sequenceType = dicomSequenceFolder.split("_")[1]
        new_file_name = f"{patientID}_{sequenceType}"
        dcm_to_nifti_conversion(path_to_folder = path_to_folder,
                                path_to_output = path_to_nifti,
                                out_filename = new_file_name)
        
    print(f"{patientID}: Finished nifti conversion")

    # get the newly converted nifti files
    niftiSequences = [
        sequence for sequence in os.listdir(os.path.join(path_to_patients, patient)) if (".nii.gz" in sequence)
    ]

    if len(niftiSequences) < 4:
        print(f"Warning: too few nifti files found ({len(niftiSequences)})")

    # loop through the nifit sequences
    for niftiSequence in niftiSequences:

        # reorient images
        print(f"{niftiSequence}: Starting reorientation")
        sequenceType = (niftiSequence.split("_")[1]).split(".")[0]
        path_to_input_image = os.path.join(path_to_patients, patient, niftiSequence)
        path_to_output_reorientedImage = f"{path_to_patients}/{patient}/{patientID}_{sequenceType}_reoriented.nii"
        reorient_brain(path_to_input_image = path_to_input_image,
                      path_to_output_image = path_to_output_reorientedImage)
        print(f"{niftiSequence}: Finished reorientation")

        # use brain extraction
        print(f"{patientID} {sequenceType}: Starting brain extraction")
        path_to_output_extractedImage = f"{path_to_patients}/{patient}/{patientID}_{sequenceType}_brainextracted.nii"
        extract_brain(path_to_input_image=path_to_input_image, path_to_output_image=path_to_output_extractedImage, device="cpu")
        #os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_extractedImage} -device cpu -mode fast -tta 0")
        print(f"{patientID} {sequenceType}: Finished brain extraction")
    
    # get the brain extracted files
    brainExtractedFiles = [
        sequence for sequence in os.listdir(os.path.join(path_to_patients, patient)) if ("brainextracted" in sequence and "mask" not in sequence)
    ]

    if len(brainExtractedFiles) < 4:
        print(f"Warning: too few brain extracted files found ({len(brainExtractedFiles)})")

    # loop through the nifit sequences
    for brainExtractedSequence in brainExtractedFiles:
        print(f"{brainExtractedSequence}: Starting bounding box")

        input_image = sitk.ReadImage(os.path.join(path_to_patients, patient, brainExtractedSequence), imageIO="NiftiImageIO")

        # get and apply a bounding box both to the brain as well as the mask
        croppedImage = apply_bounding_box(
            image = input_image,
            bounding_box = get_bounding_box(image = input_image))
        print(f"{brainExtractedSequence}: Finished bounding box")

        # n4 bias correction
        print(f"{brainExtractedSequence}: Starting n4 bias correction")
        n4correctedImage = apply_bias_correction(image = croppedImage)
        print(f"{brainExtractedSequence}: Finished n4 bias correction")

        # save image
        sequenceType = (brainExtractedSequence.split("_")[1]).split(".")[0]
        path_to_output_image = f"{path_to_patients}/{patient}/{patientID}_{sequenceType}_n4biascorrected.nii.gz"
        sitk.WriteImage(n4correctedImage, path_to_output_image, imageIO = "NiftiImageIO")


    n4correctedFiles = [
        sequence for sequence in os.listdir(os.path.join(path_to_patients, patient)) if ("_n4biascorrected" in sequence)
    ]

    if len(n4correctedFiles) < 4:
        print(f"Warning: too few brain n4biascorrected files found ({len(n4correctedFiles)})")

    # the T1CE sequence was arbitrarily chosen as a reference sequence for the coregistration
    referenceSequenceForCoregistration = [reference for reference in n4correctedFiles if "T1CE" in reference][0]

    for n4correctedFile in n4correctedFiles:
        
        sequenceType = (n4correctedFile.split("_")[1]).split(".")[0]
        coregistered_out_path = f"{path_to_patients}/{patient}/{patientID}_{sequenceType}_coregistered.nii.gz"

        # skip coregistration for the reference Sequence 
        if "T1CE" not in n4correctedFile:
            
            # coregister images
            print(f"{patientID} {sequenceType}: Starting coregistration of sequence")
            coregister_antspy(
                fixed_path = os.path.join(path_to_patients, patient, referenceSequenceForCoregistration),
                moving_path = os.path.join(path_to_patients, patient, n4correctedFile),
                out_path = coregistered_out_path,
                num_threads = N_PROC)
            print(f"{patientID} {sequenceType}: Finished coregistration of sequence")
        else:
            coregistered_out_path = f"{path_to_patients}/{patient}/{n4correctedFile}"

        coregistered_image = sitk.ReadImage(coregistered_out_path, imageIO="NiftiImageIO")


        # resample images
        print(f"{patientID} {sequenceType}: Stating resampling of images")
        resampled_image = resample(
            itk_image = coregistered_image,
            out_spacing = (1,1,1),
            is_mask = False
        )
        print(f"{patientID} {sequenceType}: Finished resampling of images")

        # z score normalize images
        print(f"{patientID} {sequenceType}: Starting z score normalization of sequence")
        z_normalized_image = zscore_normalize(resampled_image)
        print(f"{patientID} {sequenceType}: Starting z score normalization of sequence")

        # save z_normalized_image in the finished preprocessing folder
        sitk.WriteImage(z_normalized_image, f"{path_to_preprocessed_files}/{patientID}/{patientID}_{sequenceType}_preprocessed.nii.gz", imageIO = "NiftiImageIO")

    print(f"Finished patient {patientID}")
    
    # clean up created files (nifti files and brain extracted images)
    print("Cleaned up unnecessary files")

print("Finished preprocessing images")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Starting nifti conversion...
# 240119-11:35:16,506 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.506551:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:16,507 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.506551:Found 56 DICOM file(s)
# 240119-11:35:16,507 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.506551:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:16,507 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.506551:Philips Scaling Values RS:RI:SS = 1.76337:0:0.137811 (see PMC3998685)
# 240119-11:35:16,508 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.506551:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1CE (512x512x28x1)
# 240119-11:35:16,587 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.587029:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1CE.nii"
# 240119-11:35:16,587 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.587029:Conversion required 0.206500 seconds (0.127183 for core code).
# 240119-11:35:16,846 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.846241:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:16,847 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.846241:Found 56 DICOM file(s)
# 240119-11:35:16,847 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.846241:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:16,847 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.846241:Philips Scaling Values RS:RI:SS = 5.31893:0:0.0452134 (see PMC3998685)
# 240119-11:35:16,847 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.846241:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_FLAIR (528x528x28x1)
# 240119-11:35:16,916 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.916632:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_FLAIR.nii"
# 240119-11:35:16,917 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:16.916632:Conversion required 0.202136 seconds (0.133590 for core code).
# 240119-11:35:17,176 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.176721:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:17,177 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.176721:Found 56 DICOM file(s)
# 240119-11:35:17,178 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.176721:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:17,178 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.176721:Philips Scaling Values RS:RI:SS = 2.25275:0:0.0730654 (see PMC3998685)
# 240119-11:35:17,178 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.176721:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T2 (560x560x28x1)
# 240119-11:35:17,270 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.270284:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T2.nii"
# 240119-11:35:17,270 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.270284:Conversion required 0.243074 seconds (0.152063 for core code).
# 240119-11:35:17,425 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.424995:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:17,425 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.424995:Found 56 DICOM file(s)
# 240119-11:35:17,426 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.424995:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:17,426 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.424995:Philips Scaling Values RS:RI:SS = 9.23874e-07:0:0.0656098 (see PMC3998685)
# 240119-11:35:17,426 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.424995:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_DWI (256x256x28x1)
# 240119-11:35:17,446 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.446007:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_DWI.nii"
# 240119-11:35:17,446 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:17.446007:Conversion required 0.054917 seconds (0.034708 for core code).
# 240119-11:35:18,463 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:18.463024:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:18,463 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:18.463024:Found 370 DICOM file(s)
# 240119-11:35:18,464 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:18.463024:185 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:18,464 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:18.463024:Philips Scaling Values RS:RI:SS = 3.17265:0:0.003199 (see PMC3998685)
# 240119-11:35:18,464 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:18.463024:Convert 185 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1 (560x560x185x1)
# 240119-11:35:19,42 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.042025:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1.nii"
# 240119-11:35:19,42 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.042025:Conversion required 1.483513 seconds (1.034207 for core code).
# 240119-11:35:19,255 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:19,256 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Found 168 DICOM file(s)
# 240119-11:35:19,256 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:84 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:19,256 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Warning: Isotropic DWI series, all bvecs are zero (issue 405)
# 240119-11:35:19,257 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:35:19,257 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Warning: Volume 2 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:35:19,257 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Philips Scaling Values RS:RI:SS = 1.35751:0:0.0656098 (see PMC3998685)
# 240119-11:35:19,257 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.255522:Convert 84 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_DWIa (256x256x28x3)
# 240119-11:35:19,314 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.314184:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_DWIa.nii"
# 240119-11:35:19,314 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.314184:Conversion required 0.166191 seconds (0.109451 for core code).
# 240119-11:35:19,538 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.538435:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:35:19,539 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.538435:Found 56 DICOM file(s)
# 240119-11:35:19,539 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.538435:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:35:19,539 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.538435:Philips Scaling Values RS:RI:SS = 1.71258:0:0.152039 (see PMC3998685)
# 240119-11:35:19,540 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.538435:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1a (512x512x28x1)
# 240119-11:35:19,605 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.605238:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01199093/01199093_T1a.nii"
# 240119-11:35:19,605 nipype.interface INFO:
# 	 stdout 2024-01-19T11:35:19.605238:Conversion required 0.187435 seconds (0.123060 for core code).
# Finished nifti conversion
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
#   4%|▎         | 1/27 [08:46<3:48:14, 526.70s/it]
# Starting z score normalization of sequence
# Finished patient
# Cleaned up unnecessary files
# Starting nifti conversion...
# 240119-11:44:03,71 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,71 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:Found 54 DICOM file(s)
# 240119-11:44:03,72 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,72 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,72 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,72 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.071289:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T1 (256x256x27x1)
# 240119-11:44:03,121 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.121372:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T1.nii"
# 240119-11:44:03,121 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.121372:Conversion required 0.064740 seconds (0.015029 for core code).
# 240119-11:44:03,245 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,245 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:Found 54 DICOM file(s)
# 240119-11:44:03,246 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,246 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,246 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,246 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.244955:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_STERN (216x256x27x1)
# 240119-11:44:03,293 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.293647:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_STERN.nii"
# 240119-11:44:03,293 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.293647:Conversion required 0.061945 seconds (0.013945 for core code).
# 240119-11:44:03,420 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,421 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:Found 54 DICOM file(s)
# 240119-11:44:03,421 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,421 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,421 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,421 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.420478:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_FLAIR (208x256x27x1)
# 240119-11:44:03,468 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.468904:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_FLAIR.nii"
# 240119-11:44:03,469 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.468904:Conversion required 0.062558 seconds (0.014786 for core code).
# 240119-11:44:03,596 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Found 54 DICOM file(s)
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-1738-0001-0001.dcm
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-1599-0001-0001.dcm
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,597 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,598 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: This diffusion series does not have a B0 (reference) volume
# 240119-11:44:03,598 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:44:03,598 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.595976:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_ADC (384x384x27x1)
# 240119-11:44:03,615 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.615771:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_ADC.nii"
# 240119-11:44:03,616 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.615771:Conversion required 0.035573 seconds (0.017285 for core code).
# 240119-11:44:03,746 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,747 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Found 54 DICOM file(s)
# 240119-11:44:03,747 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,748 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,748 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,748 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Warning: This diffusion series does not have a B0 (reference) volume
# 240119-11:44:03,748 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:44:03,748 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.746824:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_DWI (384x384x27x1)
# 240119-11:44:03,808 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.808754:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_DWI.nii"
# 240119-11:44:03,809 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.808754:Conversion required 0.076686 seconds (0.016233 for core code).
# 240119-11:44:03,934 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:03,935 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:Found 54 DICOM file(s)
# 240119-11:44:03,935 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:03,936 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:03,936 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:03,936 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.934789:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T1CE (256x256x27x1)
# 240119-11:44:03,983 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.983389:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T1CE.nii"
# 240119-11:44:03,983 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:03.983389:Conversion required 0.062379 seconds (0.014557 for core code).
# 240119-11:44:04,113 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:44:04,114 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:Found 54 DICOM file(s)
# 240119-11:44:04,114 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:44:04,115 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:44:04,115 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:44:04,115 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.113849:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T2 (384x384x27x1)
# 240119-11:44:04,175 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.175122:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01220269/01220269_T2.nii"
# 240119-11:44:04,175 nipype.interface INFO:
# 	 stdout 2024-01-19T11:44:04.175122:Conversion required 0.076475 seconds (0.016744 for core code).
# Finished nifti conversion
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
#   7%|▋         | 2/27 [11:44<2:13:58, 321.52s/it]
# Starting z score normalization of sequence
# Finished patient
# Cleaned up unnecessary files
# Starting nifti conversion...
# 240119-11:47:01,10 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:01,10 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:Found 54 DICOM file(s)
# 240119-11:47:01,11 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:01,11 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:01,11 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:01,11 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.010315:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T1 (260x320x27x1)
# 240119-11:47:01,63 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.063188:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T1.nii"
# 240119-11:47:01,63 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.063188:Conversion required 0.093534 seconds (0.017707 for core code).
# 240119-11:47:01,227 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:01,228 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:Found 54 DICOM file(s)
# 240119-11:47:01,228 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:01,228 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:01,228 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:01,229 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.227624:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T1CE (260x320x27x1)
# 240119-11:47:01,280 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.280352:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T1CE.nii"
# 240119-11:47:01,280 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.280352:Conversion required 0.098548 seconds (0.017573 for core code).
# 240119-11:47:01,438 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:01,439 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Found 54 DICOM file(s)
# 240119-11:47:01,439 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: interpolated protocol 'Diffusion trace tra' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_ADC_0_Diffusion+trace+tra_ADC+-+8/IM-0632-0001-0001.dcm
# 240119-11:47:01,439 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: interpolated protocol 'Diffusion trace tra' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_ADC_0_Diffusion+trace+tra_ADC+-+8/IM-0771-0001-0001.dcm
# 240119-11:47:01,439 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:01,440 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:01,440 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:01,440 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: This diffusion series does not have a B0 (reference) volume
# 240119-11:47:01,440 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:47:01,440 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.438643:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_ADC (384x384x27x1)
# 240119-11:47:01,462 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.462123:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_ADC.nii"
# 240119-11:47:01,462 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.462123:Conversion required 0.061935 seconds (0.020507 for core code).
# 240119-11:47:01,626 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:01,627 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Found 54 DICOM file(s)
# 240119-11:47:01,627 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:01,627 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:01,627 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:01,627 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Warning: This diffusion series does not have a B0 (reference) volume
# 240119-11:47:01,628 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:47:01,628 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.626208:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_DWI (384x384x27x1)
# 240119-11:47:01,691 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.691313:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_DWI.nii"
# 240119-11:47:01,691 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.691313:Conversion required 0.108173 seconds (0.019516 for core code).
# 240119-11:47:01,860 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:01,861 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:Found 54 DICOM file(s)
# 240119-11:47:01,861 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:01,861 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:01,861 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:01,862 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.860529:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T2 (392x448x27x1)
# 240119-11:47:01,954 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.954249:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_T2.nii"
# 240119-11:47:01,954 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:01.954249:Conversion required 0.141450 seconds (0.019761 for core code).
# 240119-11:47:02,118 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:02,119 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:Found 54 DICOM file(s)
# 240119-11:47:02,119 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:02,119 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:02,119 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:02,119 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.118440:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_FLAIR (260x320x27x1)
# 240119-11:47:02,174 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.174614:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_FLAIR.nii"
# 240119-11:47:02,174 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.174614:Conversion required 0.100322 seconds (0.017483 for core code).
# 240119-11:47:02,340 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:47:02,340 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:Found 54 DICOM file(s)
# 240119-11:47:02,341 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:47:02,341 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240119-11:47:02,341 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:47:02,341 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.339934:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_STERN (448x512x27x1)
# 240119-11:47:02,447 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.447867:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01150136/01150136_STERN.nii"
# 240119-11:47:02,448 nipype.interface INFO:
# 	 stdout 2024-01-19T11:47:02.447867:Conversion required 0.152786 seconds (0.021922 for core code).
# Finished nifti conversion
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting reorientation
# Finished reorientation
# Starting brain extraction
# Finished brain extraction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting bounding box
# Finished bounding box
# Starting n4 bias correction
# Finished n4 bias correction
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Starting coregistration of sequence
# Finished coregistration of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
# Starting z score normalization of sequence
# Stating resampling of images
# Finished resampling of images
# Starting z score normalization of sequence
#  11%|█         | 3/27 [15:12<1:47:55, 269.82s/it]
# Starting z score normalization of sequence
# Finished patient
# Cleaned up unnecessary files
# Starting nifti conversion...
# 240119-11:50:29,326 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:29,326 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Found 54 DICOM file(s)
# 240119-11:50:29,326 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0402-0001-0001.dcm
# 240119-11:50:29,327 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-0263-0001-0001.dcm
# 240119-11:50:29,327 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:29,327 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Warning: Slice timing appears corrupted (range 84395..84395, TR=7700 ms)
# 240119-11:50:29,327 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:29,327 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.326122:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_ADC (384x384x27x1)
# 240119-11:50:29,348 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.348336:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_ADC.nii"
# 240119-11:50:29,348 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.348336:Conversion required 0.065548 seconds (0.021738 for core code).
# 240119-11:50:29,508 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:29,509 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:Found 54 DICOM file(s)
# 240119-11:50:29,509 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:29,509 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:Warning: Slice timing appears corrupted (range 4515..4515, TR=4690 ms)
# 240119-11:50:29,509 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:29,510 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.508285:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T2 (320x320x27x1)
# 240119-11:50:29,560 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.560713:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T2.nii"
# 240119-11:50:29,561 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.560713:Conversion required 0.090756 seconds (0.019206 for core code).
# 240119-11:50:29,714 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:29,715 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:Found 54 DICOM file(s)
# 240119-11:50:29,715 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:29,715 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:Warning: Slice timing appears corrupted (range 67680..67680, TR=8000 ms)
# 240119-11:50:29,716 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:29,716 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.714755:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_FLAIR (224x256x27x1)
# 240119-11:50:29,762 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.762680:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_FLAIR.nii"
# 240119-11:50:29,763 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.762680:Conversion required 0.084699 seconds (0.017828 for core code).
# 240119-11:50:29,919 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:29,920 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:Found 54 DICOM file(s)
# 240119-11:50:29,920 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:29,920 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:Warning: Slice timing appears corrupted (range 900..900, TR=933 ms)
# 240119-11:50:29,920 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:29,921 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.919659:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_STERN (224x256x27x1)
# 240119-11:50:29,969 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.969747:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_STERN.nii"
# 240119-11:50:29,970 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:29.969747:Conversion required 0.086907 seconds (0.018209 for core code).
# 240119-11:50:30,138 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:30,139 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:Found 54 DICOM file(s)
# 240119-11:50:30,139 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:30,139 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:Warning: Slice timing appears corrupted (range 482.5..482.5, TR=500 ms)
# 240119-11:50:30,139 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:30,139 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.138283:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T1 (224x256x27x1)
# 240119-11:50:30,187 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.187780:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T1.nii"
# 240119-11:50:30,188 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.187780:Conversion required 0.089907 seconds (0.019835 for core code).
# 240119-11:50:30,392 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:30,392 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Found 108 DICOM file(s)
# 240119-11:50:30,393 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0262-0001-0001.dcm
# 240119-11:50:30,393 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0401-0001-0001.dcm
# 240119-11:50:30,393 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:54 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:30,393 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: Discrepancy between reported (7.7s) and estimated (69.3s) repetition time (issue 560).
# 240119-11:50:30,393 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: Slice timing appears corrupted (range 7395..7395, TR=69300 ms)
# 240119-11:50:30,394 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:30,394 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240119-11:50:30,394 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.391980:Convert 54 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_DWI (384x384x27x2)
# 240119-11:50:30,505 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.505331:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_DWI.nii"
# 240119-11:50:30,505 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.505331:Conversion required 0.196563 seconds (0.034638 for core code).
# 240119-11:50:30,664 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240119-11:50:30,665 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:Found 54 DICOM file(s)
# 240119-11:50:30,665 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240119-11:50:30,665 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240119-11:50:30,665 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240119-11:50:30,665 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.664192:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T1CE (224x256x27x1)
# 240119-11:50:30,713 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.713205:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240119-113443/01134825/01134825_T1CE.nii"
# 240119-11:50:30,713 nipype.interface INFO:
# 	 stdout 2024-01-19T11:50:30.713205:Conversion required 0.085336 seconds (0.017892 for core code).
# Finished nifti conversion
# Starting reorientation
# Finished reorientation
# Starting brain extraction
#  11%|█         | 3/27 [15:16<2:02:09, 305.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 66
#      64 print("Starting brain extraction")
#      65 path_to_output_extractedImage = f"{path_to_patients}/{patient}/{patientID}_{sequenceType}_brainextracted.nii"
# ---> 66 extract_brain(path_to_input_image=path_to_input_image, path_to_output_image=path_to_output_extractedImage, device="cpu")
#      67 #os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_extractedImage} -device cpu -mode fast -tta 0")
#      68 print("Finished brain extraction")
#
# Cell In[14], line 55, in extract_brain(path_to_input_image, path_to_output_image, device)
#      53 # os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_extractedImage} -device cpu -mode fast -tta 0")
#      54 if device == "cpu":
# ---> 55     subprocess.call(["hd-bet", "-i", f"{path_to_input_image}", "-o", f"{path_to_output_image}", "-device", "cpu", "-mode", "fast", "-tta", "0"], stdout=open(os.devnull, "w"), stderr=subprocess.STDOUT)
#      56 elif device == "gpu":
#      57     subprocess.call(["hd-bet", "-i", f"{path_to_input_image}", "-o", f"{path_to_output_image}"], stdout=open(os.devnull, "w"), stderr=subprocess.STDOUT)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1260, in Popen.wait(self, timeout)
#    1258     endtime = _time() + timeout
#    1259 try:
# -> 1260     return self._wait(timeout=timeout)
#    1261 except KeyboardInterrupt:
#    1262     # https://bugs.python.org/issue25942
#    1263     # The first keyboard interrupt waits briefly for the child to
#    1264     # exit under the common assumption that it also received the ^C
#    1265     # generated SIGINT and will exit rapidly.
#    1266     if timeout is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1995, in Popen._wait(self, timeout)
#    1993 if self.returncode is not None:
#    1994     break  # Another thread waited.
# -> 1995 (pid, sts) = self._try_wait(0)
#    1996 # Check the pid and loop as waitpid has been known to
#    1997 # return 0 even without WNOHANG in odd situations.
#    1998 # http://bugs.python.org/issue14396.
#    1999 if pid == self.pid:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:1953, in Popen._try_wait(self, wait_flags)
#    1951 """All callers to this function MUST hold self._waitpid_lock."""
#    1952 try:
# -> 1953     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1954 except ChildProcessError:
#    1955     # This happens if SIGCLD is set to be ignored or waiting
#    1956     # for child processes has otherwise been disabled for our
#    1957     # process.  This child is dead, we can't get the status.
#    1958     pid = self.pid
#
# KeyboardInterrupt:
