# %% [markdown]
# # Preprocessing all at once
# This notebook is meant to run the preprocessing code found in the scripts directory all at once\
# If you'd rather run the code step by step go to the `02_preprocessing_step_by_step.ipynb` file\
# The preprocesing steps include
# 1. convert dicom to nifti using [Dcm2niix](https://github.com/rordenlab/dcm2niix)
# 2. reorient images
# 3. extract brain using [HD-BET](https://github.com/MIC-DKFZ/HD-BET)
# 4. N4 bias correction
# 5. Coregister images
# 6. Resample images
# 7. Z-score normalize images

# %% [markdown]
# ## Import necessary libraries

# %%
import sys
sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification")
#sys.path.append(r"/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/HD-BET/HD_BET")
import brain_mets_classification.config as config
import brain_mets_classification.custom_funcs as funcs

from tqdm import tqdm
from datetime import datetime

import pandas as pd
import os
import pathlib
import ants
from typing import Union, List, Tuple
import multiprocessing
import SimpleITK as sitk
from nipype.interfaces.dcm2nii import Dcm2niix
import numpy as np
#from HD_BET.run import run_hd_bet
#import HD_BET
from nipype.interfaces import fsl
#from intensity_normalization.normalize.zscore import ZScoreNormalize

os.environ["FSLOUTPUTTYPE"] = "NIFTI"

# %% [markdown]
# ## Helper Functions

# %%
N_PROC = multiprocessing.cpu_count() - 1

def dcm_to_nifti_conversion(
        path_to_folder: Union[str, pathlib.Path],
        path_to_output: Union[str, pathlib.Path],
        out_filename: str):

    # new sequence name: {patientID}_{sequence}_{preprocessingStep}
    converter = Dcm2niix()
    converter.inputs.source_dir = path_to_folder
    converter.inputs.compress = "y" # uses compression, "y" = yes
    converter.inputs.merge_imgs = True
    # converter.inputs.compression = 5
    converter.inputs.out_filename = out_filename
    converter.inputs.output_dir = path_to_output
    converter.run()
    

def extract_brain(
    path_to_input_image: Union[str, pathlib.Path],
    path_to_output_image: Union[str, pathlib.Path],
):
    """
    applies FSL.Reorient2Std() to input brain scan
    and returns brain extracted image

    Keyword Arguments:
    path_to_input_image: Union[str, pathlib.Path] = file path to input image (brain scan)
    path_to_output_image: Union[str, pathlib.Path] = location to store brain extracted image
    """

    # Alternative: torchio tocanonical
    reorient = fsl.Reorient2Std()
    reorient.inputs.in_file = path_to_input_image
    reorient.inputs.out_file = path_to_output_image
    reorient.run()

    #run_hd_bet(mri_fnames=path_to_output_image, output_fnames=path_to_output_image)
    #os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_image} -device cpu -mode fast -tta 0")


def fill_holes(
    binary_image: sitk.Image,
    radius: int = 3,
) -> sitk.Image:
    """
    Fills holes in binary segmentation

    Keyword Arguments:
    - binary_image: sitk.Image = binary brain segmentation
    - radius: int = kernel radius

    Returns:
    - closed_image: sitk.Image = binary brain segmentation with holes filled
    """

    closing_filter = sitk.BinaryMorphologicalClosingImageFilter()
    closing_filter.SetKernelRadius(radius)
    closed_image = closing_filter.Execute(binary_image)

    return closed_image


def binary_segment_brain(
    image: sitk.Image,
) -> sitk.Image:
    """
    Returns binary segmentation of brain from brain-extracted scan via otsu thresholding

    Keyword Arguments:
    - image: sitk.Image = brain-extracted scan

    Returns:
    - sitk.Image = binary segmentation of brain scan with filled holes
    """

    otsu_filter = sitk.OtsuThresholdImageFilter()
    otsu_filter.SetInsideValue(0)
    otsu_filter.SetOutsideValue(1)
    binary_mask = otsu_filter.Execute(image)

    return fill_holes(binary_mask)


def get_bounding_box(
    image: sitk.Image,
) -> Tuple[int]:
    """
    Returns bounding box of brain-extracted scan

    Keyword Arguments:
    - image: sitk.Image = brain-extracted scan

    Returns
    - bounding_box: Tuple(int) = bounding box (startX, startY, startZ, sizeX, sizeY, sizeZ)
    """

    mask_image = binary_segment_brain(image)

    lsif = sitk.LabelShapeStatisticsImageFilter()
    lsif.Execute(mask_image)
    bounding_box = np.array(lsif.GetBoundingBox(1))

    return bounding_box


def apply_bounding_box(
    image: sitk.Image,
    bounding_box: Tuple[int],
) -> sitk.Image:
    """
    Returns image, cropped to bounding box

    Keyword Arguments:
    - image: sitk.Image = image
    - bounding_box: Tuple(ing) = bounding box of kind (startX, startY, startZ, sizeX, sizeY, sizeZ)

    Returns
    - cropped_image: sitk.Image = cropped image
    """

    cropped_image = image[
        bounding_box[0] : bounding_box[3] + bounding_box[0],
        bounding_box[1] : bounding_box[4] + bounding_box[1],
        bounding_box[2] : bounding_box[5] + bounding_box[2],
    ]

    return cropped_image


def apply_bias_correction(
    image: sitk.Image,
) -> sitk.Image:
    """applies N4 bias field correction to image but keeps background at zero

    Keyword Arguments:
    image: sitk.Image = image to apply bias correction to

    Returns:
    image_corrected_masked: sitk.Image = N4 bias field corrected image
    """

    mask_image = binary_segment_brain(image)
    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    image_corrected = corrector.Execute(image, mask_image)

    mask_filter = sitk.MaskImageFilter()
    mask_filter.SetOutsideValue(0)
    image_corrected_masked = mask_filter.Execute(image_corrected, mask_image)

    return image_corrected_masked


def coregister_antspy(
    fixed_path: Union[str, pathlib.Path],
    moving_path: Union[str, pathlib.Path],
    out_path: Union[str, pathlib.Path],
    num_threads=N_PROC,
) -> ants.core.ants_image.ANTsImage:
    """
    Coregister moving image to fixed image. Return warped image and save to disk.

    Keyword Arguments:
    fixed_path: path to fixed image
    moving_path: path to moving image
    out_path: path to save warped image to
    num_threads: number of threads
    """

    os.environ["ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS"] = str(num_threads)

    res = ants.registration(
        fixed=ants.image_read(fixed_path),
        moving=ants.image_read(moving_path),
        type_of_transform="antsRegistrationSyNQuick[s]",  # or "SyNRA"
        initial_transform=None,
        outprefix="",
        mask=None,
        moving_mask=None,
        mask_all_stages=False,
        grad_step=0.2,
        flow_sigma=3,
        total_sigma=0,
        aff_metric="mattes",
        aff_sampling=32,
        aff_random_sampling_rate=0.2,
        syn_metric="mattes",
        syn_sampling=32,
        reg_iterations=(40, 20, 0),
        aff_iterations=(2100, 1200, 1200, 10),
        aff_shrink_factors=(6, 4, 2, 1),
        aff_smoothing_sigmas=(3, 2, 1, 0),
        write_composite_transform=False,
        random_seed=None,
        verbose=False,
        multivariate_extras=None,
        restrict_transformation=None,
        smoothing_in_mm=False,
    )

    warped_moving = res["warpedmovout"]

    ants.image_write(warped_moving, out_path)

    return warped_moving


def resample(
    itk_image: sitk.Image,
    out_spacing: Tuple[float, ...],
    is_mask: bool,
) -> sitk.Image:
    """
    Resamples sitk image to expected output spacing

    Keyword Arguments:
    itk_image: sitk.Image
    out_spacing: Tuple
    is_mask: bool = True if input image is label mask -> NN-interpolation

    Returns
    output_image: sitk.Image = image resampled to out_spacing
    """

    original_spacing = itk_image.GetSpacing()
    original_size = itk_image.GetSize()

    out_size = [
        int(round(osz * osp / nsp))
        for osz, osp, nsp in zip(original_size, original_spacing, out_spacing)
    ]

    resample = sitk.ResampleImageFilter()
    resample.SetOutputSpacing(out_spacing)
    resample.SetSize(out_size)
    resample.SetOutputDirection(itk_image.GetDirection())
    resample.SetOutputOrigin(itk_image.GetOrigin())
    resample.SetTransform(sitk.Transform())
    resample.SetDefaultPixelValue(0)

    if is_mask:
        resample.SetInterpolator(sitk.sitkNearestNeighbor)

    else:
        resample.SetInterpolator(
            sitk.sitkBSpline
        )  # sitk.sitkLinear sitk.sitkNearestNeighbor

    output_image = resample.Execute(itk_image)

    return output_image


def zscore_normalize(image: sitk.Image) -> sitk.Image:
    """
    Applies z score normalization to brain scan using a brain mask

    Keyword Arguments:
    image: sitk.Image = input brain scan

    Returns:
    normalized_brain_image: sitk.Image = normalized brain scan
    """

    brain_mask = binary_segment_brain(image)

    normalizer = ZScoreNormalize()
    normalized_brain_array = normalizer(
        sitk.GetArrayFromImage(image),
        sitk.GetArrayFromImage(brain_mask),
    )

    normalized_brain_image = sitk.GetImageFromArray(normalized_brain_array)
    normalized_brain_image.CopyInformation(image)

    return normalized_brain_image

# %% [markdown]
# ## Run preprocessing
# Input arguments:\
# path_to_patients: str,\
# path_to_output: str,
#
# The `path_to_patients` variable should lead to a directory, where all the patients directories can be found, in which all the sequences are storted as directories full of dicom files

# %%
path_to_patients = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743"
path_to_output = "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30"

N_PROC = multiprocessing.cpu_count() - 1

# %%
# create folder at path to output called Rgb_Brain_Mets_preprocessed
now = datetime.now()
timeFormatted = now.strftime("%Y%m%d-%H%M%S")
path_to_preprocessed_files = f"{path_to_output}/Rgb_Brain_Mets_preprocessed_{timeFormatted}"
os.mkdir(path_to_preprocessed_files)

# gets only the folders at path and puts them in an array 
patient_folders = [
    folder for folder in os.listdir(path_to_patients) if os.path.isdir(os.path.join(path_to_patients, folder))
]

for patient in tqdm(patient_folders):

     # ignores the ds_folders
    if config.dsStore in patient:
        continue
    
    patientID = patient

    # create folder for patient in path_to_preprocessed_files
    funcs.createFolderForPatient(path_to_preprocessed_files, patientID)

    # get the different sequences (stored in folders) for each patient and put them in an array
    dicomSequences = [
        sequenceFolder for sequenceFolder in os.listdir(os.path.join(path_to_patients, patient)) if os.path.isdir(os.path.join(path_to_patients, patient, sequenceFolder))
    ]

    print("Starting nifti conversion...")
    # loop through the dicom sequences
    for dicomSequenceFolder in dicomSequences:
        # turn each sequence into nifti file
        # save the nifti file in each patient folder
        path_to_folder = os.path.join(path_to_patients, patient, dicomSequenceFolder)
        path_to_nifti = os.path.join(path_to_patients, patient)
        sequenceType = dicomSequenceFolder.split("_")[1]
        new_file_name = f"{patientID}_{sequenceType}"
        dcm_to_nifti_conversion(path_to_folder = path_to_folder,
                                path_to_output = path_to_nifti,
                                out_filename = new_file_name)
        
    print("Finished nifti conversion")

    # get the newly converted nifti files
    niftiSequences = [
        sequence for sequence in os.listdir(os.path.join(path_to_patients, patient)) if (".nii.gz" in sequence)
    ]

    if len(niftiSequences) < 4:
        print(f"Warning: too few nifti files found ({len(niftiSequences)})")
    

    # loop through the nifit sequences
    for niftiSequence in niftiSequences:
        print("Starting reorientation")
        # reorient images
        path_to_input_image = os.path.join(path_to_patients, patient, niftiSequence)
        path_to_output_reorientedImage = f"{path_to_patients}/{patient}/{patientID}_reoriented.nii"
        extract_brain(path_to_input_image = path_to_input_image,
                      path_to_output_image = path_to_output_reorientedImage)
        print("Finished reorientation")

        print("Starting brain extraction")
        # use brain extraction
        path_to_output_extractedImage = f"{path_to_patients}/{patient}/{patientID}_brainextracted.nii"
        os.system(f"hd-bet -i {path_to_input_image} -o {path_to_output_extractedImage} -device cpu -mode fast -tta 0")
        print("Finished brain extraction")
    
    # get the brain extracted files
    brainExtractedFiles = [
        sequence for sequence in os.listdir(os.path.join(path_to_patients, patient)) if ("brainextracted" in sequence)
    ]

    referenceSequenceForCoregistration = ""

    # loop through the nifit sequences
    for brainExtractedSequence in brainExtractedFiles:
        print("Starting bounding box")
        # get and apply a bounding box both to the brain as well as the mask
        print("Finished bounding box")
        print("Starting n4 bias correction")
        # n4 bias correction
        print("Finished n4 bias correction")
        print("Starting coregistration of sequences")
        # coregister images
        print("Finished coregistration of sequences")
        print("Stating resampling of images")
        # resample images
        print("Finished resampling of images")
        print("Starting z score normalization of sequence")
        # z score normalize images
        print("Starting z score normalization of sequence")

    print("Finished patient")
    
    # clean up created files (nifti files and brain extracted images)
    print("Cleaned up unnecessary files")

print("Finished preprocessing images")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Starting nifti conversion...
# 240118-17:39:04,322 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.322241:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:04,323 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.322241:
# 240118-17:39:04,328 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:  Traceback (most recent call last):
# 240118-17:39:04,328 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:04,328 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:    File "<string>", line 1, in <module>
# 240118-17:39:04,329 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:04,329 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:
# 240118-17:39:04,329 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.328099:Remainder of file ignored
# 240118-17:39:04,329 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:04,329 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:  Traceback (most recent call last):
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:    File "<string>", line 1, in <module>
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:
# 240118-17:39:04,330 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.329650:Remainder of file ignored
# 240118-17:39:04,469 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.469044:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:04,469 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.469044:Found 56 DICOM file(s)
# 240118-17:39:04,470 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.469044:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:04,470 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.469044:Philips Scaling Values RS:RI:SS = 1.76337:0:0.137811 (see PMC3998685)
# 240118-17:39:04,470 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.469044:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1CE (512x512x28x1)
# 240118-17:39:04,549 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.549006:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1CE.nii"
# 240118-17:39:04,549 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.549006:Conversion required 0.209533 seconds (0.133414 for core code).
# 240118-17:39:04,691 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.691551:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:04,692 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.691551:
# 240118-17:39:04,696 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:  Traceback (most recent call last):
# 240118-17:39:04,697 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:04,697 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:    File "<string>", line 1, in <module>
# 240118-17:39:04,697 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:04,697 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.696932:Remainder of file ignored
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:  Traceback (most recent call last):
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:04,698 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:    File "<string>", line 1, in <module>
# 240118-17:39:04,699 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:04,699 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:
# 240118-17:39:04,699 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:04.698314:Remainder of file ignored
# 240118-17:39:04,839 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.839880:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:04,840 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.839880:Found 56 DICOM file(s)
# 240118-17:39:04,840 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.839880:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:04,840 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.839880:Philips Scaling Values RS:RI:SS = 5.31893:0:0.0452134 (see PMC3998685)
# 240118-17:39:04,840 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.839880:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_FLAIR (528x528x28x1)
# 240118-17:39:04,907 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.907000:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_FLAIR.nii"
# 240118-17:39:04,907 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:04.907000:Conversion required 0.201476 seconds (0.137001 for core code).
# 240118-17:39:05,11 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.010946:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,12 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.010946:
# 240118-17:39:05,15 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:  Traceback (most recent call last):
# 240118-17:39:05,15 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,15 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:    File "<string>", line 1, in <module>
# 240118-17:39:05,15 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,16 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:
# 240118-17:39:05,16 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.015356:Remainder of file ignored
# 240118-17:39:05,16 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,16 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:  Traceback (most recent call last):
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:    File "<string>", line 1, in <module>
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:
# 240118-17:39:05,17 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.016683:Remainder of file ignored
# 240118-17:39:05,168 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.168830:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:05,169 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.168830:Found 56 DICOM file(s)
# 240118-17:39:05,169 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.168830:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:05,169 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.168830:Philips Scaling Values RS:RI:SS = 2.25275:0:0.0730654 (see PMC3998685)
# 240118-17:39:05,169 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.168830:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T2 (560x560x28x1)
# 240118-17:39:05,262 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.262094:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T2.nii"
# 240118-17:39:05,262 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.262094:Conversion required 0.239190 seconds (0.148819 for core code).
# 240118-17:39:05,369 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.369283:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,370 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.369283:
# 240118-17:39:05,374 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:  Traceback (most recent call last):
# 240118-17:39:05,374 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,374 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:    File "<string>", line 1, in <module>
# 240118-17:39:05,375 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,375 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:
# 240118-17:39:05,375 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.374114:Remainder of file ignored
# 240118-17:39:05,376 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,376 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:
# 240118-17:39:05,376 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:  Traceback (most recent call last):
# 240118-17:39:05,376 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,377 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:    File "<string>", line 1, in <module>
# 240118-17:39:05,377 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,377 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:
# 240118-17:39:05,377 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.376175:Remainder of file ignored
# 240118-17:39:05,425 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.425476:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:05,425 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.425476:Found 56 DICOM file(s)
# 240118-17:39:05,426 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.425476:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:05,426 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.425476:Philips Scaling Values RS:RI:SS = 9.23874e-07:0:0.0656098 (see PMC3998685)
# 240118-17:39:05,426 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.425476:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWI (256x256x28x1)
# 240118-17:39:05,449 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.449675:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWI.nii"
# 240118-17:39:05,450 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:05.449675:Conversion required 0.067083 seconds (0.036861 for core code).
# 240118-17:39:05,554 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.554151:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,555 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.554151:
# 240118-17:39:05,558 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:  Traceback (most recent call last):
# 240118-17:39:05,559 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,559 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:    File "<string>", line 1, in <module>
# 240118-17:39:05,559 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.558706:Remainder of file ignored
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:  Traceback (most recent call last):
# 240118-17:39:05,560 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:05,561 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:    File "<string>", line 1, in <module>
# 240118-17:39:05,561 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:05,561 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:
# 240118-17:39:05,561 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:05.560405:Remainder of file ignored
# 240118-17:39:06,465 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:06.465666:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:06,466 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:06.465666:Found 370 DICOM file(s)
# 240118-17:39:06,466 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:06.465666:185 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:06,466 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:06.465666:Philips Scaling Values RS:RI:SS = 3.17265:0:0.003199 (see PMC3998685)
# 240118-17:39:06,466 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:06.465666:Convert 185 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1 (560x560x185x1)
# 240118-17:39:07,46 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.046877:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1.nii"
# 240118-17:39:07,47 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.046877:Conversion required 1.480060 seconds (1.021624 for core code).
# 240118-17:39:07,139 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.139731:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:07,140 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.139731:
# 240118-17:39:07,143 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:  Traceback (most recent call last):
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:    File "<string>", line 1, in <module>
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.143909:Remainder of file ignored
# 240118-17:39:07,144 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:  Traceback (most recent call last):
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:    File "<string>", line 1, in <module>
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:07,145 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:
# 240118-17:39:07,146 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.144933:Remainder of file ignored
# 240118-17:39:07,304 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:07,304 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Found 168 DICOM file(s)
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:84 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Warning: Isotropic DWI series, all bvecs are zero (issue 405)
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Warning: Volume 2 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Philips Scaling Values RS:RI:SS = 1.35751:0:0.0656098 (see PMC3998685)
# 240118-17:39:07,305 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.304539:Convert 84 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWIa (256x256x28x3)
# 240118-17:39:07,365 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.365769:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWIa.nii"
# 240118-17:39:07,366 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.365769:Conversion required 0.215329 seconds (0.112603 for core code).
# 240118-17:39:07,463 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.463362:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:07,464 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.463362:
# 240118-17:39:07,467 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:  Traceback (most recent call last):
# 240118-17:39:07,467 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:    File "<string>", line 1, in <module>
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.467665:Remainder of file ignored
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:39:07,468 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:  Traceback (most recent call last):
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:    File "<frozen site>", line 186, in addpackage
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:    File "<string>", line 1, in <module>
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:
# 240118-17:39:07,469 nipype.interface INFO:
# 	 stderr 2024-01-18T17:39:07.468756:Remainder of file ignored
# 240118-17:39:07,595 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.595962:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:39:07,596 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.595962:Found 56 DICOM file(s)
# 240118-17:39:07,596 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.595962:28 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:39:07,596 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.595962:Philips Scaling Values RS:RI:SS = 1.71258:0:0.152039 (see PMC3998685)
# 240118-17:39:07,597 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.595962:Convert 28 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1a (512x512x28x1)
# 240118-17:39:07,663 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.663031:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1a.nii"
# 240118-17:39:07,663 nipype.interface INFO:
# 	 stdout 2024-01-18T17:39:07.663031:Conversion required 0.188182 seconds (0.123490 for core code).
# Finished nifti conversion
# Starting reorientation
# 240118-17:39:07,715 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T2.nii.gz
# preprocessing...
# image shape after preprocessing:  (103, 153, 153)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:39:32,548 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1CE.nii.gz
# preprocessing...
# image shape after preprocessing:  (103, 153, 153)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:39:46,215 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1a.nii.gz
# preprocessing...
# image shape after preprocessing:  (103, 153, 153)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:40:00,7 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_FLAIR.nii.gz
# preprocessing...
# image shape after preprocessing:  (103, 153, 153)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:40:13,301 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWI.nii.gz
# preprocessing...
# image shape after preprocessing:  (103, 154, 154)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:40:25,815 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_T1.nii.gz
# preprocessing...
# image shape after preprocessing:  (167, 167, 123)
# prediction (CNN id)...
# 0
# running postprocessing...
# exporting segmentation...
# Finished brain extraction
# Starting reorientation
# 240118-17:40:52,117 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01199093/01199093_DWIa.nii.gz
# preprocessing...
# The image has unsupported number of dimensions. Only 3D images are allowed
#   4%|▎         | 1/27 [01:49<47:28, 109.55s/it]
# Finished brain extraction
# Finished patient
# Cleaned up unnecessary files
# Starting nifti conversion...
# 240118-17:40:53,836 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.835961:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:53,836 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.835961:
# 240118-17:40:53,844 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:  Traceback (most recent call last):
# 240118-17:40:53,844 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:53,844 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:    File "<string>", line 1, in <module>
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.844629:Remainder of file ignored
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:  Traceback (most recent call last):
# 240118-17:40:53,845 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:53,846 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:    File "<string>", line 1, in <module>
# 240118-17:40:53,846 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:53,846 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:
# 240118-17:40:53,846 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:53.845498:Remainder of file ignored
# 240118-17:40:53,890 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:40:53,891 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:Found 54 DICOM file(s)
# 240118-17:40:53,891 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:40:53,891 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240118-17:40:53,891 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:40:53,891 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.890847:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_T1 (256x256x27x1)
# 240118-17:40:53,942 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.942248:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_T1.nii"
# 240118-17:40:53,942 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:53.942248:Conversion required 0.086041 seconds (0.015347 for core code).
# 240118-17:40:54,26 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.026637:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,27 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.026637:
# 240118-17:40:54,30 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:  Traceback (most recent call last):
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:    File "<string>", line 1, in <module>
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.030914:Remainder of file ignored
# 240118-17:40:54,31 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:  Traceback (most recent call last):
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:    File "<string>", line 1, in <module>
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:
# 240118-17:40:54,32 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.031886:Remainder of file ignored
# 240118-17:40:54,72 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:40:54,73 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:Found 54 DICOM file(s)
# 240118-17:40:54,73 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:40:54,73 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240118-17:40:54,73 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:40:54,73 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.072864:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_STERN (216x256x27x1)
# 240118-17:40:54,120 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.120405:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_STERN.nii"
# 240118-17:40:54,120 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.120405:Conversion required 0.082758 seconds (0.015688 for core code).
# 240118-17:40:54,210 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.210860:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,211 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.210860:
# 240118-17:40:54,215 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:  Traceback (most recent call last):
# 240118-17:40:54,215 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,215 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:    File "<string>", line 1, in <module>
# 240118-17:40:54,215 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.215292:Remainder of file ignored
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:  Traceback (most recent call last):
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,216 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:    File "<string>", line 1, in <module>
# 240118-17:40:54,217 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,217 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:
# 240118-17:40:54,217 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.216372:Remainder of file ignored
# 240118-17:40:54,255 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:40:54,255 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:Found 54 DICOM file(s)
# 240118-17:40:54,255 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:40:54,256 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240118-17:40:54,256 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:40:54,256 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.255491:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_FLAIR (208x256x27x1)
# 240118-17:40:54,306 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.306753:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_FLAIR.nii"
# 240118-17:40:54,307 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.306753:Conversion required 0.084703 seconds (0.015620 for core code).
# 240118-17:40:54,393 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.392994:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,393 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.392994:
# 240118-17:40:54,397 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:  Traceback (most recent call last):
# 240118-17:40:54,397 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,397 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:    File "<string>", line 1, in <module>
# 240118-17:40:54,397 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,397 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.397290:Remainder of file ignored
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:  Traceback (most recent call last):
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:    File "<frozen site>", line 186, in addpackage
# 240118-17:40:54,398 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:    File "<string>", line 1, in <module>
# 240118-17:40:54,399 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:40:54,399 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:
# 240118-17:40:54,399 nipype.interface INFO:
# 	 stderr 2024-01-18T17:40:54.398346:Remainder of file ignored
# 240118-17:40:54,441 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:40:54,441 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Found 54 DICOM file(s)
# 240118-17:40:54,441 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-1738-0001-0001.dcm
# 240118-17:40:54,441 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_ADC_0_Diffusion+trace+tra+schnell_ADC+-+8/IM-1599-0001-0001.dcm
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: Weird CSA 'ProtocolSliceNumber' (System/Miscellaneous/ImageNumbering reversed): VALIDATE SLICETIMING AND BVECS
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: This diffusion series does not have a B0 (reference) volume
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Warning: Volume 0 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240118-17:40:54,442 nipype.interface INFO:
# 	 stdout 2024-01-18T17:40:54.441328:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01220269/01220269_ADC (384x384x27x1)
# 240118-17:40:54,459 nipype.interface INFO:
# ...
# 	 stderr 2024-01-18T17:43:35.768938:    File "<string>", line 1, in <module>
# 240118-17:43:35,769 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.768938:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:35,769 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.768938:
# 240118-17:43:35,769 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.768938:Remainder of file ignored
# 240118-17:43:35,769 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:  Traceback (most recent call last):
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:    File "<string>", line 1, in <module>
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:35,770 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:
# 240118-17:43:35,771 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.769993:Remainder of file ignored
# 240118-17:43:35,812 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:43:35,813 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:Found 54 DICOM file(s)
# 240118-17:43:35,813 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:43:35,813 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:Warning: Slice timing appears corrupted (range 900..900, TR=933 ms)
# 240118-17:43:35,813 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:43:35,813 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.812820:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_STERN (224x256x27x1)
# 240118-17:43:35,861 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.861410:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_STERN.nii"
# 240118-17:43:35,861 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:35.861410:Conversion required 0.085584 seconds (0.018232 for core code).
# 240118-17:43:35,951 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.950951:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:35,951 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.950951:
# 240118-17:43:35,955 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:  Traceback (most recent call last):
# 240118-17:43:35,955 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:35,955 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:    File "<string>", line 1, in <module>
# 240118-17:43:35,955 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:35,955 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.955307:Remainder of file ignored
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:  Traceback (most recent call last):
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:    File "<string>", line 1, in <module>
# 240118-17:43:35,956 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:35,957 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:
# 240118-17:43:35,957 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:35.956312:Remainder of file ignored
# 240118-17:43:36,14 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:43:36,15 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:Found 54 DICOM file(s)
# 240118-17:43:36,15 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:43:36,15 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:Warning: Slice timing appears corrupted (range 482.5..482.5, TR=500 ms)
# 240118-17:43:36,15 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:43:36,15 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.014923:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_T1 (224x256x27x1)
# 240118-17:43:36,64 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.064041:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_T1.nii"
# 240118-17:43:36,64 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.064041:Conversion required 0.101955 seconds (0.018906 for core code).
# 240118-17:43:36,150 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.150396:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:36,151 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.150396:
# 240118-17:43:36,154 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:  Traceback (most recent call last):
# 240118-17:43:36,154 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:36,155 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:    File "<string>", line 1, in <module>
# 240118-17:43:36,155 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:36,155 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:
# 240118-17:43:36,155 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.154751:Remainder of file ignored
# 240118-17:43:36,155 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:  Traceback (most recent call last):
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:    File "<string>", line 1, in <module>
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:
# 240118-17:43:36,156 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.155861:Remainder of file ignored
# 240118-17:43:36,233 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:43:36,233 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Found 108 DICOM file(s)
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0262-0001-0001.dcm
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: interpolated protocol 'Diffusion trace tra schnell' may be unsuitable for dwidenoise/mrdegibbs. /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_DWI_0_Diffusion+trace+tra+schnell_TRACEW+-+7/IM-0401-0001-0001.dcm
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:54 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: Discrepancy between reported (7.7s) and estimated (69.3s) repetition time (issue 560).
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: Slice timing appears corrupted (range 7395..7395, TR=69300 ms)
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:43:36,234 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Warning: Volume 1 appears to be derived image ADC/Isotropic (non-zero b-value with zero vector length)
# 240118-17:43:36,235 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.233523:Convert 54 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_DWI (384x384x27x2)
# 240118-17:43:36,342 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.342542:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_DWI.nii"
# 240118-17:43:36,342 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.342542:Conversion required 0.180521 seconds (0.034329 for core code).
# 240118-17:43:36,428 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.428843:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:36,429 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.428843:
# 240118-17:43:36,433 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:  Traceback (most recent call last):
# 240118-17:43:36,433 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:36,433 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:    File "<string>", line 1, in <module>
# 240118-17:43:36,433 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:36,433 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.433210:Remainder of file ignored
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:Error processing line 1 of /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/.brain_mets_env/lib/python3.11/site-packages/distutils-precedence.pth:
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:  Traceback (most recent call last):
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:    File "<frozen site>", line 186, in addpackage
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:    File "<string>", line 1, in <module>
# 240118-17:43:36,434 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:  AttributeError: module '_distutils_hack' has no attribute 'add_shim'
# 240118-17:43:36,435 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:
# 240118-17:43:36,435 nipype.interface INFO:
# 	 stderr 2024-01-18T17:43:36.434188:Remainder of file ignored
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:Chris Rorden's dcm2niiX version v1.0.20220505  Clang15.0.0 ARM (64-bit MacOS)
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:Found 54 DICOM file(s)
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:27 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:Warning: Slice timing appears corrupted (range 61615..61615, TR=450 ms)
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:Warning: Assuming mosaics saved in reverse order due to 'sSliceArray.ucImageNumb'
# 240118-17:43:36,476 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.475991:Convert 27 DICOM as /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_T1CE (224x256x27x1)
# 240118-17:43:36,525 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.525233:Compress: "/opt/homebrew/bin/pigz" -b 960 -n -f -6 "/Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_T1CE.nii"
# 240118-17:43:36,525 nipype.interface INFO:
# 	 stdout 2024-01-18T17:43:36.525233:Conversion required 0.085152 seconds (0.017722 for core code).
# Finished nifti conversion
# Starting reorientation
# 240118-17:43:36,578 nipype.interface WARNING:
# 	 FSLOUTPUTTYPE environment variable is not set. Setting FSLOUTPUTTYPE=NIFTI
# Finished reorientation
# Starting brain extraction
# /opt/homebrew/bin/hd-bet:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').require('HD-BET==1.0')
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# File: /Users/LennartPhilipp/Desktop/Uni/Prowiss/Code/Brain_Mets_Classification/Rgb_Brain_Mets_Dataset/N30/Rgb_Brain_Mets_Preprocessing_01_sequencesFiltered_20240118-173743/01134825/01134825_T1CE.nii.gz
# preprocessing...
# image shape after preprocessing:  (99, 153, 134)
# prediction (CNN id)...
# 0
